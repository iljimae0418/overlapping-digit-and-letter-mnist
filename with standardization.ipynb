# %%
# environment: Paperspace Quadro P6000 GPU  
import numpy as np 
import pandas as pd 
import os 
import tensorflow as tf
import tensorflow.keras # run pip install keras==2.3 beforehand for compatability 
from tensorflow.keras import Input, Model 
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, AlphaDropout, MaxPooling2D, AveragePooling2D, BatchNormalization, Concatenate, Flatten, Reshape, Add, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from keras.utils.np_utils import to_categorical
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import skimage
from skimage.transform import rotate
from skimage.util import random_noise
from skimage.transform import warp, AffineTransform
from skimage.transform import resize
import cv2
import random 
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.utils import shuffle # shuffle dataset before splitting into folds
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Read file and preprocess data

# %%
train_path = './storage/modified_mnist_dataset/train.csv'  
test_path = './storage/modified_mnist_dataset/test.csv' 
submission_path = './storage/modified_mnist_dataset/submission.csv'

# %%
train = pd.read_csv(train_path)
test = pd.read_csv(test_path) 
submission = pd.read_csv(submission_path)

# %%
# convert types of digit and letter columns to categorical 
train.iloc[:,1] = pd.Categorical(train.iloc[:,1])
train.iloc[:,2] = pd.Categorical(train.iloc[:,2]) 
test.iloc[:,1] = pd.Categorical(test.iloc[:,1])

# %%
# define and re-format train and test data 
# this time, we will standardize instead of normalize data 
x_train = train.iloc[:,3:].values.reshape(-1,28,28,1).astype(np.float32) 
# standardize - we assume train and test data have the same "distribution" 
mu = np.mean(x_train)
sd = np.std(x_train)
x_train -= mu 
x_train /= sd 
y_train = train.iloc[:,1].values
y_train = np.asarray(y_train)
y_train = to_categorical(y_train, num_classes = 10)
train_letters = train.iloc[:,2].values

x_test = test.iloc[:,2:].values.reshape(-1,28,28,1).astype(np.float32)  
x_test -= mu 
x_test /= sd 
test_letters = test.iloc[:,1].values

# %%
train_letters_numeric = [] 
test_letters_numeric = [] 
for letter in train_letters: 
    train_letters_numeric.append(ord(letter) - ord("A"))
for letter in test_letters: 
    test_letters_numeric.append(ord(letter) - ord("A")) 
    
train_letters_numeric = np.asarray(train_letters_numeric) 
test_letters_numeric = np.asarray(test_letters_numeric) 

train_letters_numeric = to_categorical(train_letters_numeric, num_classes = 26) 
test_letters_numeric = to_categorical(test_letters_numeric, num_classes = 26)

x_train.shape, y_train.shape, x_test.shape, train_letters_numeric.shape, test_letters_numeric.shape
# Out:
# ((2048, 28, 28, 1), (2048, 10), (20480, 28, 28, 1), (2048, 26), (20480, 26))

# %% [markdown]
# # Augment Data
#
# For now, we will try augmenting the data using the following methods
# - rotation
# - adding noise
# - adding gaussian blur
# - shifting image
#
# Please refer to [this notebook](https://github.com/iljimae0418/overlapping-digit-and-letter-mnist/blob/master/Examples%20of%20data%20augmentations.ipynb) for examples.
#
# Some more augmentations were decided to be added. They are
# - modifying brightness
# - ZCA Whitening
# - random crops
#
# Please refer to [this notebook](https://github.com/iljimae0418/overlapping-digit-and-letter-mnist/blob/master/Examples%20of%20augmentation%202%20(further%20augmentation).ipynb) for examples.

# %%
# apply rotations 
x_train_rotated = [] 
for x_data in x_train:
    rotated_img = rotate(x_data, angle = random.randint(10,40))
    x_train_rotated.append(rotated_img) 
x_train_rotated = np.asarray(x_train_rotated)

# %%
# apply clockwise rotations 
x_train_rotated_2 = [] 
for x_data in x_train: 
    rotated_img = rotate(x_data, angle = -random.randint(10,40)) 
    x_train_rotated_2.append(rotated_img)
x_train_rotated_2 = np.asarray(x_train_rotated_2)

# %%
# add noise 
x_noised = [] 
for x_data in x_train: 
    noised_img = random_noise(x_data) 
    x_noised.append(noised_img)
x_noised = np.asarray(x_noised)

# %%
# add gaussian blur 
x_blurred = [] 
for x_data in x_train:
    kernel_size = random.choice([3,5,9]) 
    blurred = cv2.GaussianBlur(x_data, (kernel_size, kernel_size), 0) 
    x_blurred.append(blurred)
x_blurred = np.asarray(x_blurred)
x_blurred = x_blurred.reshape(-1,28,28,1)

# %%
# shift image 
x_shifted = [] 
for x_data in x_train: 
    dx = random.choice([-2,-1,1,2])
    dy = random.choice([-2,-1,1,2])
    transform = AffineTransform(translation = (dx,dy))
    warp_img = warp(x_data, transform, mode = "wrap")
    x_shifted.append(warp_img) 
x_shifted = np.asarray(x_shifted)

# %%
# apply brightness modifications 
x_brightness = [] 
for x_data in x_train: 
    brightness = 0.5
    alpha = 1.0 + random.uniform(-brightness, brightness) 
    brightness_modified = x_data * alpha 
    x_brightness.append(brightness_modified) 

x_brightness = np.asarray(x_brightness)

# %%
# apply zca whitening 
def zca_whitening(sample): 
    sample = sample - sample.mean(axis=0)
    cov = np.cov(sample, rowvar = False)
    U,S,V = np.linalg.svd(cov) 
    epsilon = 0.1
    X_ZCA = U.dot(np.diag(1.0/np.sqrt(S + epsilon))).dot(U.T).dot(sample.T).T
    X_ZCA_rescaled = (X_ZCA - X_ZCA.min()) / (X_ZCA.max() - X_ZCA.min())
    X_ZCA_rescaled = X_ZCA_rescaled.reshape((28,28,1)) 
    return X_ZCA_rescaled 

x_zca_whitened = [] 
for x_data in x_train: 
    zca_whitened = zca_whitening(x_data.reshape((28,28))) 
    x_zca_whitened.append(zca_whitened) 
    
x_zca_whitened = np.asarray(x_zca_whitened)

# %%
# add random cropping (zooming effect)
def random_crop(img): 
    img = img.copy() 
    size = random.randint(22,24) # this seems to be a good balance, since our image size is 28 by 28
    crop_size = (size,size)
    w,h = img.shape[:2]
    x,y = np.random.randint(h-crop_size[0]), np.random.randint(w-crop_size[1])
    img = img[y:y+crop_size[0], x:x+crop_size[1]] 
    return img 

x_random_crop = []
for x_data in x_train: 
    cropped = random_crop(x_data) 
    cropped = resize(cropped, (28,28,1))
    x_random_crop.append(cropped)

x_random_crop = np.asarray(x_random_crop)

# %%
# concatenating augmented data to the original 
x_train = np.concatenate((x_train, x_train_rotated, x_train_rotated_2, x_noised, x_blurred, x_shifted, x_brightness, x_zca_whitened, x_random_crop), axis = 0) 
y_train = np.concatenate((y_train, y_train, y_train, y_train, y_train, y_train, y_train, y_train, y_train), axis = 0) 
train_letters_numeric = np.concatenate((train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric), axis = 0)

x_train.shape, y_train.shape, train_letters_numeric.shape
# Out:
# ((18432, 28, 28, 1), (18432, 10), (18432, 26))

# %% [markdown]
# # Conduct Training

# %%
# uses skip connections and also adds information from both MaxPooling2D and AveragePooling2D 
def conv2d_block(input_layer, n_filters, kernel):
    conv1 = Conv2D(n_filters, kernel, activation = 'relu', padding = 'same')(input_layer)
    conv1 = BatchNormalization()(conv1)
    conv2 = Conv2D(n_filters, kernel, activation = 'relu', padding = 'same')(conv1)
    conv1 = Add()([conv1, conv2])   
    conv1 = BatchNormalization()(conv1)
    maxpool = MaxPooling2D((2,2))(conv1) 
    avgpool = AveragePooling2D((2,2))(conv1)
    ret = Add()([maxpool,avgpool])
    return ret 


def conv2d_block_2(input_layer, n_filters, kernel):
    conv1 = Conv2D(n_filters, kernel, activation = 'selu', padding = 'same', kernel_initializer='lecun_normal')(input_layer)
    conv1 = BatchNormalization()(conv1)
    conv2 = Conv2D(n_filters, kernel, activation = 'selu', padding = 'same', kernel_initializer='lecun_normal')(conv1)
    conv1 = Add()([conv1, conv2])   
    conv1 = BatchNormalization()(conv1)
    maxpool = MaxPooling2D((2,2))(conv1) 
    avgpool = AveragePooling2D((2,2))(conv1)
    ret = Add()([maxpool,avgpool])
    return ret 

# obtains around 82% validation loss on a 9:1 train/validation split
# the most promising model so far, until we come up with a potentially more powerful grade 5 model 
def base_cnn_grade_4(): 
    inputs = Input((28,28,1))
    letter_input = Input((26,))   
    conv1 = conv2d_block(inputs, 64, 7) 
    conv2 = conv2d_block(inputs, 64, 5) 
    conv3 = conv2d_block(inputs, 64, 3) 
    conv = Concatenate()([conv1,conv2,conv3])   
    conv1 = conv2d_block(conv, 32, 7)
    conv2 = conv2d_block(conv, 32, 5)
    conv3 = conv2d_block(conv, 32, 3) 
    conv = Concatenate()([conv1,conv2,conv3]) 
    outputs = Flatten()(conv) 
    outputs = Concatenate()([outputs,letter_input])
    for unit in [512, 256, 128]: 
        outputs = Dense(unit, activation = 'relu')(outputs)  
        outputs = BatchNormalization()(outputs) 
    outputs = Dropout(0.4)(outputs) 
    outputs = Dense(10, activation = 'softmax')(outputs)
    model = Model(inputs = [inputs, letter_input], outputs = outputs)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model  

    
def base_cnn_grade_5(): 
    inputs = Input((28,28,1))
    letter_input = Input((26,))   
    conv1 = conv2d_block(inputs, 64, 7) 
    conv2 = conv2d_block(inputs, 64, 5) 
    conv3 = conv2d_block(inputs, 64, 3) 
    conv4 = conv2d_block(inputs, 64, 1)
    conv = Concatenate()([conv1,conv2,conv3,conv4])   
    conv = BatchNormalization()(conv) 
    conv1 = conv2d_block(conv, 32, 7)
    conv2 = conv2d_block(conv, 32, 5)
    conv3 = conv2d_block(conv, 32, 3) 
    conv4 = conv2d_block(conv, 32, 1)
    conv = Concatenate()([conv1,conv2,conv3,conv4])   
    conv = BatchNormalization()(conv) 
    conv1 = conv2d_block(conv, 16, 7)
    conv2 = conv2d_block(conv, 16, 5)
    conv3 = conv2d_block(conv, 16, 3)   
    conv4 = conv2d_block(conv, 16, 1)       
    conv = Concatenate()([conv1,conv2,conv3,conv4]) 
    conv = BatchNormalization()(conv) 
    outputs = Flatten()(conv) 
    for _ in range(3): 
        outputs = Dense(1024, activation = 'relu')(outputs) 
        outputs = BatchNormalization()(outputs)  
    outputs = Dropout(0.25)(outputs) 
    outputs = Dense(10, activation = 'softmax')(outputs)
    model = Model(inputs = [inputs, letter_input], outputs = outputs)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model

# %%
# implement k-fold cv 
def k_fold(k,files):  
    folds = [] 
    fold_size = len(files) // k 
    for i in range(k): 
        if i == k-1:  
            l = files[i*fold_size:] 
        else: 
            l = files[i*fold_size:(i+1)*fold_size]  
        folds.append(l)   
    return folds  

# uncomment below to shuffle before splitting data into folds 
x_train, y_train, train_letters_numeric = shuffle(x_train, y_train, train_letters_numeric)
# split data into 5 folds 
k = 10 
x_train_folds = k_fold(k, x_train)
y_train_folds = k_fold(k, y_train) 
letter_train_folds = k_fold(k,train_letters_numeric)

for t in range(k):  
    print("************ Fold {} training ************".format(t+1)) 
    cur_val_x = x_train_folds[t] 
    cur_val_y = y_train_folds[t] 
    cur_val_letter = letter_train_folds[t]
    train_folds_x = x_train_folds[0:t] + x_train_folds[t+1:] 
    train_folds_y = y_train_folds[0:t] + y_train_folds[t+1:]
    train_fold_letter = letter_train_folds[0:t] + letter_train_folds[t+1:]
    cur_train_x = [] 
    cur_train_y = [] 
    cur_letter = [] 
    for j in train_folds_x:  
        for q in j:  
            cur_train_x.append(q) 
    for j in train_folds_y:  
        for q in j:  
            cur_train_y.append(q)  
    for j in train_fold_letter: 
        for q in j: 
            cur_letter.append(q) 
    cur_train_x = np.asarray(cur_train_x)
    cur_train_y = np.asarray(cur_train_y)
    cur_letter = np.asarray(cur_letter) 
    model_path = './storage/mnist_test_4/' + 'kfold' + str(t+1) + '/epoch_{epoch:03d}_val_{val_loss:.3f}_acc_{val_accuracy:.3f}.h5' 
    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.8)
    checkpoint = ModelCheckpoint(filepath=model_path,monitor='val_accuracy',verbose=1,save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_accuracy',patience=25)
    annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x) # possible alternative to ReduceLROnPlateau
    model = base_cnn_grade_5() 
    
    history = model.fit([cur_train_x,cur_letter],
                        cur_train_y,
                       batch_size = 32,
                       shuffle = True, 
                       validation_data = ([cur_val_x,cur_val_letter],cur_val_y),
                       verbose = 1, 
                       epochs = 300,
                       callbacks = [learning_rate_reduction, checkpoint, early_stopping])
# Out:
# ************ Fold 1 training ************
# Train on 16589 samples, validate on 1843 samples
# Epoch 1/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 2.0342 - accuracy: 0.3694
# Epoch 00001: val_accuracy improved from -inf to 0.46446, saving model to ./storage/mnist_test_4/kfold1/epoch_001_val_1.627_acc_0.464.h5
# 16589/16589 [==============================] - 24s 1ms/sample - loss: 2.0337 - accuracy: 0.3695 - val_loss: 1.6272 - val_accuracy: 0.4645
# Epoch 2/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 1.2002 - accuracy: 0.6095
# Epoch 00002: val_accuracy improved from 0.46446 to 0.62832, saving model to ./storage/mnist_test_4/kfold1/epoch_002_val_1.337_acc_0.628.h5
# 16589/16589 [==============================] - 15s 934us/sample - loss: 1.2009 - accuracy: 0.6094 - val_loss: 1.3375 - val_accuracy: 0.6283
# Epoch 3/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.8743 - accuracy: 0.7136
# Epoch 00003: val_accuracy improved from 0.62832 to 0.70537, saving model to ./storage/mnist_test_4/kfold1/epoch_003_val_0.937_acc_0.705.h5
# 16589/16589 [==============================] - 15s 927us/sample - loss: 0.8733 - accuracy: 0.7139 - val_loss: 0.9370 - val_accuracy: 0.7054
# Epoch 4/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.6593 - accuracy: 0.7808
# Epoch 00004: val_accuracy improved from 0.70537 to 0.75909, saving model to ./storage/mnist_test_4/kfold1/epoch_004_val_0.733_acc_0.759.h5
# 16589/16589 [==============================] - 15s 929us/sample - loss: 0.6597 - accuracy: 0.7806 - val_loss: 0.7332 - val_accuracy: 0.7591
# Epoch 5/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.5267 - accuracy: 0.8247
# Epoch 00005: val_accuracy improved from 0.75909 to 0.79381, saving model to ./storage/mnist_test_4/kfold1/epoch_005_val_0.690_acc_0.794.h5
# 16589/16589 [==============================] - 15s 932us/sample - loss: 0.5272 - accuracy: 0.8246 - val_loss: 0.6903 - val_accuracy: 0.7938
# Epoch 6/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.4446 - accuracy: 0.8485
# Epoch 00006: val_accuracy did not improve from 0.79381
# 16589/16589 [==============================] - 15s 897us/sample - loss: 0.4445 - accuracy: 0.8486 - val_loss: 0.6765 - val_accuracy: 0.7906
# Epoch 7/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.3395 - accuracy: 0.8852
# Epoch 00007: val_accuracy improved from 0.79381 to 0.81063, saving model to ./storage/mnist_test_4/kfold1/epoch_007_val_0.600_acc_0.811.h5
# 16589/16589 [==============================] - 15s 929us/sample - loss: 0.3401 - accuracy: 0.8849 - val_loss: 0.5995 - val_accuracy: 0.8106
# Epoch 8/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.2950 - accuracy: 0.9009
# Epoch 00008: val_accuracy improved from 0.81063 to 0.82583, saving model to ./storage/mnist_test_4/kfold1/epoch_008_val_0.592_acc_0.826.h5
# 16589/16589 [==============================] - 16s 938us/sample - loss: 0.2955 - accuracy: 0.9007 - val_loss: 0.5921 - val_accuracy: 0.8258
# Epoch 9/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.2472 - accuracy: 0.9180
# Epoch 00009: val_accuracy did not improve from 0.82583
# 16589/16589 [==============================] - 15s 904us/sample - loss: 0.2471 - accuracy: 0.9181 - val_loss: 0.6636 - val_accuracy: 0.8182
# Epoch 10/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.2294 - accuracy: 0.9235
# Epoch 00010: val_accuracy improved from 0.82583 to 0.82908, saving model to ./storage/mnist_test_4/kfold1/epoch_010_val_0.607_acc_0.829.h5
# 16589/16589 [==============================] - 15s 925us/sample - loss: 0.2300 - accuracy: 0.9234 - val_loss: 0.6070 - val_accuracy: 0.8291
# Epoch 11/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1909 - accuracy: 0.9365
# Epoch 00011: val_accuracy improved from 0.82908 to 0.82963, saving model to ./storage/mnist_test_4/kfold1/epoch_011_val_0.653_acc_0.830.h5
# 16589/16589 [==============================] - 16s 938us/sample - loss: 0.1918 - accuracy: 0.9365 - val_loss: 0.6531 - val_accuracy: 0.8296
# Epoch 12/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1690 - accuracy: 0.9466
# Epoch 00012: val_accuracy improved from 0.82963 to 0.83831, saving model to ./storage/mnist_test_4/kfold1/epoch_012_val_0.600_acc_0.838.h5
# 16589/16589 [==============================] - 15s 927us/sample - loss: 0.1687 - accuracy: 0.9467 - val_loss: 0.6000 - val_accuracy: 0.8383
# Epoch 13/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1512 - accuracy: 0.9484
# Epoch 00013: val_accuracy improved from 0.83831 to 0.84590, saving model to ./storage/mnist_test_4/kfold1/epoch_013_val_0.576_acc_0.846.h5
# 16589/16589 [==============================] - 16s 936us/sample - loss: 0.1511 - accuracy: 0.9483 - val_loss: 0.5759 - val_accuracy: 0.8459
# Epoch 14/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1480 - accuracy: 0.9495
# Epoch 00014: val_accuracy did not improve from 0.84590
# 16589/16589 [==============================] - 15s 898us/sample - loss: 0.1477 - accuracy: 0.9496 - val_loss: 0.6765 - val_accuracy: 0.8318
# Epoch 15/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1264 - accuracy: 0.9589
# Epoch 00015: val_accuracy did not improve from 0.84590
# 16589/16589 [==============================] - 15s 893us/sample - loss: 0.1263 - accuracy: 0.9589 - val_loss: 0.6539 - val_accuracy: 0.8454
# Epoch 16/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.1089 - accuracy: 0.9650
# Epoch 00016: val_accuracy improved from 0.84590 to 0.85513, saving model to ./storage/mnist_test_4/kfold1/epoch_016_val_0.615_acc_0.855.h5
# 16589/16589 [==============================] - 16s 936us/sample - loss: 0.1089 - accuracy: 0.9650 - val_loss: 0.6152 - val_accuracy: 0.8551
# Epoch 17/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9653
# Epoch 00017: val_accuracy improved from 0.85513 to 0.85947, saving model to ./storage/mnist_test_4/kfold1/epoch_017_val_0.636_acc_0.859.h5
# 16589/16589 [==============================] - 15s 930us/sample - loss: 0.1032 - accuracy: 0.9653 - val_loss: 0.6362 - val_accuracy: 0.8595
# Epoch 18/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1050 - accuracy: 0.9645
# Epoch 00018: val_accuracy did not improve from 0.85947
# 16589/16589 [==============================] - 15s 899us/sample - loss: 0.1049 - accuracy: 0.9646 - val_loss: 0.6351 - val_accuracy: 0.8573
# Epoch 19/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0969 - accuracy: 0.9687
# Epoch 00019: val_accuracy did not improve from 0.85947
# 16589/16589 [==============================] - 15s 901us/sample - loss: 0.0969 - accuracy: 0.9687 - val_loss: 0.6777 - val_accuracy: 0.8405
# Epoch 20/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0947 - accuracy: 0.9674
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
#
# Epoch 00020: val_accuracy did not improve from 0.85947
# 16589/16589 [==============================] - 15s 903us/sample - loss: 0.0956 - accuracy: 0.9674 - val_loss: 0.8233 - val_accuracy: 0.8237
# Epoch 21/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0619 - accuracy: 0.9789
# Epoch 00021: val_accuracy improved from 0.85947 to 0.86435, saving model to ./storage/mnist_test_4/kfold1/epoch_021_val_0.611_acc_0.864.h5
# 16589/16589 [==============================] - 15s 933us/sample - loss: 0.0621 - accuracy: 0.9788 - val_loss: 0.6114 - val_accuracy: 0.8644
# Epoch 22/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9852
# Epoch 00022: val_accuracy improved from 0.86435 to 0.86652, saving model to ./storage/mnist_test_4/kfold1/epoch_022_val_0.626_acc_0.867.h5
# 16589/16589 [==============================] - 15s 930us/sample - loss: 0.0454 - accuracy: 0.9852 - val_loss: 0.6257 - val_accuracy: 0.8665
# Epoch 23/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0527 - accuracy: 0.9824
# Epoch 00023: val_accuracy did not improve from 0.86652
# 16589/16589 [==============================] - 15s 896us/sample - loss: 0.0527 - accuracy: 0.9825 - val_loss: 0.6945 - val_accuracy: 0.8562
# Epoch 24/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0576 - accuracy: 0.9809
# Epoch 00024: val_accuracy did not improve from 0.86652
# 16589/16589 [==============================] - 15s 898us/sample - loss: 0.0579 - accuracy: 0.9808 - val_loss: 0.6813 - val_accuracy: 0.8611
# Epoch 25/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0562 - accuracy: 0.9819
# Epoch 00025: val_accuracy improved from 0.86652 to 0.87032, saving model to ./storage/mnist_test_4/kfold1/epoch_025_val_0.623_acc_0.870.h5
# 16589/16589 [==============================] - 15s 933us/sample - loss: 0.0571 - accuracy: 0.9817 - val_loss: 0.6231 - val_accuracy: 0.8703
# Epoch 26/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0514 - accuracy: 0.9837
# Epoch 00026: val_accuracy improved from 0.87032 to 0.87737, saving model to ./storage/mnist_test_4/kfold1/epoch_026_val_0.621_acc_0.877.h5
# 16589/16589 [==============================] - 15s 932us/sample - loss: 0.0517 - accuracy: 0.9836 - val_loss: 0.6207 - val_accuracy: 0.8774
# Epoch 27/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0473 - accuracy: 0.9833
# Epoch 00027: val_accuracy did not improve from 0.87737
# 16589/16589 [==============================] - 15s 895us/sample - loss: 0.0473 - accuracy: 0.9832 - val_loss: 0.6616 - val_accuracy: 0.8654
# Epoch 28/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9841
# Epoch 00028: val_accuracy did not improve from 0.87737
# 16589/16589 [==============================] - 15s 893us/sample - loss: 0.0470 - accuracy: 0.9841 - val_loss: 0.5620 - val_accuracy: 0.8768
# Epoch 29/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0484 - accuracy: 0.9842
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 00029: val_accuracy did not improve from 0.87737
# 16589/16589 [==============================] - 15s 901us/sample - loss: 0.0488 - accuracy: 0.9842 - val_loss: 0.6108 - val_accuracy: 0.8692
# Epoch 30/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0297 - accuracy: 0.9904
# Epoch 00030: val_accuracy improved from 0.87737 to 0.88117, saving model to ./storage/mnist_test_4/kfold1/epoch_030_val_0.543_acc_0.881.h5
# 16589/16589 [==============================] - 16s 943us/sample - loss: 0.0298 - accuracy: 0.9903 - val_loss: 0.5428 - val_accuracy: 0.8812
# Epoch 31/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9929
# Epoch 00031: val_accuracy improved from 0.88117 to 0.88768, saving model to ./storage/mnist_test_4/kfold1/epoch_031_val_0.561_acc_0.888.h5
# 16589/16589 [==============================] - 15s 932us/sample - loss: 0.0206 - accuracy: 0.9929 - val_loss: 0.5608 - val_accuracy: 0.8877
# Epoch 32/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9906
# Epoch 00032: val_accuracy did not improve from 0.88768
# 16589/16589 [==============================] - 15s 897us/sample - loss: 0.0307 - accuracy: 0.9905 - val_loss: 0.7390 - val_accuracy: 0.8595
# Epoch 33/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9906
# Epoch 00033: val_accuracy did not improve from 0.88768
# 16589/16589 [==============================] - 15s 898us/sample - loss: 0.0281 - accuracy: 0.9905 - val_loss: 0.6144 - val_accuracy: 0.8817
# Epoch 34/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0328 - accuracy: 0.9892
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 00034: val_accuracy did not improve from 0.88768
# 16589/16589 [==============================] - 15s 899us/sample - loss: 0.0327 - accuracy: 0.9893 - val_loss: 0.6132 - val_accuracy: 0.8774
# Epoch 35/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0200 - accuracy: 0.9937
# Epoch 00035: val_accuracy did not improve from 0.88768
# 16589/16589 [==============================] - 15s 895us/sample - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.5922 - val_accuracy: 0.8855
# Epoch 36/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0138 - accuracy: 0.9950
# Epoch 00036: val_accuracy did not improve from 0.88768
# 16589/16589 [==============================] - 15s 901us/sample - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.6698 - val_accuracy: 0.8714
# Epoch 37/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9943
# Epoch 00037: val_accuracy improved from 0.88768 to 0.89908, saving model to ./storage/mnist_test_4/kfold1/epoch_037_val_0.555_acc_0.899.h5
# 16589/16589 [==============================] - 15s 932us/sample - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.5553 - val_accuracy: 0.8991
# Epoch 38/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9957
# Epoch 00038: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 897us/sample - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.6405 - val_accuracy: 0.8795
# Epoch 39/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9909
# Epoch 00039: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 898us/sample - loss: 0.0296 - accuracy: 0.9909 - val_loss: 0.6479 - val_accuracy: 0.8665
# Epoch 40/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9964
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 00040: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 898us/sample - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.5948 - val_accuracy: 0.8877
# Epoch 41/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9978
# Epoch 00041: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 902us/sample - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.5731 - val_accuracy: 0.8947
# Epoch 42/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9969
# Epoch 00042: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 893us/sample - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.6446 - val_accuracy: 0.8774
# Epoch 43/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9955
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 00043: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 895us/sample - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.6167 - val_accuracy: 0.8888
# Epoch 44/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 0.9973
# Epoch 00044: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 896us/sample - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.6095 - val_accuracy: 0.8833
# Epoch 45/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9979
# Epoch 00045: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 901us/sample - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.5948 - val_accuracy: 0.8833
# Epoch 46/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9982
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 00046: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 895us/sample - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.5786 - val_accuracy: 0.8877
# Epoch 47/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9978
# Epoch 00047: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 897us/sample - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.5684 - val_accuracy: 0.8942
# Epoch 48/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.9984
# Epoch 00048: val_accuracy did not improve from 0.89908
# 16589/16589 [==============================] - 15s 896us/sample - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.6283 - val_accuracy: 0.8947
# Epoch 49/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9986
# Epoch 00049: val_accuracy improved from 0.89908 to 0.90071, saving model to ./storage/mnist_test_4/kfold1/epoch_049_val_0.589_acc_0.901.h5
# 16589/16589 [==============================] - 16s 936us/sample - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.5894 - val_accuracy: 0.9007
# Epoch 50/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9987
# Epoch 00050: val_accuracy improved from 0.90071 to 0.90179, saving model to ./storage/mnist_test_4/kfold1/epoch_050_val_0.602_acc_0.902.h5
# 16589/16589 [==============================] - 16s 949us/sample - loss: 0.0033 - accuracy: 0.9987 - val_loss: 0.6024 - val_accuracy: 0.9018
# Epoch 51/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9985
# Epoch 00051: val_accuracy did not improve from 0.90179
# 16589/16589 [==============================] - 15s 913us/sample - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.6158 - val_accuracy: 0.8931
# Epoch 52/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9989
# Epoch 00052: val_accuracy did not improve from 0.90179
# 16589/16589 [==============================] - 15s 925us/sample - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.6164 - val_accuracy: 0.8920
# Epoch 53/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9989
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 00053: val_accuracy did not improve from 0.90179
# 16589/16589 [==============================] - 15s 915us/sample - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.5973 - val_accuracy: 0.8958
# Epoch 54/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9989
# Epoch 00054: val_accuracy did not improve from 0.90179
# 16589/16589 [==============================] - 15s 910us/sample - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.6229 - val_accuracy: 0.8969
# Epoch 55/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9983
# Epoch 00055: val_accuracy did not improve from 0.90179
# 16589/16589 [==============================] - 15s 912us/sample - loss: 0.0044 - accuracy: 0.9983 - val_loss: 0.5954 - val_accuracy: 0.9002
# Epoch 56/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9987
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# Epoch 00056: val_accuracy did not improve from 0.90179
# 16589/16589 [==============================] - 15s 918us/sample - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.6107 - val_accuracy: 0.8920
# Epoch 57/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9989
# Epoch 00057: val_accuracy did not improve from 0.90179
# 16589/16589 [==============================] - 15s 919us/sample - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.6272 - val_accuracy: 0.8937
# Epoch 58/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 00058: val_accuracy did not improve from 0.90179
# 16589/16589 [==============================] - 15s 913us/sample - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.5972 - val_accuracy: 0.8974
# Epoch 59/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9995
# Epoch 00059: val_accuracy improved from 0.90179 to 0.90667, saving model to ./storage/mnist_test_4/kfold1/epoch_059_val_0.574_acc_0.907.h5
# 16589/16589 [==============================] - 16s 948us/sample - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.5739 - val_accuracy: 0.9067
# Epoch 60/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9992
# Epoch 00060: val_accuracy did not improve from 0.90667
# 16589/16589 [==============================] - 15s 926us/sample - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.5727 - val_accuracy: 0.9050
# Epoch 61/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9997
# Epoch 00061: val_accuracy did not improve from 0.90667
# 16589/16589 [==============================] - 15s 917us/sample - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.5540 - val_accuracy: 0.9067
# Epoch 62/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 6.7879e-04 - accuracy: 0.9998
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
#
# Epoch 00062: val_accuracy did not improve from 0.90667
# 16589/16589 [==============================] - 15s 923us/sample - loss: 6.7825e-04 - accuracy: 0.9998 - val_loss: 0.5749 - val_accuracy: 0.9023
# Epoch 63/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 00063: val_accuracy did not improve from 0.90667
# 16589/16589 [==============================] - 15s 917us/sample - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.5623 - val_accuracy: 0.9056
# Epoch 64/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00064: val_accuracy did not improve from 0.90667
# 16589/16589 [==============================] - 15s 912us/sample - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.5814 - val_accuracy: 0.9050
# Epoch 65/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
#
# Epoch 00065: val_accuracy did not improve from 0.90667
# 16589/16589 [==============================] - 15s 926us/sample - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.5550 - val_accuracy: 0.9061
# Epoch 66/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 4.5238e-04 - accuracy: 0.9999
# Epoch 00066: val_accuracy improved from 0.90667 to 0.90993, saving model to ./storage/mnist_test_4/kfold1/epoch_066_val_0.546_acc_0.910.h5
# 16589/16589 [==============================] - 16s 948us/sample - loss: 4.5197e-04 - accuracy: 0.9999 - val_loss: 0.5460 - val_accuracy: 0.9099
# Epoch 67/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 5.2765e-04 - accuracy: 0.9999
# Epoch 00067: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 919us/sample - loss: 5.2628e-04 - accuracy: 0.9999 - val_loss: 0.5698 - val_accuracy: 0.9094
# Epoch 68/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9993
# Epoch 00068: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 911us/sample - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.5756 - val_accuracy: 0.9023
# Epoch 69/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9995
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
#
# Epoch 00069: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 897us/sample - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.5726 - val_accuracy: 0.8980
# Epoch 70/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 6.1887e-04 - accuracy: 0.9999
# Epoch 00070: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 893us/sample - loss: 6.1727e-04 - accuracy: 0.9999 - val_loss: 0.5681 - val_accuracy: 0.9018
# Epoch 71/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 4.5083e-04 - accuracy: 0.9999
# Epoch 00071: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 899us/sample - loss: 4.7066e-04 - accuracy: 0.9999 - val_loss: 0.5659 - val_accuracy: 0.9050
# Epoch 72/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 5.3582e-04 - accuracy: 0.9998
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 00072: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 901us/sample - loss: 5.3535e-04 - accuracy: 0.9998 - val_loss: 0.5718 - val_accuracy: 0.9002
# Epoch 73/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 6.9768e-04 - accuracy: 0.9997
# Epoch 00073: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 897us/sample - loss: 6.9598e-04 - accuracy: 0.9997 - val_loss: 0.5666 - val_accuracy: 0.8996
# Epoch 74/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 3.8431e-04 - accuracy: 0.9999
# Epoch 00074: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 896us/sample - loss: 9.8999e-04 - accuracy: 0.9998 - val_loss: 0.5643 - val_accuracy: 0.9018
# Epoch 75/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 5.4261e-04 - accuracy: 0.9998
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
#
# Epoch 00075: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 893us/sample - loss: 5.4192e-04 - accuracy: 0.9998 - val_loss: 0.5639 - val_accuracy: 0.9045
# Epoch 76/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 5.6938e-04 - accuracy: 0.9998
# Epoch 00076: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 896us/sample - loss: 5.6785e-04 - accuracy: 0.9998 - val_loss: 0.5702 - val_accuracy: 0.9056
# Epoch 77/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 4.7580e-04 - accuracy: 0.9998
# Epoch 00077: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 900us/sample - loss: 4.7456e-04 - accuracy: 0.9998 - val_loss: 0.5730 - val_accuracy: 0.9061
# Epoch 78/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 1.5155e-04 - accuracy: 1.0000
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
#
# Epoch 00078: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 898us/sample - loss: 1.5122e-04 - accuracy: 1.0000 - val_loss: 0.5779 - val_accuracy: 0.9067
# Epoch 79/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 3.6407e-04 - accuracy: 0.9999
# Epoch 00079: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 893us/sample - loss: 3.6358e-04 - accuracy: 0.9999 - val_loss: 0.5735 - val_accuracy: 0.9061
# Epoch 80/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 2.7471e-04 - accuracy: 0.9999
# Epoch 00080: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 904us/sample - loss: 2.7514e-04 - accuracy: 0.9999 - val_loss: 0.5770 - val_accuracy: 0.9045
# Epoch 81/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 3.5465e-04 - accuracy: 0.9999
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
#
# Epoch 00081: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 899us/sample - loss: 3.5389e-04 - accuracy: 0.9999 - val_loss: 0.5745 - val_accuracy: 0.9056
# Epoch 82/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 4.8108e-04 - accuracy: 0.9998
# Epoch 00082: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 897us/sample - loss: 4.7979e-04 - accuracy: 0.9998 - val_loss: 0.5715 - val_accuracy: 0.9067
# Epoch 83/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 3.1293e-04 - accuracy: 0.9999
# Epoch 00083: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 899us/sample - loss: 3.1223e-04 - accuracy: 0.9999 - val_loss: 0.5798 - val_accuracy: 0.9099
# Epoch 84/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 2.5373e-04 - accuracy: 0.9999
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
#
# Epoch 00084: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 900us/sample - loss: 2.5307e-04 - accuracy: 0.9999 - val_loss: 0.5706 - val_accuracy: 0.9078
# Epoch 85/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 2.4851e-04 - accuracy: 0.9999
# Epoch 00085: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 900us/sample - loss: 2.4831e-04 - accuracy: 0.9999 - val_loss: 0.5688 - val_accuracy: 0.9078
# Epoch 86/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 1.9371e-04 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 896us/sample - loss: 1.9323e-04 - accuracy: 1.0000 - val_loss: 0.5763 - val_accuracy: 0.9056
# Epoch 87/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 2.1066e-04 - accuracy: 1.0000
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
#
# Epoch 00087: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 895us/sample - loss: 2.3128e-04 - accuracy: 1.0000 - val_loss: 0.5748 - val_accuracy: 0.9050
# Epoch 88/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 1.8751e-04 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 901us/sample - loss: 1.8701e-04 - accuracy: 1.0000 - val_loss: 0.5809 - val_accuracy: 0.9072
# Epoch 89/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 1.9941e-04 - accuracy: 0.9999
# Epoch 00089: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 885us/sample - loss: 2.0051e-04 - accuracy: 0.9999 - val_loss: 0.5781 - val_accuracy: 0.9067
# Epoch 90/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 2.0574e-04 - accuracy: 0.9999
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
#
# Epoch 00090: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 897us/sample - loss: 2.0523e-04 - accuracy: 0.9999 - val_loss: 0.5810 - val_accuracy: 0.9045
# Epoch 91/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 1.2768e-04 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.90993
# 16589/16589 [==============================] - 15s 901us/sample - loss: 1.2743e-04 - accuracy: 1.0000 - val_loss: 0.5790 - val_accuracy: 0.9040
# ************ Fold 2 training ************
# Train on 16589 samples, validate on 1843 samples
# Epoch 1/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 2.0467 - accuracy: 0.3686
# Epoch 00001: val_accuracy improved from -inf to 0.49973, saving model to ./storage/mnist_test_4/kfold2/epoch_001_val_1.531_acc_0.500.h5
# 16589/16589 [==============================] - 22s 1ms/sample - loss: 2.0447 - accuracy: 0.3692 - val_loss: 1.5314 - val_accuracy: 0.4997
# Epoch 2/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 1.2048 - accuracy: 0.6081
# Epoch 00002: val_accuracy improved from 0.49973 to 0.62887, saving model to ./storage/mnist_test_4/kfold2/epoch_002_val_1.104_acc_0.629.h5
# 16589/16589 [==============================] - 15s 924us/sample - loss: 1.2051 - accuracy: 0.6081 - val_loss: 1.1039 - val_accuracy: 0.6289
# Epoch 3/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.8932 - accuracy: 0.7121
# Epoch 00003: val_accuracy improved from 0.62887 to 0.71514, saving model to ./storage/mnist_test_4/kfold2/epoch_003_val_0.850_acc_0.715.h5
# 16589/16589 [==============================] - 15s 926us/sample - loss: 0.8929 - accuracy: 0.7122 - val_loss: 0.8505 - val_accuracy: 0.7151
# Epoch 4/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.6966 - accuracy: 0.7704
# Epoch 00004: val_accuracy improved from 0.71514 to 0.77428, saving model to ./storage/mnist_test_4/kfold2/epoch_004_val_0.692_acc_0.774.h5
# 16589/16589 [==============================] - 15s 920us/sample - loss: 0.6965 - accuracy: 0.7705 - val_loss: 0.6917 - val_accuracy: 0.7743
# Epoch 5/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.5472 - accuracy: 0.8169
# Epoch 00005: val_accuracy improved from 0.77428 to 0.79761, saving model to ./storage/mnist_test_4/kfold2/epoch_005_val_0.597_acc_0.798.h5
# 16589/16589 [==============================] - 15s 917us/sample - loss: 0.5480 - accuracy: 0.8169 - val_loss: 0.5971 - val_accuracy: 0.7976
# Epoch 6/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.4252 - accuracy: 0.8561
# Epoch 00006: val_accuracy did not improve from 0.79761
# 16589/16589 [==============================] - 15s 898us/sample - loss: 0.4256 - accuracy: 0.8559 - val_loss: 0.6243 - val_accuracy: 0.7960
# Epoch 7/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.3654 - accuracy: 0.8767
# Epoch 00007: val_accuracy improved from 0.79761 to 0.80467, saving model to ./storage/mnist_test_4/kfold2/epoch_007_val_0.590_acc_0.805.h5
# 16589/16589 [==============================] - 15s 919us/sample - loss: 0.3658 - accuracy: 0.8767 - val_loss: 0.5897 - val_accuracy: 0.8047
# Epoch 8/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.3021 - accuracy: 0.8988
# Epoch 00008: val_accuracy improved from 0.80467 to 0.81226, saving model to ./storage/mnist_test_4/kfold2/epoch_008_val_0.627_acc_0.812.h5
# 16589/16589 [==============================] - 15s 927us/sample - loss: 0.3023 - accuracy: 0.8986 - val_loss: 0.6266 - val_accuracy: 0.8123
# Epoch 9/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.2531 - accuracy: 0.9152
# Epoch 00009: val_accuracy improved from 0.81226 to 0.84048, saving model to ./storage/mnist_test_4/kfold2/epoch_009_val_0.540_acc_0.840.h5
# 16589/16589 [==============================] - 15s 924us/sample - loss: 0.2530 - accuracy: 0.9153 - val_loss: 0.5403 - val_accuracy: 0.8405
# Epoch 10/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.2181 - accuracy: 0.9255
# Epoch 00010: val_accuracy did not improve from 0.84048
# 16589/16589 [==============================] - 15s 892us/sample - loss: 0.2181 - accuracy: 0.9255 - val_loss: 0.6417 - val_accuracy: 0.8323
# Epoch 11/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1929 - accuracy: 0.9352
# Epoch 00011: val_accuracy improved from 0.84048 to 0.84699, saving model to ./storage/mnist_test_4/kfold2/epoch_011_val_0.564_acc_0.847.h5
# 16589/16589 [==============================] - 15s 924us/sample - loss: 0.1935 - accuracy: 0.9351 - val_loss: 0.5636 - val_accuracy: 0.8470
# Epoch 12/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.1656 - accuracy: 0.9423
# Epoch 00012: val_accuracy did not improve from 0.84699
# 16589/16589 [==============================] - 15s 879us/sample - loss: 0.1655 - accuracy: 0.9423 - val_loss: 0.5687 - val_accuracy: 0.8470
# Epoch 13/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1401 - accuracy: 0.9535
# Epoch 00013: val_accuracy did not improve from 0.84699
# 16589/16589 [==============================] - 15s 892us/sample - loss: 0.1404 - accuracy: 0.9535 - val_loss: 0.6328 - val_accuracy: 0.8416
# Epoch 14/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1558 - accuracy: 0.9469
# Epoch 00014: val_accuracy improved from 0.84699 to 0.84753, saving model to ./storage/mnist_test_4/kfold2/epoch_014_val_0.566_acc_0.848.h5
# 16589/16589 [==============================] - 15s 934us/sample - loss: 0.1562 - accuracy: 0.9469 - val_loss: 0.5663 - val_accuracy: 0.8475
# Epoch 15/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.1343 - accuracy: 0.9537
# Epoch 00015: val_accuracy improved from 0.84753 to 0.85296, saving model to ./storage/mnist_test_4/kfold2/epoch_015_val_0.619_acc_0.853.h5
# 16589/16589 [==============================] - 15s 923us/sample - loss: 0.1344 - accuracy: 0.9536 - val_loss: 0.6186 - val_accuracy: 0.8530
# Epoch 16/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.1152 - accuracy: 0.9619
# Epoch 00016: val_accuracy did not improve from 0.85296
# 16589/16589 [==============================] - 15s 891us/sample - loss: 0.1154 - accuracy: 0.9618 - val_loss: 0.6438 - val_accuracy: 0.8454
# Epoch 17/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0944 - accuracy: 0.9691
# Epoch 00017: val_accuracy improved from 0.85296 to 0.85947, saving model to ./storage/mnist_test_4/kfold2/epoch_017_val_0.584_acc_0.859.h5
# 16589/16589 [==============================] - 15s 931us/sample - loss: 0.0944 - accuracy: 0.9691 - val_loss: 0.5836 - val_accuracy: 0.8595
# Epoch 18/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.1240 - accuracy: 0.9598
# Epoch 00018: val_accuracy did not improve from 0.85947
# 16589/16589 [==============================] - 15s 890us/sample - loss: 0.1240 - accuracy: 0.9598 - val_loss: 0.6011 - val_accuracy: 0.8551
# Epoch 19/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9684
# Epoch 00019: val_accuracy improved from 0.85947 to 0.86110, saving model to ./storage/mnist_test_4/kfold2/epoch_019_val_0.600_acc_0.861.h5
# 16589/16589 [==============================] - 15s 917us/sample - loss: 0.0967 - accuracy: 0.9683 - val_loss: 0.5999 - val_accuracy: 0.8611
# Epoch 20/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0779 - accuracy: 0.9732
# Epoch 00020: val_accuracy did not improve from 0.86110
# 16589/16589 [==============================] - 15s 886us/sample - loss: 0.0781 - accuracy: 0.9731 - val_loss: 0.7590 - val_accuracy: 0.8421
# Epoch 21/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.1012 - accuracy: 0.9670
# Epoch 00021: val_accuracy did not improve from 0.86110
# 16589/16589 [==============================] - 15s 886us/sample - loss: 0.1015 - accuracy: 0.9668 - val_loss: 0.6743 - val_accuracy: 0.8519
# Epoch 22/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0804 - accuracy: 0.9746
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
#
# Epoch 00022: val_accuracy did not improve from 0.86110
# 16589/16589 [==============================] - 15s 884us/sample - loss: 0.0803 - accuracy: 0.9746 - val_loss: 0.6358 - val_accuracy: 0.8568
# Epoch 23/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0480 - accuracy: 0.9837
# Epoch 00023: val_accuracy improved from 0.86110 to 0.87954, saving model to ./storage/mnist_test_4/kfold2/epoch_023_val_0.517_acc_0.880.h5
# 16589/16589 [==============================] - 15s 929us/sample - loss: 0.0484 - accuracy: 0.9837 - val_loss: 0.5172 - val_accuracy: 0.8795
# Epoch 24/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9898
# Epoch 00024: val_accuracy did not improve from 0.87954
# 16589/16589 [==============================] - 15s 882us/sample - loss: 0.0317 - accuracy: 0.9898 - val_loss: 0.5658 - val_accuracy: 0.8730
# Epoch 25/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0558 - accuracy: 0.9826
# Epoch 00025: val_accuracy did not improve from 0.87954
# 16589/16589 [==============================] - 15s 889us/sample - loss: 0.0557 - accuracy: 0.9826 - val_loss: 0.6493 - val_accuracy: 0.8584
# Epoch 26/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0574 - accuracy: 0.9815
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 00026: val_accuracy did not improve from 0.87954
# 16589/16589 [==============================] - 15s 885us/sample - loss: 0.0574 - accuracy: 0.9815 - val_loss: 0.6151 - val_accuracy: 0.8622
# Epoch 27/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0301 - accuracy: 0.9901
# Epoch 00027: val_accuracy improved from 0.87954 to 0.88606, saving model to ./storage/mnist_test_4/kfold2/epoch_027_val_0.544_acc_0.886.h5
# 16589/16589 [==============================] - 15s 929us/sample - loss: 0.0301 - accuracy: 0.9901 - val_loss: 0.5444 - val_accuracy: 0.8861
# Epoch 28/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0270 - accuracy: 0.9912
# Epoch 00028: val_accuracy did not improve from 0.88606
# 16589/16589 [==============================] - 15s 891us/sample - loss: 0.0271 - accuracy: 0.9911 - val_loss: 0.5823 - val_accuracy: 0.8839
# Epoch 29/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 0.9914
# Epoch 00029: val_accuracy did not improve from 0.88606
# 16589/16589 [==============================] - 15s 891us/sample - loss: 0.0247 - accuracy: 0.9914 - val_loss: 0.5817 - val_accuracy: 0.8806
# Epoch 30/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9900
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 00030: val_accuracy did not improve from 0.88606
# 16589/16589 [==============================] - 15s 887us/sample - loss: 0.0319 - accuracy: 0.9900 - val_loss: 0.6254 - val_accuracy: 0.8850
# Epoch 31/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 0.9930
# Epoch 00031: val_accuracy improved from 0.88606 to 0.89148, saving model to ./storage/mnist_test_4/kfold2/epoch_031_val_0.573_acc_0.891.h5
# 16589/16589 [==============================] - 15s 919us/sample - loss: 0.0219 - accuracy: 0.9930 - val_loss: 0.5729 - val_accuracy: 0.8915
# Epoch 32/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9935
# Epoch 00032: val_accuracy did not improve from 0.89148
# 16589/16589 [==============================] - 15s 900us/sample - loss: 0.0188 - accuracy: 0.9935 - val_loss: 0.6051 - val_accuracy: 0.8747
# Epoch 33/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9939
# Epoch 00033: val_accuracy did not improve from 0.89148
# 16589/16589 [==============================] - 15s 906us/sample - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.5505 - val_accuracy: 0.8877
# Epoch 34/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9943
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 00034: val_accuracy did not improve from 0.89148
# 16589/16589 [==============================] - 15s 912us/sample - loss: 0.0195 - accuracy: 0.9943 - val_loss: 0.6307 - val_accuracy: 0.8828
# Epoch 35/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9958
# Epoch 00035: val_accuracy did not improve from 0.89148
# 16589/16589 [==============================] - 15s 899us/sample - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.5817 - val_accuracy: 0.8866
# Epoch 36/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9977
# Epoch 00036: val_accuracy did not improve from 0.89148
# 16589/16589 [==============================] - 15s 905us/sample - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.6027 - val_accuracy: 0.8877
# Epoch 37/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0134 - accuracy: 0.9953
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 00037: val_accuracy did not improve from 0.89148
# 16589/16589 [==============================] - 15s 900us/sample - loss: 0.0136 - accuracy: 0.9952 - val_loss: 0.6526 - val_accuracy: 0.8757
# Epoch 38/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 0.9963
# Epoch 00038: val_accuracy did not improve from 0.89148
# 16589/16589 [==============================] - 15s 907us/sample - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.6382 - val_accuracy: 0.8801
# Epoch 39/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9973
# Epoch 00039: val_accuracy did not improve from 0.89148
# 16589/16589 [==============================] - 15s 909us/sample - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.6229 - val_accuracy: 0.8904
# Epoch 40/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9978
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 00040: val_accuracy did not improve from 0.89148
# 16589/16589 [==============================] - 15s 911us/sample - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.6399 - val_accuracy: 0.8839
# Epoch 41/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9974
# Epoch 00041: val_accuracy did not improve from 0.89148
# 16589/16589 [==============================] - 15s 911us/sample - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.6339 - val_accuracy: 0.8915
# Epoch 42/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9982
# Epoch 00042: val_accuracy improved from 0.89148 to 0.89691, saving model to ./storage/mnist_test_4/kfold2/epoch_042_val_0.619_acc_0.897.h5
# 16589/16589 [==============================] - 16s 937us/sample - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.6187 - val_accuracy: 0.8969
# Epoch 43/300
# 16512/16589 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9980
# Epoch 00043: val_accuracy did not improve from 0.89691
# 16589/16589 [==============================] - 15s 903us/sample - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.6006 - val_accuracy: 0.8920
# Epoch 44/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9987
# Epoch 00044: val_accuracy did not improve from 0.89691
# 16589/16589 [==============================] - 15s 902us/sample - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.6321 - val_accuracy: 0.8947
# Epoch 45/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9995
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 00045: val_accuracy did not improve from 0.89691
# 16589/16589 [==============================] - 15s 910us/sample - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.6100 - val_accuracy: 0.8964
# Epoch 46/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9990
# Epoch 00046: val_accuracy did not improve from 0.89691
# 16589/16589 [==============================] - 15s 913us/sample - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.6555 - val_accuracy: 0.8920
# Epoch 47/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9985
# Epoch 00047: val_accuracy did not improve from 0.89691
# 16589/16589 [==============================] - 15s 899us/sample - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.6471 - val_accuracy: 0.8958
# Epoch 48/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9987
# Epoch 00048: val_accuracy improved from 0.89691 to 0.89745, saving model to ./storage/mnist_test_4/kfold2/epoch_048_val_0.622_acc_0.897.h5
# 16589/16589 [==============================] - 16s 936us/sample - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.6222 - val_accuracy: 0.8974
# Epoch 49/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9986
# Epoch 00049: val_accuracy did not improve from 0.89745
# 16589/16589 [==============================] - 15s 907us/sample - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.5970 - val_accuracy: 0.8969
# Epoch 50/300
# 16576/16589 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 0.9983
# Epoch 00050: val_accuracy did not improve from 0.89745
# 16589/16589 [==============================] - 15s 904us/sample - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.6245 - val_accuracy: 0.8958
# Epoch 51/300
# 16544/16589 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9989
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# ...
# Epoch 58/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9992
# Epoch 00058: val_accuracy did not improve from 0.89322
# 16587/16587 [==============================] - 14s 859us/sample - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.6313 - val_accuracy: 0.8911
# Epoch 59/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995
# Epoch 00059: val_accuracy did not improve from 0.89322
# 16587/16587 [==============================] - 14s 860us/sample - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.6505 - val_accuracy: 0.8911
# Epoch 60/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00060: val_accuracy improved from 0.89322 to 0.89593, saving model to ./storage/mnist_test_4/kfold10/epoch_060_val_0.631_acc_0.896.h5
# 16587/16587 [==============================] - 15s 892us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.6313 - val_accuracy: 0.8959
# Epoch 61/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9992
# Epoch 00061: val_accuracy did not improve from 0.89593
# 16587/16587 [==============================] - 14s 860us/sample - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.6263 - val_accuracy: 0.8954
# Epoch 62/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9989
# Epoch 00062: val_accuracy did not improve from 0.89593
# 16587/16587 [==============================] - 14s 855us/sample - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.6328 - val_accuracy: 0.8878
# Epoch 63/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
#
# Epoch 00063: val_accuracy did not improve from 0.89593
# 16587/16587 [==============================] - 14s 864us/sample - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.6558 - val_accuracy: 0.8921
# Epoch 64/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 9.3758e-04 - accuracy: 0.9998
# Epoch 00064: val_accuracy did not improve from 0.89593
# 16587/16587 [==============================] - 14s 852us/sample - loss: 9.3734e-04 - accuracy: 0.9998 - val_loss: 0.6399 - val_accuracy: 0.8932
# Epoch 65/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9994
# Epoch 00065: val_accuracy did not improve from 0.89593
# 16587/16587 [==============================] - 14s 856us/sample - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.6650 - val_accuracy: 0.8878
# Epoch 66/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9995
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
#
# Epoch 00066: val_accuracy did not improve from 0.89593
# 16587/16587 [==============================] - 14s 853us/sample - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.6406 - val_accuracy: 0.8927
# Epoch 67/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 00067: val_accuracy did not improve from 0.89593
# 16587/16587 [==============================] - 14s 859us/sample - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.6424 - val_accuracy: 0.8932
# Epoch 68/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 6.6049e-04 - accuracy: 0.9999
# Epoch 00068: val_accuracy did not improve from 0.89593
# 16587/16587 [==============================] - 14s 855us/sample - loss: 6.6013e-04 - accuracy: 0.9999 - val_loss: 0.6376 - val_accuracy: 0.8905
# Epoch 69/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 00069: val_accuracy did not improve from 0.89593
# 16587/16587 [==============================] - 14s 862us/sample - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.6379 - val_accuracy: 0.8943
# Epoch 70/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 00070: val_accuracy improved from 0.89593 to 0.89810, saving model to ./storage/mnist_test_4/kfold10/epoch_070_val_0.643_acc_0.898.h5
# 16587/16587 [==============================] - 15s 889us/sample - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.6435 - val_accuracy: 0.8981
# Epoch 71/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 4.5472e-04 - accuracy: 0.9999
# Epoch 00071: val_accuracy did not improve from 0.89810
# 16587/16587 [==============================] - 14s 857us/sample - loss: 4.5464e-04 - accuracy: 0.9999 - val_loss: 0.6418 - val_accuracy: 0.8943
# Epoch 72/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 4.0616e-04 - accuracy: 0.9999
# Epoch 00072: val_accuracy did not improve from 0.89810
# 16587/16587 [==============================] - 14s 857us/sample - loss: 4.1432e-04 - accuracy: 0.9999 - val_loss: 0.6400 - val_accuracy: 0.8932
# Epoch 73/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 8.3794e-04 - accuracy: 0.9998
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
#
# Epoch 00073: val_accuracy did not improve from 0.89810
# 16587/16587 [==============================] - 14s 851us/sample - loss: 8.3745e-04 - accuracy: 0.9998 - val_loss: 0.6571 - val_accuracy: 0.8905
# Epoch 74/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 4.7232e-04 - accuracy: 0.9999
# Epoch 00074: val_accuracy did not improve from 0.89810
# 16587/16587 [==============================] - 14s 855us/sample - loss: 4.7204e-04 - accuracy: 0.9999 - val_loss: 0.6542 - val_accuracy: 0.8911
# Epoch 75/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 4.5752e-04 - accuracy: 0.9998
# Epoch 00075: val_accuracy did not improve from 0.89810
# 16587/16587 [==============================] - 14s 861us/sample - loss: 4.5652e-04 - accuracy: 0.9998 - val_loss: 0.6379 - val_accuracy: 0.8938
# Epoch 76/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 5.7924e-04 - accuracy: 0.9998
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
#
# Epoch 00076: val_accuracy did not improve from 0.89810
# 16587/16587 [==============================] - 14s 858us/sample - loss: 5.8041e-04 - accuracy: 0.9998 - val_loss: 0.6520 - val_accuracy: 0.8954
# Epoch 77/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 2.5605e-04 - accuracy: 1.0000
# Epoch 00077: val_accuracy did not improve from 0.89810
# 16587/16587 [==============================] - 14s 855us/sample - loss: 2.5633e-04 - accuracy: 1.0000 - val_loss: 0.6485 - val_accuracy: 0.8959
# Epoch 78/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 2.5778e-04 - accuracy: 0.9999
# Epoch 00078: val_accuracy did not improve from 0.89810
# 16587/16587 [==============================] - 14s 850us/sample - loss: 2.5761e-04 - accuracy: 0.9999 - val_loss: 0.6479 - val_accuracy: 0.8949
# Epoch 79/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 1.9195e-04 - accuracy: 1.0000
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
#
# Epoch 00079: val_accuracy did not improve from 0.89810
# 16587/16587 [==============================] - 14s 853us/sample - loss: 1.9182e-04 - accuracy: 1.0000 - val_loss: 0.6402 - val_accuracy: 0.8959
# Epoch 80/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 1.4990e-04 - accuracy: 1.0000
# Epoch 00080: val_accuracy improved from 0.89810 to 0.90027, saving model to ./storage/mnist_test_4/kfold10/epoch_080_val_0.637_acc_0.900.h5
# 16587/16587 [==============================] - 15s 897us/sample - loss: 3.3855e-04 - accuracy: 0.9999 - val_loss: 0.6373 - val_accuracy: 0.9003
# Epoch 81/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 2.1177e-04 - accuracy: 0.9999
# Epoch 00081: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 852us/sample - loss: 2.1391e-04 - accuracy: 0.9999 - val_loss: 0.6531 - val_accuracy: 0.8986
# Epoch 82/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 3.2994e-04 - accuracy: 0.9999
# Epoch 00082: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 857us/sample - loss: 3.2916e-04 - accuracy: 0.9999 - val_loss: 0.6507 - val_accuracy: 0.8976
# Epoch 83/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 4.9475e-04 - accuracy: 0.9998
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
#
# Epoch 00083: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 858us/sample - loss: 4.9443e-04 - accuracy: 0.9998 - val_loss: 0.6479 - val_accuracy: 0.8970
# Epoch 84/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 4.3264e-04 - accuracy: 0.9999
# Epoch 00084: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 863us/sample - loss: 4.3156e-04 - accuracy: 0.9999 - val_loss: 0.6495 - val_accuracy: 0.8976
# Epoch 85/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 4.5473e-04 - accuracy: 0.9998
# Epoch 00085: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 857us/sample - loss: 4.5359e-04 - accuracy: 0.9998 - val_loss: 0.6478 - val_accuracy: 0.8949
# Epoch 86/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 4.3281e-04 - accuracy: 0.9998
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
#
# Epoch 00086: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 855us/sample - loss: 4.3253e-04 - accuracy: 0.9998 - val_loss: 0.6395 - val_accuracy: 0.8970
# Epoch 87/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 6.8664e-04 - accuracy: 0.9998
# Epoch 00087: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 856us/sample - loss: 6.8493e-04 - accuracy: 0.9998 - val_loss: 0.6431 - val_accuracy: 0.8970
# Epoch 88/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 2.8402e-04 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 855us/sample - loss: 2.8330e-04 - accuracy: 1.0000 - val_loss: 0.6519 - val_accuracy: 0.8965
# Epoch 89/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 2.7754e-04 - accuracy: 0.9999
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
#
# Epoch 00089: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 855us/sample - loss: 2.7687e-04 - accuracy: 0.9999 - val_loss: 0.6405 - val_accuracy: 0.8965
# Epoch 90/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 2.5689e-04 - accuracy: 0.9999
# Epoch 00090: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 858us/sample - loss: 2.5626e-04 - accuracy: 0.9999 - val_loss: 0.6376 - val_accuracy: 0.8965
# Epoch 91/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 1.1486e-04 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 852us/sample - loss: 1.6669e-04 - accuracy: 1.0000 - val_loss: 0.6400 - val_accuracy: 0.8965
# Epoch 92/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 2.0236e-04 - accuracy: 0.9999
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
#
# Epoch 00092: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 855us/sample - loss: 2.0185e-04 - accuracy: 0.9999 - val_loss: 0.6430 - val_accuracy: 0.8976
# Epoch 93/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 3.0891e-04 - accuracy: 0.9999
# Epoch 00093: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 859us/sample - loss: 3.0814e-04 - accuracy: 0.9999 - val_loss: 0.6425 - val_accuracy: 0.8949
# Epoch 94/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 1.0899e-04 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 857us/sample - loss: 5.8803e-04 - accuracy: 0.9999 - val_loss: 0.6484 - val_accuracy: 0.8949
# Epoch 95/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 1.5739e-04 - accuracy: 1.0000
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
#
# Epoch 00095: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 856us/sample - loss: 1.5927e-04 - accuracy: 1.0000 - val_loss: 0.6404 - val_accuracy: 0.8970
# Epoch 96/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 5.0778e-04 - accuracy: 0.9999
# Epoch 00096: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 856us/sample - loss: 5.2850e-04 - accuracy: 0.9999 - val_loss: 0.6387 - val_accuracy: 0.8970
# Epoch 97/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 1.7165e-04 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 858us/sample - loss: 1.7153e-04 - accuracy: 1.0000 - val_loss: 0.6373 - val_accuracy: 0.8965
# Epoch 98/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 2.0229e-04 - accuracy: 0.9999
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
#
# Epoch 00098: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 854us/sample - loss: 2.0359e-04 - accuracy: 0.9999 - val_loss: 0.6336 - val_accuracy: 0.8959
# Epoch 99/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 1.0386e-04 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 855us/sample - loss: 1.0432e-04 - accuracy: 1.0000 - val_loss: 0.6313 - val_accuracy: 0.8954
# Epoch 100/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 2.9516e-04 - accuracy: 0.9999
# Epoch 00100: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 856us/sample - loss: 2.9455e-04 - accuracy: 0.9999 - val_loss: 0.6375 - val_accuracy: 0.8954
# Epoch 101/300
# 16576/16587 [============================>.] - ETA: 0s - loss: 1.2282e-04 - accuracy: 1.0000
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 7.378698501270265e-06.
#
# Epoch 00101: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 860us/sample - loss: 1.2276e-04 - accuracy: 1.0000 - val_loss: 0.6299 - val_accuracy: 0.8981
# Epoch 102/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 1.1782e-04 - accuracy: 1.0000
# Epoch 00102: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 853us/sample - loss: 1.2084e-04 - accuracy: 1.0000 - val_loss: 0.6318 - val_accuracy: 0.8976
# Epoch 103/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 1.6161e-04 - accuracy: 0.9999
# Epoch 00103: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 852us/sample - loss: 1.6486e-04 - accuracy: 0.9999 - val_loss: 0.6318 - val_accuracy: 0.8976
# Epoch 104/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 2.5721e-04 - accuracy: 0.9999
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 5.902958946535364e-06.
#
# Epoch 00104: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 852us/sample - loss: 2.5655e-04 - accuracy: 0.9999 - val_loss: 0.6313 - val_accuracy: 0.8986
# Epoch 105/300
# 16544/16587 [============================>.] - ETA: 0s - loss: 1.7860e-04 - accuracy: 0.9999
# Epoch 00105: val_accuracy did not improve from 0.90027
# 16587/16587 [==============================] - 14s 855us/sample - loss: 1.7867e-04 - accuracy: 0.9999 - val_loss: 0.6316 - val_accuracy: 0.8981

# %% [markdown]
# ### Make prediction for further augmented, shuffling k-fold method, input normalized

# %%
model1 = load_model('./storage/mnist_test_4/kfold1/epoch_066_val_0.546_acc_0.910.h5')
model2 = load_model('./storage/mnist_test_4/kfold2/epoch_088_val_0.619_acc_0.908.h5')
model3 = load_model('./storage/mnist_test_4/kfold3/epoch_066_val_0.603_acc_0.906.h5')

# %%
model4 = load_model('./storage/mnist_test_4/kfold4/epoch_058_val_0.526_acc_0.908.h5')
model5 = load_model('./storage/mnist_test_4/kfold5/epoch_067_val_0.580_acc_0.908.h5') 
model6 = load_model('./storage/mnist_test_4/kfold6/epoch_108_val_0.604_acc_0.918.h5')

# %%
model7 = load_model('./storage/mnist_test_4/kfold7/epoch_074_val_0.632_acc_0.915.h5') 
model8 = load_model('./storage/mnist_test_4/kfold8/epoch_081_val_0.594_acc_0.909.h5')
model9 = load_model('./storage/mnist_test_4/kfold9/epoch_067_val_0.590_acc_0.910.h5') 
model10 = load_model('./storage/mnist_test_4/kfold10/epoch_080_val_0.637_acc_0.900.h5')

# %%
pred1 = model1.predict([x_test, test_letters_numeric])
pred2 = model2.predict([x_test, test_letters_numeric])
pred3 = model3.predict([x_test, test_letters_numeric])
pred4 = model4.predict([x_test, test_letters_numeric])
pred5 = model5.predict([x_test, test_letters_numeric])  
pred6 = model6.predict([x_test, test_letters_numeric])
pred7 = model7.predict([x_test, test_letters_numeric])
pred8 = model8.predict([x_test, test_letters_numeric]) 
pred9 = model9.predict([x_test, test_letters_numeric]) 
pred10 = model10.predict([x_test, test_letters_numeric])


pred_avg = (pred1 + pred2 + pred3 + pred4 + pred5 + pred6 + pred7 + pred8 + pred9 + pred10)/10.0

# %%
result_arr = [] 
for pred in pred_avg: 
    result_arr.append(np.argmax(pred))
result_arr = np.asarray(result_arr)
result_arr
# Out:
# array([6, 5, 8, ..., 6, 8, 0])

# %%
submission['digit'] = result_arr 
submission.head()
# Out:
#      id  digit
# 0  2049      6
# 1  2050      5
# 2  2051      8
# 3  2052      0
# 4  2053      3

# %%
submission.to_csv('./storage/standard_test.csv', index=False)
