# %%
# environment: Paperspace Quadro P4000 GPU, as dataset size is small 
import numpy as np 
import pandas as pd 
import os 
import tensorflow as tf
import tensorflow.keras # run pip install keras==2.3 beforehand for compatability 
from tensorflow.keras import Input, Model 
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, AlphaDropout, MaxPooling2D, AveragePooling2D, BatchNormalization, Concatenate, Flatten, Reshape, Add, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from keras.utils.np_utils import to_categorical
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import skimage
from skimage.transform import rotate
from skimage.util import random_noise
from skimage.transform import warp, AffineTransform
import cv2 # opencv, when error occurs due to libGL, you may refer to https://github.com/conda-forge/pygridgen-feedstock/issues/10
import random 
from sklearn.model_selection import KFold
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Read in file and preprocess data

# %%
train_path = './storage/modified_mnist_dataset/train.csv'  
test_path = './storage/modified_mnist_dataset/test.csv' 
submission_path = './storage/modified_mnist_dataset/submission.csv'

# %%
train = pd.read_csv(train_path)
test = pd.read_csv(test_path) 
submission = pd.read_csv(submission_path)

# %%
# convert types of digit and letter columns to categorical 
train.iloc[:,1] = pd.Categorical(train.iloc[:,1])
train.iloc[:,2] = pd.Categorical(train.iloc[:,2]) 
test.iloc[:,1] = pd.Categorical(test.iloc[:,1])

# %%
# define and re-format train and test data 
x_train = train.iloc[:,3:].values.reshape(-1,28,28,1).astype(np.float32) 
x_train /= 255.0 
y_train = train.iloc[:,1].values
y_train = np.asarray(y_train)
y_train = to_categorical(y_train, num_classes = 10)
train_letters = train.iloc[:,2].values

x_test = test.iloc[:,2:].values.reshape(-1,28,28,1).astype(np.float32) 
x_test /= 255.0
test_letters = test.iloc[:,1].values

# %%
train_letters_numeric = [] 
test_letters_numeric = [] 
for letter in train_letters: 
    train_letters_numeric.append(ord(letter) - ord("A"))
for letter in test_letters: 
    test_letters_numeric.append(ord(letter) - ord("A")) 
    
train_letters_numeric = np.asarray(train_letters_numeric) 
test_letters_numeric = np.asarray(test_letters_numeric) 

train_letters_numeric = to_categorical(train_letters_numeric, num_classes = 26) 
test_letters_numeric = to_categorical(test_letters_numeric, num_classes = 26)

x_train.shape, y_train.shape, x_test.shape, train_letters_numeric.shape, test_letters_numeric.shape
# Out:
# ((2048, 28, 28, 1), (2048, 10), (20480, 28, 28, 1), (2048, 26), (20480, 26))

# %% [markdown]
# # Augment Data
#
# For now, we will try augmenting the data using the following methods
# - rotation
# - adding noise
# - adding gaussian blur
# - shifting image
#
# Please refer to [this notebook](https://github.com/iljimae0418/overlapping-digit-and-letter-mnist/blob/master/Examples%20of%20data%20augmentations.ipynb) for examples.

# %%
# apply rotations 
x_train_rotated = [] 
for x_data in x_train:
    rotated_img = rotate(x_data, angle = random.randint(10,40))
    x_train_rotated.append(rotated_img) 
x_train_rotated = np.asarray(x_train_rotated)

# %%
# apply clockwise rotations 
x_train_rotated_2 = [] 
for x_data in x_train: 
    rotated_img = rotate(x_data, angle = -random.randint(10,40)) 
    x_train_rotated_2.append(rotated_img)
x_train_rotated_2 = np.asarray(x_train_rotated_2)

# %%
# add noise 
x_noised = [] 
for x_data in x_train: 
    noised_img = random_noise(x_data) 
    x_noised.append(noised_img)
x_noised = np.asarray(x_noised)

# %%
# add gaussian blur 
x_blurred = [] 
for x_data in x_train:
    kernel_size = random.choice([3,5,9]) 
    blurred = cv2.GaussianBlur(x_data, (kernel_size, kernel_size), 0) 
    x_blurred.append(blurred)
x_blurred = np.asarray(x_blurred)
x_blurred = x_blurred.reshape(-1,28,28,1)

# %%
# shift image 
x_shifted = [] 
for x_data in x_train: 
    dx = random.choice([-2,-1,1,2])
    dy = random.choice([-2,-1,1,2])
    transform = AffineTransform(translation = (dx,dy))
    warp_img = warp(x_data, transform, mode = "wrap")
    x_shifted.append(warp_img) 
x_shifted = np.asarray(x_shifted)

# %%
# concatenating augmented data to the original 
x_train = np.concatenate((x_train, x_train_rotated, x_train_rotated_2, x_noised, x_blurred, x_shifted), axis = 0) 
y_train = np.concatenate((y_train, y_train, y_train, y_train, y_train, y_train), axis = 0) 
train_letters_numeric = np.concatenate((train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric), axis = 0)

x_train.shape, y_train.shape, train_letters_numeric.shape
# Out:
# ((12288, 28, 28, 1), (12288, 10), (12288, 26))

# %% [markdown]
# # Conduct Training

# %%
# define train and test data generators 
# this "replaces" the train data. It does not add to it 
train_datagen = ImageDataGenerator(rotation_range = 40, 
                                  width_shift_range = 0.2, 
                                  height_shift_range = 0.2, 
                                  shear_range = 0.2,
                                  zoom_range = 0.2)

# %%
# define models to be used for experimentation 
# a basic model that obtains around a 74% validation loss on 9:1 train/validation split. 
def base_cnn(): 
    inputs = Input((28,28,1))
    conv = Conv2D(64, 3, activation = 'relu')(inputs)
    conv = Conv2D(64, 3, activation = 'relu')(conv)
    conv = MaxPooling2D((2,2))(conv)
    bn = BatchNormalization()(conv) 
    conv = Conv2D(128, 3, activation = 'relu')(bn)
    conv = Conv2D(128, 3, activation = 'relu')(conv) 
    conv = MaxPooling2D((2,2))(conv) 
    bn = BatchNormalization()(conv)
    conv = Conv2D(256, 3, activation = 'relu')(bn)
    conv = MaxPooling2D((2,2))(conv)
    outputs = Flatten()(conv)
    outputs = BatchNormalization()(outputs)
    outputs = Dense(512, activation = 'relu')(outputs)
    outputs = Dense(10, activation = 'softmax')(outputs) 
    model = Model(inputs = inputs, outputs = outputs) 
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy']) 
    return model

# %%
# uses skip connections and also adds information from both MaxPooling2D and AveragePooling2D 
def conv2d_block(input_layer, n_filters, kernel):
    conv1 = Conv2D(n_filters, kernel, activation = 'relu', padding = 'same')(input_layer)
    conv1 = BatchNormalization()(conv1)
    conv2 = Conv2D(n_filters, kernel, activation = 'relu', padding = 'same')(conv1)
    conv1 = Add()([conv1, conv2])   
    conv1 = BatchNormalization()(conv1)
    maxpool = MaxPooling2D((2,2))(conv1) 
    avgpool = AveragePooling2D((2,2))(conv1)
    ret = Add()([maxpool,avgpool])
    return ret 

def dense_block(input_layer, units): 
    dense1 = Dense(units, activation = 'relu')(input_layer)
    for i in range(3): 
        bn = BatchNormalization()(dense1)
        dense2 = Dense(units, activation = 'relu')(bn)
        dense1 = Add()([dense1,dense2]) 
    return dense1 
    
# obtains around 75% validation loss on a 9:1 train/validation split 
def base_cnn_grade_2(): 
    inputs = Input((28,28,1))
    conv0 = conv2d_block(inputs, 64, 7)    
    conv1 = conv2d_block(inputs, 64, 5) 
    conv2 = conv2d_block(inputs, 64, 4) 
    conv3 = conv2d_block(inputs, 64, 3)
    conv = Concatenate()([conv0,conv1,conv2,conv3])   
    conv0 = conv2d_block(conv, 32, 7)
    conv1 = conv2d_block(conv, 32, 5)
    conv2 = conv2d_block(conv, 32, 4)
    conv3 = conv2d_block(conv, 32, 3) 
    conv = Concatenate()([conv0,conv1,conv2,conv3]) 
    outputs = Flatten()(conv)
    for unit in [256, 128, 64]: 
        outputs = Dense(unit, activation = 'selu', kernel_initializer = 'lecun_normal')(outputs)  
    outputs = Dense(10, activation = 'softmax')(outputs)
    model = Model(inputs = inputs, outputs = outputs)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model 

# obtains around 80% validation loss on a 9:1 train/validation split 
def base_cnn_grade_3(): 
    inputs = Input((28,28,1))
    letter_input = Input((26,))
    conv0 = conv2d_block(inputs, 64, 7)    
    conv1 = conv2d_block(inputs, 64, 5) 
    conv2 = conv2d_block(inputs, 64, 4) 
    conv3 = conv2d_block(inputs, 64, 3)
    conv = Concatenate()([conv0,conv1,conv2,conv3])   
    conv0 = conv2d_block(conv, 32, 7)
    conv1 = conv2d_block(conv, 32, 5)
    conv2 = conv2d_block(conv, 32, 4)
    conv3 = conv2d_block(conv, 32, 3) 
    conv = Concatenate()([conv0,conv1,conv2,conv3]) 
    outputs = Flatten()(conv) 
    outputs = Concatenate()([outputs,letter_input])
    for unit in [512, 256, 128]: 
        outputs = Dense(unit, activation = 'selu', kernel_initializer = 'lecun_normal')(outputs)  
    outputs = Dense(10, activation = 'softmax')(outputs)
    model = Model(inputs = [inputs, letter_input], outputs = outputs)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model  

# obtains around 82% validation loss on a 9:1 train/validation split
# the most promising model so far, until we come up with a potentially more powerful grade 5 model 
def base_cnn_grade_4(): 
    inputs = Input((28,28,1))
    letter_input = Input((26,))   
    conv1 = conv2d_block(inputs, 64, 7) 
    conv2 = conv2d_block(inputs, 64, 5) 
    conv3 = conv2d_block(inputs, 64, 3) 
    conv = Concatenate()([conv1,conv2,conv3])   
    conv1 = conv2d_block(conv, 32, 7)
    conv2 = conv2d_block(conv, 32, 5)
    conv3 = conv2d_block(conv, 32, 3) 
    conv = Concatenate()([conv1,conv2,conv3]) 
    outputs = Flatten()(conv) 
    outputs = Concatenate()([outputs,letter_input])
    for unit in [512, 256, 128]: 
        outputs = Dense(unit, activation = 'relu')(outputs)  
        outputs = BatchNormalization()(outputs) 
    outputs = Dropout(0.4)(outputs) 
    outputs = Dense(10, activation = 'softmax')(outputs)
    model = Model(inputs = [inputs, letter_input], outputs = outputs)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model  

# baseline model presented by Dacon 
# results in 74% accuracy for 9:1 train/validation split
def cnn_dacon(): 
    inputs = Input((28,28,1)) 
    letter_data = Input((26,)) 

    bn = BatchNormalization()(inputs)
    conv = Conv2D(128, kernel_size=5, strides=1, padding='same', activation='relu')(bn)
    bn = BatchNormalization()(conv)
    conv = Conv2D(128, kernel_size=2, strides=1, padding='same', activation='relu')(bn)
    pool = MaxPooling2D((2, 2))(conv)

    bn = BatchNormalization()(pool)
    conv = Conv2D(256, kernel_size=2, strides=1, padding='same', activation='relu')(bn)
    bn = BatchNormalization()(conv)
    conv = Conv2D(256, kernel_size=2, strides=1, padding='same', activation='relu')(bn)
    pool = MaxPooling2D((2, 2))(conv)

    flatten = Flatten()(pool)
    flatten = Concatenate()([flatten, letter_data])
    bn = BatchNormalization()(flatten)
    dense = Dense(1000, activation='relu')(bn)

    bn = BatchNormalization()(dense)
    outputs = Dense(10, activation='softmax')(bn)
    model = Model(inputs = [inputs,letter_data], outputs = outputs) 
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy']) 
    return model

# %%
'''
# codeblock to delete files in model directory - for experimentation 
# use with caution! 
files = [os.path.join('./storage/mnist_test/kfold1_sklearn/',x) for x in os.listdir('./storage/mnist_test/kfold1_sklearn/')] 
for file in files:  
    if 'epoch' in file: 
        os.remove(file)
'''

# %%
# implement k-fold cv 
def k_fold(k,files):  
    folds = [] 
    fold_size = len(files) // k 
    for i in range(k): 
        if i == k-1:  
            l = files[i*fold_size:] 
        else: 
            l = files[i*fold_size:(i+1)*fold_size]  
        folds.append(l)   
    return folds  

x_train_folds = k_fold(5, x_train)
y_train_folds = k_fold(5, y_train) 
letter_train_folds = k_fold(5,train_letters_numeric)

for t in range(5):  
    print("************ Fold {} training ************".format(t+1)) 
    cur_val_x = x_train_folds[t] 
    cur_val_y = y_train_folds[t] 
    cur_val_letter = letter_train_folds[t]
    train_folds_x = x_train_folds[0:t] + x_train_folds[t+1:] 
    train_folds_y = y_train_folds[0:t] + y_train_folds[t+1:]
    train_fold_letter = letter_train_folds[0:t] + letter_train_folds[t+1:]
    cur_train_x = [] 
    cur_train_y = [] 
    cur_letter = [] 
    for j in train_folds_x:  
        for q in j:  
            cur_train_x.append(q) 
    for j in train_folds_y:  
        for q in j:  
            cur_train_y.append(q)  
    for j in train_fold_letter: 
        for q in j: 
            cur_letter.append(q) 
    cur_train_x = np.asarray(cur_train_x)
    cur_train_y = np.asarray(cur_train_y)
    cur_letter = np.asarray(cur_letter) 
    model_path = './storage/mnist_test/' + 'kfold' + str(t+1) + '/epoch_{epoch:03d}_val_{val_loss:.3f}_acc_{val_accuracy:.3f}.h5' 
    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.8)
    checkpoint = ModelCheckpoint(filepath=model_path,monitor='val_accuracy',verbose=1,save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_accuracy',patience=25)
    annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x) # possible alternative to ReduceLROnPlateau
    model = base_cnn_grade_4() 
 
    '''
    history = model.fit_generator(
        train_datagen.flow(cur_train_x, cur_train_y, batch_size = 32, shuffle = True),
        epochs = 200, 
        steps_per_epoch = cur_train_x.shape[0]//32,
        verbose = 1, 
        validation_data = (cur_val_x, cur_val_y),
        callbacks=[learning_rate_reduction, checkpoint, early_stopping]
    )
    ''' 
    
    history = model.fit([cur_train_x,cur_letter],
                        cur_train_y,
                       batch_size = 32,
                       shuffle = True, 
                       validation_data = ([cur_val_x,cur_val_letter],cur_val_y),
                       verbose = 1, 
                       epochs = 300,
                       callbacks = [learning_rate_reduction, checkpoint, early_stopping])
# Out:
# ************ Fold 1 training ************
# Train on 9831 samples, validate on 2457 samples
# Epoch 1/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 2.1160 - accuracy: 0.3196
# Epoch 00001: val_accuracy improved from -inf to 0.09768, saving model to ./storage/mnist_test/kfold1/epoch_001_val_3.610_acc_0.098.h5
# 9831/9831 [==============================] - 13s 1ms/sample - loss: 2.1159 - accuracy: 0.3196 - val_loss: 3.6096 - val_accuracy: 0.0977
# Epoch 2/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 1.4207 - accuracy: 0.5197
# Epoch 00002: val_accuracy improved from 0.09768 to 0.70981, saving model to ./storage/mnist_test/kfold1/epoch_002_val_0.860_acc_0.710.h5
# 9831/9831 [==============================] - 7s 713us/sample - loss: 1.4208 - accuracy: 0.5197 - val_loss: 0.8604 - val_accuracy: 0.7098
# Epoch 3/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 1.0575 - accuracy: 0.6381
# Epoch 00003: val_accuracy improved from 0.70981 to 0.80667, saving model to ./storage/mnist_test/kfold1/epoch_003_val_0.564_acc_0.807.h5
# 9831/9831 [==============================] - 7s 716us/sample - loss: 1.0582 - accuracy: 0.6381 - val_loss: 0.5637 - val_accuracy: 0.8067
# Epoch 4/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.8753 - accuracy: 0.7001
# Epoch 00004: val_accuracy improved from 0.80667 to 0.85429, saving model to ./storage/mnist_test/kfold1/epoch_004_val_0.442_acc_0.854.h5
# 9831/9831 [==============================] - 7s 713us/sample - loss: 0.8750 - accuracy: 0.7000 - val_loss: 0.4416 - val_accuracy: 0.8543
# Epoch 5/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.7184 - accuracy: 0.7606
# Epoch 00005: val_accuracy improved from 0.85429 to 0.88523, saving model to ./storage/mnist_test/kfold1/epoch_005_val_0.372_acc_0.885.h5
# 9831/9831 [==============================] - 7s 714us/sample - loss: 0.7194 - accuracy: 0.7603 - val_loss: 0.3722 - val_accuracy: 0.8852
# Epoch 6/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.6070 - accuracy: 0.7942
# Epoch 00006: val_accuracy improved from 0.88523 to 0.89255, saving model to ./storage/mnist_test/kfold1/epoch_006_val_0.333_acc_0.893.h5
# 9831/9831 [==============================] - 7s 720us/sample - loss: 0.6069 - accuracy: 0.7942 - val_loss: 0.3330 - val_accuracy: 0.8926
# Epoch 7/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.4860 - accuracy: 0.8399
# Epoch 00007: val_accuracy improved from 0.89255 to 0.90354, saving model to ./storage/mnist_test/kfold1/epoch_007_val_0.311_acc_0.904.h5
# 9831/9831 [==============================] - 7s 715us/sample - loss: 0.4869 - accuracy: 0.8396 - val_loss: 0.3114 - val_accuracy: 0.9035
# Epoch 8/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.4044 - accuracy: 0.8687
# Epoch 00008: val_accuracy improved from 0.90354 to 0.92877, saving model to ./storage/mnist_test/kfold1/epoch_008_val_0.230_acc_0.929.h5
# 9831/9831 [==============================] - 7s 714us/sample - loss: 0.4041 - accuracy: 0.8688 - val_loss: 0.2300 - val_accuracy: 0.9288
# Epoch 9/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.3342 - accuracy: 0.8905
# Epoch 00009: val_accuracy improved from 0.92877 to 0.94180, saving model to ./storage/mnist_test/kfold1/epoch_009_val_0.181_acc_0.942.h5
# 9831/9831 [==============================] - 7s 715us/sample - loss: 0.3341 - accuracy: 0.8906 - val_loss: 0.1810 - val_accuracy: 0.9418
# Epoch 10/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.2657 - accuracy: 0.9107
# Epoch 00010: val_accuracy did not improve from 0.94180
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.2656 - accuracy: 0.9107 - val_loss: 0.1937 - val_accuracy: 0.9410
# Epoch 11/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.2402 - accuracy: 0.9234
# Epoch 00011: val_accuracy improved from 0.94180 to 0.94221, saving model to ./storage/mnist_test/kfold1/epoch_011_val_0.202_acc_0.942.h5
# 9831/9831 [==============================] - 7s 715us/sample - loss: 0.2408 - accuracy: 0.9233 - val_loss: 0.2020 - val_accuracy: 0.9422
# Epoch 12/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.2534 - accuracy: 0.9150
# Epoch 00012: val_accuracy did not improve from 0.94221
# 9831/9831 [==============================] - 7s 672us/sample - loss: 0.2551 - accuracy: 0.9149 - val_loss: 0.2928 - val_accuracy: 0.9158
# Epoch 13/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.4333 - accuracy: 0.8522
# Epoch 00013: val_accuracy improved from 0.94221 to 0.95157, saving model to ./storage/mnist_test/kfold1/epoch_013_val_0.189_acc_0.952.h5
# 9831/9831 [==============================] - 7s 718us/sample - loss: 0.4332 - accuracy: 0.8521 - val_loss: 0.1894 - val_accuracy: 0.9516
# Epoch 14/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.2486 - accuracy: 0.9153
# Epoch 00014: val_accuracy did not improve from 0.95157
# 9831/9831 [==============================] - 7s 670us/sample - loss: 0.2486 - accuracy: 0.9153 - val_loss: 0.1917 - val_accuracy: 0.9446
# Epoch 15/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.1280 - accuracy: 0.9580
# Epoch 00015: val_accuracy improved from 0.95157 to 0.95808, saving model to ./storage/mnist_test/kfold1/epoch_015_val_0.163_acc_0.958.h5
# 9831/9831 [==============================] - 7s 712us/sample - loss: 0.1282 - accuracy: 0.9579 - val_loss: 0.1627 - val_accuracy: 0.9581
# Epoch 16/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.1072 - accuracy: 0.9645
# Epoch 00016: val_accuracy did not improve from 0.95808
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.1082 - accuracy: 0.9643 - val_loss: 0.1788 - val_accuracy: 0.9536
# Epoch 17/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.1443 - accuracy: 0.9520
# Epoch 00017: val_accuracy did not improve from 0.95808
# 9831/9831 [==============================] - 7s 672us/sample - loss: 0.1443 - accuracy: 0.9519 - val_loss: 0.1847 - val_accuracy: 0.9573
# Epoch 18/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.1044 - accuracy: 0.9648
# Epoch 00018: val_accuracy improved from 0.95808 to 0.95971, saving model to ./storage/mnist_test/kfold1/epoch_018_val_0.170_acc_0.960.h5
# 9831/9831 [==============================] - 7s 713us/sample - loss: 0.1042 - accuracy: 0.9649 - val_loss: 0.1700 - val_accuracy: 0.9597
# Epoch 19/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0981 - accuracy: 0.9676
# Epoch 00019: val_accuracy did not improve from 0.95971
# 9831/9831 [==============================] - 7s 675us/sample - loss: 0.0979 - accuracy: 0.9677 - val_loss: 0.2089 - val_accuracy: 0.9520
# Epoch 20/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.1063 - accuracy: 0.9652
# Epoch 00020: val_accuracy did not improve from 0.95971
# 9831/9831 [==============================] - 7s 667us/sample - loss: 0.1063 - accuracy: 0.9652 - val_loss: 0.1995 - val_accuracy: 0.9524
# Epoch 21/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.9618
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
#
# Epoch 00021: val_accuracy did not improve from 0.95971
# 9831/9831 [==============================] - 7s 669us/sample - loss: 0.1114 - accuracy: 0.9619 - val_loss: 0.2448 - val_accuracy: 0.9398
# Epoch 22/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0601 - accuracy: 0.9802
# Epoch 00022: val_accuracy did not improve from 0.95971
# 9831/9831 [==============================] - 7s 668us/sample - loss: 0.0601 - accuracy: 0.9802 - val_loss: 0.1843 - val_accuracy: 0.9565
# Epoch 23/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9882
# Epoch 00023: val_accuracy did not improve from 0.95971
# 9831/9831 [==============================] - 7s 670us/sample - loss: 0.0365 - accuracy: 0.9880 - val_loss: 0.1705 - val_accuracy: 0.9589
# Epoch 24/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9845
# Epoch 00024: val_accuracy improved from 0.95971 to 0.96052, saving model to ./storage/mnist_test/kfold1/epoch_024_val_0.191_acc_0.961.h5
# 9831/9831 [==============================] - 7s 719us/sample - loss: 0.0493 - accuracy: 0.9845 - val_loss: 0.1911 - val_accuracy: 0.9605
# Epoch 25/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0577 - accuracy: 0.9813
# Epoch 00025: val_accuracy did not improve from 0.96052
# 9831/9831 [==============================] - 7s 670us/sample - loss: 0.0577 - accuracy: 0.9813 - val_loss: 0.1978 - val_accuracy: 0.9585
# Epoch 26/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0634 - accuracy: 0.9789
# Epoch 00026: val_accuracy improved from 0.96052 to 0.96133, saving model to ./storage/mnist_test/kfold1/epoch_026_val_0.183_acc_0.961.h5
# 9831/9831 [==============================] - 7s 714us/sample - loss: 0.0634 - accuracy: 0.9789 - val_loss: 0.1833 - val_accuracy: 0.9613
# Epoch 27/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0471 - accuracy: 0.9834
# Epoch 00027: val_accuracy did not improve from 0.96133
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0474 - accuracy: 0.9833 - val_loss: 0.2044 - val_accuracy: 0.9548
# Epoch 28/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0650 - accuracy: 0.9767
# Epoch 00028: val_accuracy did not improve from 0.96133
# 9831/9831 [==============================] - 7s 669us/sample - loss: 0.0649 - accuracy: 0.9767 - val_loss: 0.2046 - val_accuracy: 0.9597
# Epoch 29/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0572 - accuracy: 0.9809
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 00029: val_accuracy did not improve from 0.96133
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0569 - accuracy: 0.9811 - val_loss: 0.2064 - val_accuracy: 0.9565
# Epoch 30/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0398 - accuracy: 0.9866
# Epoch 00030: val_accuracy did not improve from 0.96133
# 9831/9831 [==============================] - 7s 672us/sample - loss: 0.0397 - accuracy: 0.9867 - val_loss: 0.2062 - val_accuracy: 0.9609
# Epoch 31/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0297 - accuracy: 0.9907
# Epoch 00031: val_accuracy did not improve from 0.96133
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.0300 - accuracy: 0.9906 - val_loss: 0.1910 - val_accuracy: 0.9605
# Epoch 32/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0713 - accuracy: 0.9773
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 00032: val_accuracy did not improve from 0.96133
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0712 - accuracy: 0.9773 - val_loss: 0.1804 - val_accuracy: 0.9577
# Epoch 33/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0352 - accuracy: 0.9885
# Epoch 00033: val_accuracy did not improve from 0.96133
# 9831/9831 [==============================] - 7s 672us/sample - loss: 0.0351 - accuracy: 0.9885 - val_loss: 0.1809 - val_accuracy: 0.9609
# Epoch 34/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0200 - accuracy: 0.9937
# Epoch 00034: val_accuracy improved from 0.96133 to 0.96622, saving model to ./storage/mnist_test/kfold1/epoch_034_val_0.166_acc_0.966.h5
# 9831/9831 [==============================] - 7s 712us/sample - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.1659 - val_accuracy: 0.9662
# Epoch 35/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0146 - accuracy: 0.9955
# Epoch 00035: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.1800 - val_accuracy: 0.9642
# Epoch 36/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0140 - accuracy: 0.9956
# Epoch 00036: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0140 - accuracy: 0.9956 - val_loss: 0.1807 - val_accuracy: 0.9634
# Epoch 37/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9962
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 00037: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 670us/sample - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.1925 - val_accuracy: 0.9605
# Epoch 38/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.9968
# Epoch 00038: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 675us/sample - loss: 0.0128 - accuracy: 0.9967 - val_loss: 0.1703 - val_accuracy: 0.9621
# Epoch 39/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 0.9967
# Epoch 00039: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.1957 - val_accuracy: 0.9613
# Epoch 40/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0199 - accuracy: 0.9938
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 00040: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0201 - accuracy: 0.9937 - val_loss: 0.2099 - val_accuracy: 0.9601
# Epoch 41/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0267 - accuracy: 0.9918
# Epoch 00041: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 676us/sample - loss: 0.0267 - accuracy: 0.9918 - val_loss: 0.2088 - val_accuracy: 0.9621
# Epoch 42/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0096 - accuracy: 0.9966
# Epoch 00042: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.2029 - val_accuracy: 0.9621
# Epoch 43/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9978
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 00043: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.2058 - val_accuracy: 0.9626
# Epoch 44/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9982
# Epoch 00044: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.1897 - val_accuracy: 0.9650
# Epoch 45/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.9967
# Epoch 00045: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 676us/sample - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.2011 - val_accuracy: 0.9642
# Epoch 46/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9986
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 00046: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0070 - accuracy: 0.9986 - val_loss: 0.2045 - val_accuracy: 0.9601
# Epoch 47/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9981
# Epoch 00047: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0075 - accuracy: 0.9981 - val_loss: 0.1950 - val_accuracy: 0.9617
# Epoch 48/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9990
# Epoch 00048: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.1941 - val_accuracy: 0.9646
# Epoch 49/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9986
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# Epoch 00049: val_accuracy did not improve from 0.96622
# 9831/9831 [==============================] - 7s 676us/sample - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.1934 - val_accuracy: 0.9662
# Epoch 50/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9991
# Epoch 00050: val_accuracy improved from 0.96622 to 0.96703, saving model to ./storage/mnist_test/kfold1/epoch_050_val_0.189_acc_0.967.h5
# 9831/9831 [==============================] - 7s 710us/sample - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.1892 - val_accuracy: 0.9670
# Epoch 51/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9988
# Epoch 00051: val_accuracy improved from 0.96703 to 0.96947, saving model to ./storage/mnist_test/kfold1/epoch_051_val_0.181_acc_0.969.h5
# 9831/9831 [==============================] - 7s 709us/sample - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.1812 - val_accuracy: 0.9695
# Epoch 52/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9987
# Epoch 00052: val_accuracy improved from 0.96947 to 0.97070, saving model to ./storage/mnist_test/kfold1/epoch_052_val_0.181_acc_0.971.h5
# 9831/9831 [==============================] - 7s 709us/sample - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.1805 - val_accuracy: 0.9707
# Epoch 53/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 00053: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1813 - val_accuracy: 0.9703
# Epoch 54/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9987
# Epoch 00054: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 675us/sample - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.1751 - val_accuracy: 0.9699
# Epoch 55/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9992
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
#
# Epoch 00055: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 672us/sample - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.1807 - val_accuracy: 0.9683
# Epoch 56/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.9986
# Epoch 00056: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 670us/sample - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.1829 - val_accuracy: 0.9687
# Epoch 57/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9988
# Epoch 00057: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 669us/sample - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.1852 - val_accuracy: 0.9670
# Epoch 58/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
#
# Epoch 00058: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.1823 - val_accuracy: 0.9662
# Epoch 59/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9999
# Epoch 00059: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.1827 - val_accuracy: 0.9683
# Epoch 60/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9986
# Epoch 00060: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 676us/sample - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.1939 - val_accuracy: 0.9666
# Epoch 61/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9992
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
#
# Epoch 00061: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 676us/sample - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.1867 - val_accuracy: 0.9670
# Epoch 62/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 00062: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.1853 - val_accuracy: 0.9670
# Epoch 63/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9994
# Epoch 00063: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 672us/sample - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.1878 - val_accuracy: 0.9674
# Epoch 64/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9997
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 00064: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1892 - val_accuracy: 0.9646
# Epoch 65/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 00065: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.1900 - val_accuracy: 0.9658
# Epoch 66/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 00066: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1908 - val_accuracy: 0.9654
# Epoch 67/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
#
# Epoch 00067: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 675us/sample - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.1909 - val_accuracy: 0.9650
# Epoch 68/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00068: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 679us/sample - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1891 - val_accuracy: 0.9658
# Epoch 69/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 9.1982e-04 - accuracy: 0.9999
# Epoch 00069: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 673us/sample - loss: 9.1680e-04 - accuracy: 0.9999 - val_loss: 0.1898 - val_accuracy: 0.9662
# Epoch 70/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
#
# Epoch 00070: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1882 - val_accuracy: 0.9678
# Epoch 71/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00071: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 670us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1872 - val_accuracy: 0.9666
# Epoch 72/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 7.5902e-04 - accuracy: 0.9999
# Epoch 00072: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 672us/sample - loss: 7.5656e-04 - accuracy: 0.9999 - val_loss: 0.1846 - val_accuracy: 0.9678
# Epoch 73/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9999
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
#
# Epoch 00073: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 670us/sample - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.1865 - val_accuracy: 0.9678
# Epoch 74/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00074: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1836 - val_accuracy: 0.9678
# Epoch 75/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 9.7260e-04 - accuracy: 0.9997
# Epoch 00075: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 681us/sample - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1799 - val_accuracy: 0.9683
# Epoch 76/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
#
# Epoch 00076: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1785 - val_accuracy: 0.9687
# Epoch 77/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00077: val_accuracy did not improve from 0.97070
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1785 - val_accuracy: 0.9703
# ************ Fold 2 training ************
# Train on 9831 samples, validate on 2457 samples
# Epoch 1/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 1.9917 - accuracy: 0.3577
# Epoch 00001: val_accuracy improved from -inf to 0.16199, saving model to ./storage/mnist_test/kfold2/epoch_001_val_3.201_acc_0.162.h5
# 9831/9831 [==============================] - 11s 1ms/sample - loss: 1.9912 - accuracy: 0.3577 - val_loss: 3.2015 - val_accuracy: 0.1620
# Epoch 2/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 1.2436 - accuracy: 0.5741
# Epoch 00002: val_accuracy improved from 0.16199 to 0.46479, saving model to ./storage/mnist_test/kfold2/epoch_002_val_1.589_acc_0.465.h5
# 9831/9831 [==============================] - 7s 715us/sample - loss: 1.2434 - accuracy: 0.5742 - val_loss: 1.5893 - val_accuracy: 0.4648
# Epoch 3/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.8985 - accuracy: 0.6942
# Epoch 00003: val_accuracy improved from 0.46479 to 0.56817, saving model to ./storage/mnist_test/kfold2/epoch_003_val_1.275_acc_0.568.h5
# 9831/9831 [==============================] - 7s 711us/sample - loss: 0.8987 - accuracy: 0.6942 - val_loss: 1.2745 - val_accuracy: 0.5682
# Epoch 4/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.7105 - accuracy: 0.7644
# Epoch 00004: val_accuracy improved from 0.56817 to 0.58649, saving model to ./storage/mnist_test/kfold2/epoch_004_val_1.273_acc_0.586.h5
# 9831/9831 [==============================] - 7s 718us/sample - loss: 0.7107 - accuracy: 0.7643 - val_loss: 1.2730 - val_accuracy: 0.5865
# Epoch 5/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.5420 - accuracy: 0.8192
# Epoch 00005: val_accuracy improved from 0.58649 to 0.60562, saving model to ./storage/mnist_test/kfold2/epoch_005_val_1.239_acc_0.606.h5
# 9831/9831 [==============================] - 7s 719us/sample - loss: 0.5419 - accuracy: 0.8193 - val_loss: 1.2389 - val_accuracy: 0.6056
# Epoch 6/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.4542 - accuracy: 0.8502
# Epoch 00006: val_accuracy did not improve from 0.60562
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.4540 - accuracy: 0.8502 - val_loss: 1.4586 - val_accuracy: 0.5686
# Epoch 7/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.3599 - accuracy: 0.8788
# Epoch 00007: val_accuracy improved from 0.60562 to 0.64794, saving model to ./storage/mnist_test/kfold2/epoch_007_val_1.191_acc_0.648.h5
# 9831/9831 [==============================] - 7s 716us/sample - loss: 0.3598 - accuracy: 0.8790 - val_loss: 1.1910 - val_accuracy: 0.6479
# Epoch 8/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.3303 - accuracy: 0.8951
# Epoch 00008: val_accuracy did not improve from 0.64794
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.3300 - accuracy: 0.8951 - val_loss: 1.3202 - val_accuracy: 0.6317
# Epoch 9/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.2653 - accuracy: 0.9127
# Epoch 00009: val_accuracy did not improve from 0.64794
# 9831/9831 [==============================] - 7s 672us/sample - loss: 0.2657 - accuracy: 0.9126 - val_loss: 1.3335 - val_accuracy: 0.6300
# Epoch 10/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.2026 - accuracy: 0.9350
# Epoch 00010: val_accuracy improved from 0.64794 to 0.65853, saving model to ./storage/mnist_test/kfold2/epoch_010_val_1.270_acc_0.659.h5
# 9831/9831 [==============================] - 7s 715us/sample - loss: 0.2031 - accuracy: 0.9349 - val_loss: 1.2704 - val_accuracy: 0.6585
# Epoch 11/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.1500 - accuracy: 0.9513
# Epoch 00011: val_accuracy did not improve from 0.65853
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.1497 - accuracy: 0.9514 - val_loss: 1.4316 - val_accuracy: 0.6325
# Epoch 12/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.1312 - accuracy: 0.9550
# Epoch 00012: val_accuracy did not improve from 0.65853
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.1314 - accuracy: 0.9548 - val_loss: 1.5291 - val_accuracy: 0.6390
# Epoch 13/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.2350 - accuracy: 0.9220
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
#
# Epoch 00013: val_accuracy did not improve from 0.65853
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.2353 - accuracy: 0.9220 - val_loss: 1.3900 - val_accuracy: 0.6545
# Epoch 14/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.1268 - accuracy: 0.9585
# Epoch 00014: val_accuracy improved from 0.65853 to 0.68498, saving model to ./storage/mnist_test/kfold2/epoch_014_val_1.284_acc_0.685.h5
# 9831/9831 [==============================] - 7s 723us/sample - loss: 0.1267 - accuracy: 0.9585 - val_loss: 1.2845 - val_accuracy: 0.6850
# Epoch 15/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0718 - accuracy: 0.9784
# Epoch 00015: val_accuracy did not improve from 0.68498
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0726 - accuracy: 0.9781 - val_loss: 1.4051 - val_accuracy: 0.6675
# Epoch 16/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.1100 - accuracy: 0.9650
# Epoch 00016: val_accuracy did not improve from 0.68498
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.1100 - accuracy: 0.9650 - val_loss: 1.4938 - val_accuracy: 0.6422
# Epoch 17/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.1404 - accuracy: 0.9555
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 00017: val_accuracy did not improve from 0.68498
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.1407 - accuracy: 0.9554 - val_loss: 1.5014 - val_accuracy: 0.6504
# Epoch 18/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0659 - accuracy: 0.9779
# Epoch 00018: val_accuracy improved from 0.68498 to 0.70004, saving model to ./storage/mnist_test/kfold2/epoch_018_val_1.340_acc_0.700.h5
# 9831/9831 [==============================] - 7s 723us/sample - loss: 0.0660 - accuracy: 0.9779 - val_loss: 1.3398 - val_accuracy: 0.7000
# Epoch 19/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0736 - accuracy: 0.9764
# Epoch 00019: val_accuracy did not improve from 0.70004
# 9831/9831 [==============================] - 7s 670us/sample - loss: 0.0736 - accuracy: 0.9764 - val_loss: 1.4241 - val_accuracy: 0.6911
# Epoch 20/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0390 - accuracy: 0.9889
# Epoch 00020: val_accuracy did not improve from 0.70004
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0390 - accuracy: 0.9889 - val_loss: 1.6234 - val_accuracy: 0.6602
# Epoch 21/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0299 - accuracy: 0.9910
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 00021: val_accuracy did not improve from 0.70004
# 9831/9831 [==============================] - 7s 676us/sample - loss: 0.0300 - accuracy: 0.9909 - val_loss: 1.4680 - val_accuracy: 0.6972
# Epoch 22/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9929
# Epoch 00022: val_accuracy did not improve from 0.70004
# 9831/9831 [==============================] - 7s 676us/sample - loss: 0.0225 - accuracy: 0.9929 - val_loss: 1.4455 - val_accuracy: 0.6976
# Epoch 23/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.9952
# Epoch 00023: val_accuracy did not improve from 0.70004
# 9831/9831 [==============================] - 7s 678us/sample - loss: 0.0159 - accuracy: 0.9952 - val_loss: 1.5087 - val_accuracy: 0.6976
# Epoch 24/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9959
# Epoch 00024: val_accuracy improved from 0.70004 to 0.70452, saving model to ./storage/mnist_test/kfold2/epoch_024_val_1.522_acc_0.705.h5
# 9831/9831 [==============================] - 7s 710us/sample - loss: 0.0144 - accuracy: 0.9957 - val_loss: 1.5220 - val_accuracy: 0.7045
# Epoch 25/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 0.9932
# Epoch 00025: val_accuracy did not improve from 0.70452
# 9831/9831 [==============================] - 7s 679us/sample - loss: 0.0247 - accuracy: 0.9932 - val_loss: 1.5396 - val_accuracy: 0.6952
# Epoch 26/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9930
# Epoch 00026: val_accuracy did not improve from 0.70452
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0226 - accuracy: 0.9930 - val_loss: 1.5626 - val_accuracy: 0.7021
# Epoch 27/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.9860
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 00027: val_accuracy did not improve from 0.70452
# 9831/9831 [==============================] - 7s 670us/sample - loss: 0.0428 - accuracy: 0.9860 - val_loss: 1.6499 - val_accuracy: 0.6866
# Epoch 28/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 0.9936
# Epoch 00028: val_accuracy did not improve from 0.70452
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0225 - accuracy: 0.9932 - val_loss: 1.5734 - val_accuracy: 0.6988
# Epoch 29/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0238 - accuracy: 0.9928
# Epoch 00029: val_accuracy did not improve from 0.70452
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0241 - accuracy: 0.9926 - val_loss: 1.5837 - val_accuracy: 0.7004
# Epoch 30/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0347 - accuracy: 0.9885
# Epoch 00030: val_accuracy improved from 0.70452 to 0.70533, saving model to ./storage/mnist_test/kfold2/epoch_030_val_1.568_acc_0.705.h5
# 9831/9831 [==============================] - 7s 713us/sample - loss: 0.0347 - accuracy: 0.9885 - val_loss: 1.5675 - val_accuracy: 0.7053
# Epoch 31/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0147 - accuracy: 0.9958
# Epoch 00031: val_accuracy improved from 0.70533 to 0.70574, saving model to ./storage/mnist_test/kfold2/epoch_031_val_1.543_acc_0.706.h5
# 9831/9831 [==============================] - 7s 718us/sample - loss: 0.0148 - accuracy: 0.9957 - val_loss: 1.5428 - val_accuracy: 0.7057
# Epoch 32/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9963
# Epoch 00032: val_accuracy improved from 0.70574 to 0.70818, saving model to ./storage/mnist_test/kfold2/epoch_032_val_1.519_acc_0.708.h5
# 9831/9831 [==============================] - 7s 718us/sample - loss: 0.0136 - accuracy: 0.9962 - val_loss: 1.5193 - val_accuracy: 0.7082
# Epoch 33/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9929
# Epoch 00033: val_accuracy did not improve from 0.70818
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.0233 - accuracy: 0.9928 - val_loss: 1.8184 - val_accuracy: 0.6691
# Epoch 34/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9893
# Epoch 00034: val_accuracy improved from 0.70818 to 0.70981, saving model to ./storage/mnist_test/kfold2/epoch_034_val_1.627_acc_0.710.h5
# 9831/9831 [==============================] - 7s 734us/sample - loss: 0.0331 - accuracy: 0.9894 - val_loss: 1.6269 - val_accuracy: 0.7098
# Epoch 35/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9950
# Epoch 00035: val_accuracy did not improve from 0.70981
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0159 - accuracy: 0.9949 - val_loss: 1.6735 - val_accuracy: 0.7013
# Epoch 36/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9925
# Epoch 00036: val_accuracy did not improve from 0.70981
# 9831/9831 [==============================] - 7s 672us/sample - loss: 0.0233 - accuracy: 0.9926 - val_loss: 1.6467 - val_accuracy: 0.6960
# Epoch 37/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 0.9958
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 00037: val_accuracy did not improve from 0.70981
# 9831/9831 [==============================] - 7s 676us/sample - loss: 0.0147 - accuracy: 0.9956 - val_loss: 1.5832 - val_accuracy: 0.7070
# Epoch 38/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9937
# Epoch 00038: val_accuracy did not improve from 0.70981
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0182 - accuracy: 0.9937 - val_loss: 1.6180 - val_accuracy: 0.7021
# Epoch 39/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9980
# Epoch 00039: val_accuracy did not improve from 0.70981
# 9831/9831 [==============================] - 7s 675us/sample - loss: 0.0084 - accuracy: 0.9979 - val_loss: 1.5435 - val_accuracy: 0.7098
# Epoch 40/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0096 - accuracy: 0.9970
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 00040: val_accuracy did not improve from 0.70981
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0097 - accuracy: 0.9969 - val_loss: 1.6568 - val_accuracy: 0.7094
# Epoch 41/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9963
# Epoch 00041: val_accuracy did not improve from 0.70981
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0117 - accuracy: 0.9963 - val_loss: 1.6756 - val_accuracy: 0.7021
# Epoch 42/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9983
# Epoch 00042: val_accuracy improved from 0.70981 to 0.72120, saving model to ./storage/mnist_test/kfold2/epoch_042_val_1.586_acc_0.721.h5
# 9831/9831 [==============================] - 7s 716us/sample - loss: 0.0061 - accuracy: 0.9983 - val_loss: 1.5864 - val_accuracy: 0.7212
# Epoch 43/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9983
# Epoch 00043: val_accuracy did not improve from 0.72120
# 9831/9831 [==============================] - 7s 670us/sample - loss: 0.0066 - accuracy: 0.9983 - val_loss: 1.6482 - val_accuracy: 0.7066
# Epoch 44/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9978
# Epoch 00044: val_accuracy did not improve from 0.72120
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0078 - accuracy: 0.9976 - val_loss: 1.6659 - val_accuracy: 0.7061
# Epoch 45/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 0.9967
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 00045: val_accuracy did not improve from 0.72120
# 9831/9831 [==============================] - 7s 678us/sample - loss: 0.0112 - accuracy: 0.9967 - val_loss: 1.6943 - val_accuracy: 0.6988
# Epoch 46/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9978
# Epoch 00046: val_accuracy did not improve from 0.72120
# 9831/9831 [==============================] - 7s 679us/sample - loss: 0.0069 - accuracy: 0.9978 - val_loss: 1.6454 - val_accuracy: 0.7094
# Epoch 47/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9986
# Epoch 00047: val_accuracy did not improve from 0.72120
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0056 - accuracy: 0.9986 - val_loss: 1.6432 - val_accuracy: 0.7078
# Epoch 48/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9985
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# Epoch 00048: val_accuracy did not improve from 0.72120
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0052 - accuracy: 0.9985 - val_loss: 1.6619 - val_accuracy: 0.7139
# Epoch 49/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9992
# Epoch 00049: val_accuracy did not improve from 0.72120
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0045 - accuracy: 0.9991 - val_loss: 1.6200 - val_accuracy: 0.7204
# Epoch 50/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.9987
# Epoch 00050: val_accuracy did not improve from 0.72120
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.0047 - accuracy: 0.9987 - val_loss: 1.6375 - val_accuracy: 0.7200
# Epoch 51/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9993
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
#
# Epoch 00051: val_accuracy did not improve from 0.72120
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0039 - accuracy: 0.9992 - val_loss: 1.6186 - val_accuracy: 0.7155
# Epoch 52/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9987
# Epoch 00052: val_accuracy did not improve from 0.72120
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.0045 - accuracy: 0.9987 - val_loss: 1.6320 - val_accuracy: 0.7179
# Epoch 53/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 00053: val_accuracy improved from 0.72120 to 0.72161, saving model to ./storage/mnist_test/kfold2/epoch_053_val_1.613_acc_0.722.h5
# 9831/9831 [==============================] - 7s 718us/sample - loss: 0.0015 - accuracy: 0.9998 - val_loss: 1.6126 - val_accuracy: 0.7216
# Epoch 54/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994
# Epoch 00054: val_accuracy improved from 0.72161 to 0.72527, saving model to ./storage/mnist_test/kfold2/epoch_054_val_1.606_acc_0.725.h5
# 9831/9831 [==============================] - 7s 714us/sample - loss: 0.0024 - accuracy: 0.9992 - val_loss: 1.6060 - val_accuracy: 0.7253
# Epoch 55/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 00055: val_accuracy did not improve from 0.72527
# 9831/9831 [==============================] - 7s 672us/sample - loss: 0.0031 - accuracy: 0.9992 - val_loss: 1.6635 - val_accuracy: 0.7179
# Epoch 56/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9997
# Epoch 00056: val_accuracy did not improve from 0.72527
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0024 - accuracy: 0.9995 - val_loss: 1.6588 - val_accuracy: 0.7147
# Epoch 57/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9987
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
#
# Epoch 00057: val_accuracy did not improve from 0.72527
# 9831/9831 [==============================] - 7s 667us/sample - loss: 0.0036 - accuracy: 0.9987 - val_loss: 1.6654 - val_accuracy: 0.7167
# Epoch 58/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 00058: val_accuracy did not improve from 0.72527
# 9831/9831 [==============================] - 7s 675us/sample - loss: 0.0017 - accuracy: 0.9996 - val_loss: 1.6299 - val_accuracy: 0.7212
# Epoch 59/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 00059: val_accuracy did not improve from 0.72527
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0021 - accuracy: 0.9993 - val_loss: 1.6453 - val_accuracy: 0.7216
# Epoch 60/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
#
# Epoch 00060: val_accuracy did not improve from 0.72527
# 9831/9831 [==============================] - 7s 672us/sample - loss: 0.0020 - accuracy: 0.9994 - val_loss: 1.6274 - val_accuracy: 0.7232
# Epoch 61/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996
# Epoch 00061: val_accuracy did not improve from 0.72527
# 9831/9831 [==============================] - 7s 671us/sample - loss: 0.0016 - accuracy: 0.9996 - val_loss: 1.6445 - val_accuracy: 0.7228
# Epoch 62/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997
# Epoch 00062: val_accuracy improved from 0.72527 to 0.72650, saving model to ./storage/mnist_test/kfold2/epoch_062_val_1.620_acc_0.726.h5
# 9831/9831 [==============================] - 7s 727us/sample - loss: 0.0017 - accuracy: 0.9997 - val_loss: 1.6198 - val_accuracy: 0.7265
# Epoch 63/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996
# Epoch 00063: val_accuracy improved from 0.72650 to 0.72731, saving model to ./storage/mnist_test/kfold2/epoch_063_val_1.629_acc_0.727.h5
# 9831/9831 [==============================] - 7s 715us/sample - loss: 0.0016 - accuracy: 0.9996 - val_loss: 1.6287 - val_accuracy: 0.7273
# Epoch 64/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00064: val_accuracy did not improve from 0.72731
# 9831/9831 [==============================] - 7s 674us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 1.6336 - val_accuracy: 0.7253
# Epoch 65/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 00065: val_accuracy did not improve from 0.72731
# 9831/9831 [==============================] - 7s 676us/sample - loss: 0.0014 - accuracy: 0.9996 - val_loss: 1.6410 - val_accuracy: 0.7273
# Epoch 66/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 00066: val_accuracy did not improve from 0.72731
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.0014 - accuracy: 0.9997 - val_loss: 1.6642 - val_accuracy: 0.7245
# Epoch 67/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 00067: val_accuracy did not improve from 0.72731
# 9831/9831 [==============================] - 7s 668us/sample - loss: 0.0012 - accuracy: 0.9999 - val_loss: 1.6746 - val_accuracy: 0.7265
# Epoch 68/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995
# Epoch 00068: val_accuracy did not improve from 0.72731
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0015 - accuracy: 0.9995 - val_loss: 1.6651 - val_accuracy: 0.7253
# Epoch 69/300
# ...
# 9828/9828 [==============================] - 7s 709us/sample - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.8922 - val_accuracy: 0.8313
# Epoch 74/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 00074: val_accuracy did not improve from 0.83130
# 9828/9828 [==============================] - 7s 677us/sample - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.9002 - val_accuracy: 0.8256
# Epoch 75/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 00075: val_accuracy did not improve from 0.83130
# 9828/9828 [==============================] - 7s 671us/sample - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.8945 - val_accuracy: 0.8236
# Epoch 76/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
#
# Epoch 00076: val_accuracy did not improve from 0.83130
# 9828/9828 [==============================] - 7s 671us/sample - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.8884 - val_accuracy: 0.8280
# Epoch 77/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998
# Epoch 00077: val_accuracy did not improve from 0.83130
# 9828/9828 [==============================] - 7s 669us/sample - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.8923 - val_accuracy: 0.8285
# Epoch 78/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998
# Epoch 00078: val_accuracy did not improve from 0.83130
# 9828/9828 [==============================] - 7s 673us/sample - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.8969 - val_accuracy: 0.8293
# Epoch 79/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
#
# Epoch 00079: val_accuracy did not improve from 0.83130
# 9828/9828 [==============================] - 7s 673us/sample - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.8978 - val_accuracy: 0.8285
# Epoch 80/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9994
# Epoch 00080: val_accuracy did not improve from 0.83130
# 9828/9828 [==============================] - 7s 675us/sample - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.8919 - val_accuracy: 0.8285
# Epoch 81/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9995
# Epoch 00081: val_accuracy did not improve from 0.83130
# 9828/9828 [==============================] - 7s 670us/sample - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.8916 - val_accuracy: 0.8260
# Epoch 82/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9996
# Epoch 00082: val_accuracy improved from 0.83130 to 0.83211, saving model to ./storage/mnist_test/kfold5/epoch_082_val_0.885_acc_0.832.h5
# 9828/9828 [==============================] - 7s 711us/sample - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.8852 - val_accuracy: 0.8321
# Epoch 83/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9995
# Epoch 00083: val_accuracy did not improve from 0.83211
# 9828/9828 [==============================] - 7s 675us/sample - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.8812 - val_accuracy: 0.8276
# Epoch 84/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 00084: val_accuracy did not improve from 0.83211
# 9828/9828 [==============================] - 7s 675us/sample - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.8847 - val_accuracy: 0.8301
# Epoch 85/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9992
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
#
# Epoch 00085: val_accuracy did not improve from 0.83211
# 9828/9828 [==============================] - 7s 672us/sample - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.8839 - val_accuracy: 0.8309
# Epoch 86/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 00086: val_accuracy improved from 0.83211 to 0.83252, saving model to ./storage/mnist_test/kfold5/epoch_086_val_0.878_acc_0.833.h5
# 9828/9828 [==============================] - 7s 730us/sample - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.8776 - val_accuracy: 0.8325
# Epoch 87/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 00087: val_accuracy did not improve from 0.83252
# 9828/9828 [==============================] - 7s 673us/sample - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.8766 - val_accuracy: 0.8289
# Epoch 88/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 00088: val_accuracy did not improve from 0.83252
# 9828/9828 [==============================] - 7s 663us/sample - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.8771 - val_accuracy: 0.8280
# Epoch 89/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
#
# Epoch 00089: val_accuracy did not improve from 0.83252
# 9828/9828 [==============================] - 7s 668us/sample - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.8729 - val_accuracy: 0.8321
# Epoch 90/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9997
# Epoch 00090: val_accuracy did not improve from 0.83252
# 9828/9828 [==============================] - 7s 669us/sample - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.8823 - val_accuracy: 0.8276
# Epoch 91/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.83252
# 9828/9828 [==============================] - 7s 669us/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.8828 - val_accuracy: 0.8285
# Epoch 92/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 9.9131e-04 - accuracy: 1.0000
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
#
# Epoch 00092: val_accuracy did not improve from 0.83252
# 9828/9828 [==============================] - 7s 674us/sample - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.8824 - val_accuracy: 0.8285
# Epoch 93/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 00093: val_accuracy did not improve from 0.83252
# 9828/9828 [==============================] - 7s 677us/sample - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.8719 - val_accuracy: 0.8305
# Epoch 94/300
# 9760/9828 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 00094: val_accuracy did not improve from 0.83252
# 9828/9828 [==============================] - 7s 677us/sample - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.8784 - val_accuracy: 0.8305
# Epoch 95/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
#
# Epoch 00095: val_accuracy did not improve from 0.83252
# 9828/9828 [==============================] - 7s 669us/sample - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.8791 - val_accuracy: 0.8305
# Epoch 96/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9993
# Epoch 00096: val_accuracy did not improve from 0.83252
# 9828/9828 [==============================] - 7s 668us/sample - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.8789 - val_accuracy: 0.8297
# Epoch 97/300
# 9760/9828 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9997
# Epoch 00097: val_accuracy improved from 0.83252 to 0.83293, saving model to ./storage/mnist_test/kfold5/epoch_097_val_0.868_acc_0.833.h5
# 9828/9828 [==============================] - 7s 711us/sample - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.8680 - val_accuracy: 0.8329
# Epoch 98/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 00098: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 673us/sample - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.8742 - val_accuracy: 0.8317
# Epoch 99/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 00099: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 674us/sample - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.8741 - val_accuracy: 0.8293
# Epoch 100/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
#
# Epoch 00100: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 670us/sample - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.8781 - val_accuracy: 0.8264
# Epoch 101/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9999
# Epoch 00101: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 675us/sample - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.8730 - val_accuracy: 0.8260
# Epoch 102/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00102: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 670us/sample - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.8763 - val_accuracy: 0.8293
# Epoch 103/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
#
# Epoch 00103: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 669us/sample - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.8843 - val_accuracy: 0.8285
# Epoch 104/300
# 9760/9828 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 00104: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 673us/sample - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.8757 - val_accuracy: 0.8293
# Epoch 105/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 00105: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 674us/sample - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.8721 - val_accuracy: 0.8293
# Epoch 106/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
#
# Epoch 00106: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 669us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.8778 - val_accuracy: 0.8276
# Epoch 107/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 00107: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 669us/sample - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.8738 - val_accuracy: 0.8317
# Epoch 108/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 8.2590e-04 - accuracy: 1.0000
# Epoch 00108: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 672us/sample - loss: 8.2353e-04 - accuracy: 1.0000 - val_loss: 0.8701 - val_accuracy: 0.8305
# Epoch 109/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 7.378698501270265e-06.
#
# Epoch 00109: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 674us/sample - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.8823 - val_accuracy: 0.8272
# Epoch 110/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 00110: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 671us/sample - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.8741 - val_accuracy: 0.8268
# Epoch 111/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 00111: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 665us/sample - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.8728 - val_accuracy: 0.8305
# Epoch 112/300
# 9760/9828 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00112: ReduceLROnPlateau reducing learning rate to 5.902958946535364e-06.
#
# Epoch 00112: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 672us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.8735 - val_accuracy: 0.8297
# Epoch 113/300
# 9760/9828 [============================>.] - ETA: 0s - loss: 9.2216e-04 - accuracy: 0.9999
# Epoch 00113: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 668us/sample - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.8781 - val_accuracy: 0.8272
# Epoch 114/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 8.0735e-04 - accuracy: 0.9999
# Epoch 00114: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 668us/sample - loss: 8.1276e-04 - accuracy: 0.9999 - val_loss: 0.8773 - val_accuracy: 0.8301
# Epoch 115/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9994
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 4.7223671572282915e-06.
#
# Epoch 00115: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 668us/sample - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.8779 - val_accuracy: 0.8289
# Epoch 116/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00116: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 666us/sample - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.8798 - val_accuracy: 0.8248
# Epoch 117/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 670us/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.8771 - val_accuracy: 0.8268
# Epoch 118/300
# 9760/9828 [============================>.] - ETA: 0s - loss: 9.6268e-04 - accuracy: 0.9998
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 3.7778936530230567e-06.
#
# Epoch 00118: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 668us/sample - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.8814 - val_accuracy: 0.8268
# Epoch 119/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 00119: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 670us/sample - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.8724 - val_accuracy: 0.8285
# Epoch 120/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 9.5351e-04 - accuracy: 0.9998
# Epoch 00120: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 670us/sample - loss: 9.5093e-04 - accuracy: 0.9998 - val_loss: 0.8734 - val_accuracy: 0.8293
# Epoch 121/300
# 9792/9828 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9999
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 3.0223149224184457e-06.
#
# Epoch 00121: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 670us/sample - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.8807 - val_accuracy: 0.8272
# Epoch 122/300
# 9824/9828 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 00122: val_accuracy did not improve from 0.83293
# 9828/9828 [==============================] - 7s 668us/sample - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.8797 - val_accuracy: 0.8268

# %%
# k-fold version 2, using the sklearn utility. 
# this version may score better, because it shuffles the batches 
# we can try comparing these two methods 
k_fold = KFold(n_splits=5, shuffle=True, random_state=7777)
t = 0 # for debugging and saving purposes  
for train_idx, val_idx in k_fold.split(x_train): 
    cur_val_x = x_train[val_idx] 
    cur_val_y = y_train[val_idx] 
    cur_val_letter = train_letters_numeric[val_idx] 
    
    cur_train_x = x_train[train_idx] 
    cur_train_y = y_train[train_idx] 
    cur_letter = train_letters_numeric[train_idx]  
    
    model_path = './storage/mnist_test/' + 'kfold' + str(t+1) + '_sklearn' + '/epoch_{epoch:03d}_val_{val_loss:.3f}_acc_{val_accuracy:.3f}.h5' 
    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.8)
    checkpoint = ModelCheckpoint(filepath=model_path,monitor='val_accuracy',verbose=1,save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_accuracy',patience=25)
    annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x)
    model = base_cnn_grade_4() 
    history = model.fit([cur_train_x,cur_letter],
                        cur_train_y,
                       batch_size = 32,
                       shuffle=True, 
                       validation_data = ([cur_val_x,cur_val_letter],cur_val_y),
                       verbose = 1, 
                       epochs = 300,
                       callbacks = [learning_rate_reduction, checkpoint, early_stopping])
    t += 1
# Out:
# Train on 9830 samples, validate on 2458 samples
# Epoch 1/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 2.0373 - accuracy: 0.3463
# Epoch 00001: val_accuracy improved from -inf to 0.12368, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_001_val_3.423_acc_0.124.h5
# 9830/9830 [==============================] - 13s 1ms/sample - loss: 2.0366 - accuracy: 0.3465 - val_loss: 3.4232 - val_accuracy: 0.1237
# Epoch 2/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 1.3057 - accuracy: 0.5559
# Epoch 00002: val_accuracy improved from 0.12368 to 0.60334, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_002_val_1.183_acc_0.603.h5
# 9830/9830 [==============================] - 7s 730us/sample - loss: 1.3038 - accuracy: 0.5565 - val_loss: 1.1828 - val_accuracy: 0.6033
# Epoch 3/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.9713 - accuracy: 0.6707
# Epoch 00003: val_accuracy improved from 0.60334 to 0.69894, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_003_val_0.859_acc_0.699.h5
# 9830/9830 [==============================] - 7s 721us/sample - loss: 0.9714 - accuracy: 0.6707 - val_loss: 0.8588 - val_accuracy: 0.6989
# Epoch 4/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.8838 - accuracy: 0.7008
# Epoch 00004: val_accuracy improved from 0.69894 to 0.75712, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_004_val_0.721_acc_0.757.h5
# 9830/9830 [==============================] - 7s 732us/sample - loss: 0.8835 - accuracy: 0.7009 - val_loss: 0.7210 - val_accuracy: 0.7571
# Epoch 5/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.6657 - accuracy: 0.7748
# Epoch 00005: val_accuracy improved from 0.75712 to 0.77339, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_005_val_0.644_acc_0.773.h5
# 9830/9830 [==============================] - 7s 719us/sample - loss: 0.6655 - accuracy: 0.7749 - val_loss: 0.6440 - val_accuracy: 0.7734
# Epoch 6/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.5726 - accuracy: 0.8035
# Epoch 00006: val_accuracy did not improve from 0.77339
# 9830/9830 [==============================] - 7s 689us/sample - loss: 0.5733 - accuracy: 0.8035 - val_loss: 0.6963 - val_accuracy: 0.7710
# Epoch 7/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.5003 - accuracy: 0.8314
# Epoch 00007: val_accuracy improved from 0.77339 to 0.78234, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_007_val_0.635_acc_0.782.h5
# 9830/9830 [==============================] - 7s 722us/sample - loss: 0.4996 - accuracy: 0.8316 - val_loss: 0.6354 - val_accuracy: 0.7823
# Epoch 8/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.3994 - accuracy: 0.8642
# Epoch 00008: val_accuracy did not improve from 0.78234
# 9830/9830 [==============================] - 7s 686us/sample - loss: 0.3991 - accuracy: 0.8643 - val_loss: 0.7571 - val_accuracy: 0.7518
# Epoch 9/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.3210 - accuracy: 0.8930
# Epoch 00009: val_accuracy improved from 0.78234 to 0.79292, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_009_val_0.656_acc_0.793.h5
# 9830/9830 [==============================] - 7s 754us/sample - loss: 0.3209 - accuracy: 0.8931 - val_loss: 0.6564 - val_accuracy: 0.7929
# Epoch 10/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.2657 - accuracy: 0.9104
# Epoch 00010: val_accuracy improved from 0.79292 to 0.82872, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_010_val_0.546_acc_0.829.h5
# 9830/9830 [==============================] - 7s 720us/sample - loss: 0.2676 - accuracy: 0.9102 - val_loss: 0.5463 - val_accuracy: 0.8287
# Epoch 11/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.3524 - accuracy: 0.8812
# Epoch 00011: val_accuracy did not improve from 0.82872
# 9830/9830 [==============================] - 7s 695us/sample - loss: 0.3524 - accuracy: 0.8812 - val_loss: 0.5950 - val_accuracy: 0.8275
# Epoch 12/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9349
# Epoch 00012: val_accuracy improved from 0.82872 to 0.85313, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_012_val_0.505_acc_0.853.h5
# 9830/9830 [==============================] - 7s 727us/sample - loss: 0.1989 - accuracy: 0.9352 - val_loss: 0.5054 - val_accuracy: 0.8531
# Epoch 13/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.1482 - accuracy: 0.9504
# Epoch 00013: val_accuracy did not improve from 0.85313
# 9830/9830 [==============================] - 7s 692us/sample - loss: 0.1489 - accuracy: 0.9501 - val_loss: 0.6394 - val_accuracy: 0.8165
# Epoch 14/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.1382 - accuracy: 0.9551
# Epoch 00014: val_accuracy did not improve from 0.85313
# 9830/9830 [==============================] - 7s 683us/sample - loss: 0.1387 - accuracy: 0.9549 - val_loss: 0.6298 - val_accuracy: 0.8226
# Epoch 15/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.2109 - accuracy: 0.9271
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
#
# Epoch 00015: val_accuracy did not improve from 0.85313
# 9830/9830 [==============================] - 7s 684us/sample - loss: 0.2109 - accuracy: 0.9271 - val_loss: 0.5880 - val_accuracy: 0.8369
# Epoch 16/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.1122 - accuracy: 0.9626
# Epoch 00016: val_accuracy improved from 0.85313 to 0.86046, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_016_val_0.504_acc_0.860.h5
# 9830/9830 [==============================] - 7s 728us/sample - loss: 0.1121 - accuracy: 0.9627 - val_loss: 0.5039 - val_accuracy: 0.8605
# Epoch 17/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9740
# Epoch 00017: val_accuracy did not improve from 0.86046
# 9830/9830 [==============================] - 7s 686us/sample - loss: 0.0824 - accuracy: 0.9738 - val_loss: 0.8187 - val_accuracy: 0.7905
# Epoch 18/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.1240 - accuracy: 0.9611
# Epoch 00018: val_accuracy did not improve from 0.86046
# 9830/9830 [==============================] - 7s 694us/sample - loss: 0.1240 - accuracy: 0.9611 - val_loss: 0.5990 - val_accuracy: 0.8409
# Epoch 19/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0725 - accuracy: 0.9762
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 00019: val_accuracy did not improve from 0.86046
# 9830/9830 [==============================] - 7s 687us/sample - loss: 0.0725 - accuracy: 0.9762 - val_loss: 0.5516 - val_accuracy: 0.8572
# Epoch 20/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0484 - accuracy: 0.9836
# Epoch 00020: val_accuracy did not improve from 0.86046
# 9830/9830 [==============================] - 7s 683us/sample - loss: 0.0484 - accuracy: 0.9836 - val_loss: 0.5262 - val_accuracy: 0.8600
# Epoch 21/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0386 - accuracy: 0.9879
# Epoch 00021: val_accuracy did not improve from 0.86046
# 9830/9830 [==============================] - 7s 689us/sample - loss: 0.0389 - accuracy: 0.9878 - val_loss: 0.5475 - val_accuracy: 0.8600
# Epoch 22/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0435 - accuracy: 0.9864
# Epoch 00022: val_accuracy improved from 0.86046 to 0.87185, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_022_val_0.554_acc_0.872.h5
# 9830/9830 [==============================] - 7s 725us/sample - loss: 0.0438 - accuracy: 0.9863 - val_loss: 0.5538 - val_accuracy: 0.8718
# Epoch 23/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0540 - accuracy: 0.9819
# Epoch 00023: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 677us/sample - loss: 0.0541 - accuracy: 0.9819 - val_loss: 0.6164 - val_accuracy: 0.8503
# Epoch 24/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0675 - accuracy: 0.9768
# Epoch 00024: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0676 - accuracy: 0.9768 - val_loss: 0.5846 - val_accuracy: 0.8584
# Epoch 25/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0897 - accuracy: 0.9717
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 00025: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.0913 - accuracy: 0.9715 - val_loss: 0.6226 - val_accuracy: 0.8442
# Epoch 26/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0492 - accuracy: 0.9834
# Epoch 00026: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 671us/sample - loss: 0.0498 - accuracy: 0.9833 - val_loss: 0.5895 - val_accuracy: 0.8580
# Epoch 27/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.1292 - accuracy: 0.9595
# Epoch 00027: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.1286 - accuracy: 0.9597 - val_loss: 0.5586 - val_accuracy: 0.8613
# Epoch 28/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0362 - accuracy: 0.9879
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 00028: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0360 - accuracy: 0.9880 - val_loss: 0.5234 - val_accuracy: 0.8690
# Epoch 29/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0201 - accuracy: 0.9941
# Epoch 00029: val_accuracy improved from 0.87185 to 0.87673, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_029_val_0.503_acc_0.877.h5
# 9830/9830 [==============================] - 7s 711us/sample - loss: 0.0202 - accuracy: 0.9941 - val_loss: 0.5029 - val_accuracy: 0.8767
# Epoch 30/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9949
# Epoch 00030: val_accuracy improved from 0.87673 to 0.88080, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_030_val_0.529_acc_0.881.h5
# 9830/9830 [==============================] - 7s 718us/sample - loss: 0.0164 - accuracy: 0.9948 - val_loss: 0.5291 - val_accuracy: 0.8808
# Epoch 31/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9959
# Epoch 00031: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 670us/sample - loss: 0.0162 - accuracy: 0.9959 - val_loss: 0.5459 - val_accuracy: 0.8710
# Epoch 32/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9960
# Epoch 00032: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 675us/sample - loss: 0.0129 - accuracy: 0.9960 - val_loss: 0.5075 - val_accuracy: 0.8800
# Epoch 33/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9962
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 00033: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.5675 - val_accuracy: 0.8751
# Epoch 34/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 0.9945
# Epoch 00034: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.0188 - accuracy: 0.9944 - val_loss: 0.6047 - val_accuracy: 0.8678
# Epoch 35/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0184 - accuracy: 0.9945
# Epoch 00035: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 672us/sample - loss: 0.0184 - accuracy: 0.9945 - val_loss: 0.5736 - val_accuracy: 0.8743
# Epoch 36/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0115 - accuracy: 0.9966
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 00036: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 675us/sample - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.5781 - val_accuracy: 0.8759
# Epoch 37/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9974
# Epoch 00037: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.5586 - val_accuracy: 0.8767
# Epoch 38/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0093 - accuracy: 0.9970
# Epoch 00038: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 677us/sample - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.5599 - val_accuracy: 0.8755
# Epoch 39/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9967
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 00039: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 674us/sample - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.5797 - val_accuracy: 0.8784
# Epoch 40/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9951
# Epoch 00040: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 677us/sample - loss: 0.0155 - accuracy: 0.9951 - val_loss: 0.5846 - val_accuracy: 0.8718
# Epoch 41/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9982
# Epoch 00041: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 672us/sample - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.5754 - val_accuracy: 0.8796
# Epoch 42/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9977
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# Epoch 00042: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 673us/sample - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.5788 - val_accuracy: 0.8755
# Epoch 43/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.9985
# Epoch 00043: val_accuracy did not improve from 0.88080
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.5751 - val_accuracy: 0.8804
# Epoch 44/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9983
# Epoch 00044: val_accuracy improved from 0.88080 to 0.88120, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_044_val_0.576_acc_0.881.h5
# 9830/9830 [==============================] - 7s 715us/sample - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.5755 - val_accuracy: 0.8812
# Epoch 45/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9980
# Epoch 00045: val_accuracy did not improve from 0.88120
# 9830/9830 [==============================] - 7s 683us/sample - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.5775 - val_accuracy: 0.8796
# Epoch 46/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9987
# Epoch 00046: val_accuracy did not improve from 0.88120
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.5777 - val_accuracy: 0.8796
# Epoch 47/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9993
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
#
# Epoch 00047: val_accuracy did not improve from 0.88120
# 9830/9830 [==============================] - 7s 685us/sample - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.5833 - val_accuracy: 0.8779
# Epoch 48/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9990
# Epoch 00048: val_accuracy did not improve from 0.88120
# 9830/9830 [==============================] - 7s 675us/sample - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.5895 - val_accuracy: 0.8771
# Epoch 49/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9991
# Epoch 00049: val_accuracy did not improve from 0.88120
# 9830/9830 [==============================] - 7s 677us/sample - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.5915 - val_accuracy: 0.8771
# Epoch 50/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9993
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
#
# Epoch 00050: val_accuracy did not improve from 0.88120
# 9830/9830 [==============================] - 7s 680us/sample - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.5887 - val_accuracy: 0.8796
# Epoch 51/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993
# Epoch 00051: val_accuracy did not improve from 0.88120
# 9830/9830 [==============================] - 7s 680us/sample - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.5845 - val_accuracy: 0.8792
# Epoch 52/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 00052: val_accuracy did not improve from 0.88120
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.5887 - val_accuracy: 0.8812
# Epoch 53/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9995
# Epoch 00053: val_accuracy improved from 0.88120 to 0.88405, saving model to ./storage/mnist_test/kfold1_sklearn/epoch_053_val_0.583_acc_0.884.h5
# 9830/9830 [==============================] - 7s 712us/sample - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.5830 - val_accuracy: 0.8841
# Epoch 54/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9994
# Epoch 00054: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 675us/sample - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.5984 - val_accuracy: 0.8779
# Epoch 55/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9992
# Epoch 00055: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 689us/sample - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.5833 - val_accuracy: 0.8796
# Epoch 56/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
#
# Epoch 00056: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 671us/sample - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.6064 - val_accuracy: 0.8804
# Epoch 57/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9993
# Epoch 00057: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 684us/sample - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.6087 - val_accuracy: 0.8796
# Epoch 58/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9992
# Epoch 00058: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 683us/sample - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.6321 - val_accuracy: 0.8763
# Epoch 59/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9995
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 00059: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 675us/sample - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.6183 - val_accuracy: 0.8763
# Epoch 60/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994
# Epoch 00060: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 680us/sample - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.6149 - val_accuracy: 0.8767
# Epoch 61/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9990
# Epoch 00061: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 673us/sample - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.6075 - val_accuracy: 0.8767
# Epoch 62/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
#
# Epoch 00062: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 672us/sample - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.6011 - val_accuracy: 0.8788
# Epoch 63/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 00063: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.5944 - val_accuracy: 0.8796
# Epoch 64/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 00064: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 673us/sample - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.5985 - val_accuracy: 0.8784
# Epoch 65/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
#
# Epoch 00065: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 671us/sample - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.6217 - val_accuracy: 0.8767
# Epoch 66/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 00066: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.6190 - val_accuracy: 0.8788
# Epoch 67/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 00067: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 672us/sample - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.6061 - val_accuracy: 0.8784
# Epoch 68/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
#
# Epoch 00068: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 682us/sample - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.6047 - val_accuracy: 0.8767
# Epoch 69/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 00069: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 671us/sample - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.6035 - val_accuracy: 0.8788
# Epoch 70/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993
# Epoch 00070: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 672us/sample - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.6051 - val_accuracy: 0.8804
# Epoch 71/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9999
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
#
# Epoch 00071: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 674us/sample - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.6055 - val_accuracy: 0.8800
# Epoch 72/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9997
# Epoch 00072: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 675us/sample - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.6030 - val_accuracy: 0.8796
# Epoch 73/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 00073: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.6028 - val_accuracy: 0.8808
# Epoch 74/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9999
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
#
# Epoch 00074: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 672us/sample - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.5969 - val_accuracy: 0.8804
# Epoch 75/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 00075: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 677us/sample - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.5927 - val_accuracy: 0.8804
# Epoch 76/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9999
# Epoch 00076: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 678us/sample - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.5913 - val_accuracy: 0.8808
# Epoch 77/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 7.7694e-04 - accuracy: 1.0000
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
#
# Epoch 00077: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 677us/sample - loss: 9.6488e-04 - accuracy: 0.9999 - val_loss: 0.5987 - val_accuracy: 0.8800
# Epoch 78/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 9.6048e-04 - accuracy: 0.9997
# Epoch 00078: val_accuracy did not improve from 0.88405
# 9830/9830 [==============================] - 7s 671us/sample - loss: 9.6079e-04 - accuracy: 0.9997 - val_loss: 0.5938 - val_accuracy: 0.8804
# Train on 9830 samples, validate on 2458 samples
# Epoch 1/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 2.0383 - accuracy: 0.3381
# Epoch 00001: val_accuracy improved from -inf to 0.16762, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_001_val_3.328_acc_0.168.h5
# 9830/9830 [==============================] - 11s 1ms/sample - loss: 2.0376 - accuracy: 0.3384 - val_loss: 3.3282 - val_accuracy: 0.1676
# Epoch 2/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 1.2727 - accuracy: 0.5711
# Epoch 00002: val_accuracy improved from 0.16762 to 0.61269, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_002_val_1.161_acc_0.613.h5
# 9830/9830 [==============================] - 7s 730us/sample - loss: 1.2717 - accuracy: 0.5712 - val_loss: 1.1607 - val_accuracy: 0.6127
# Epoch 3/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 1.0265 - accuracy: 0.6467
# Epoch 00003: val_accuracy improved from 0.61269 to 0.61798, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_003_val_1.143_acc_0.618.h5
# 9830/9830 [==============================] - 7s 717us/sample - loss: 1.0261 - accuracy: 0.6469 - val_loss: 1.1426 - val_accuracy: 0.6180
# Epoch 4/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.8017 - accuracy: 0.7313
# Epoch 00004: val_accuracy improved from 0.61798 to 0.73515, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_004_val_0.808_acc_0.735.h5
# 9830/9830 [==============================] - 7s 717us/sample - loss: 0.8019 - accuracy: 0.7310 - val_loss: 0.8084 - val_accuracy: 0.7352
# Epoch 5/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.6690 - accuracy: 0.7698
# Epoch 00005: val_accuracy improved from 0.73515 to 0.73759, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_005_val_0.786_acc_0.738.h5
# 9830/9830 [==============================] - 7s 748us/sample - loss: 0.6682 - accuracy: 0.7703 - val_loss: 0.7859 - val_accuracy: 0.7376
# Epoch 6/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.5245 - accuracy: 0.8233
# Epoch 00006: val_accuracy improved from 0.73759 to 0.75834, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_006_val_0.724_acc_0.758.h5
# 9830/9830 [==============================] - 7s 709us/sample - loss: 0.5247 - accuracy: 0.8233 - val_loss: 0.7240 - val_accuracy: 0.7583
# Epoch 7/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.4609 - accuracy: 0.8435
# Epoch 00007: val_accuracy improved from 0.75834 to 0.76526, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_007_val_0.727_acc_0.765.h5
# 9830/9830 [==============================] - 7s 746us/sample - loss: 0.4599 - accuracy: 0.8440 - val_loss: 0.7273 - val_accuracy: 0.7653
# Epoch 8/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.3645 - accuracy: 0.8801
# Epoch 00008: val_accuracy improved from 0.76526 to 0.78072, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_008_val_0.668_acc_0.781.h5
# 9830/9830 [==============================] - 7s 740us/sample - loss: 0.3648 - accuracy: 0.8801 - val_loss: 0.6676 - val_accuracy: 0.7807
# Epoch 9/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.3509 - accuracy: 0.8861
# Epoch 00009: val_accuracy did not improve from 0.78072
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.3521 - accuracy: 0.8859 - val_loss: 1.0508 - val_accuracy: 0.7091
# Epoch 10/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.3472 - accuracy: 0.8813
# Epoch 00010: val_accuracy improved from 0.78072 to 0.78926, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_010_val_0.713_acc_0.789.h5
# 9830/9830 [==============================] - 7s 752us/sample - loss: 0.3474 - accuracy: 0.8812 - val_loss: 0.7128 - val_accuracy: 0.7893
# Epoch 11/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.2417 - accuracy: 0.9173
# Epoch 00011: val_accuracy improved from 0.78926 to 0.80106, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_011_val_0.701_acc_0.801.h5
# 9830/9830 [==============================] - 7s 721us/sample - loss: 0.2418 - accuracy: 0.9172 - val_loss: 0.7006 - val_accuracy: 0.8011
# Epoch 12/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.2283 - accuracy: 0.9249
# Epoch 00012: val_accuracy improved from 0.80106 to 0.83483, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_012_val_0.614_acc_0.835.h5
# 9830/9830 [==============================] - 7s 722us/sample - loss: 0.2282 - accuracy: 0.9248 - val_loss: 0.6137 - val_accuracy: 0.8348
# Epoch 13/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.9461
# Epoch 00013: val_accuracy did not improve from 0.83483
# 9830/9830 [==============================] - 7s 677us/sample - loss: 0.1657 - accuracy: 0.9459 - val_loss: 0.6569 - val_accuracy: 0.8129
# Epoch 14/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.1510 - accuracy: 0.9503
# Epoch 00014: val_accuracy did not improve from 0.83483
# 9830/9830 [==============================] - 7s 672us/sample - loss: 0.1509 - accuracy: 0.9504 - val_loss: 0.6977 - val_accuracy: 0.8173
# Epoch 15/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.1759 - accuracy: 0.9436
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
#
# Epoch 00015: val_accuracy did not improve from 0.83483
# 9830/9830 [==============================] - 7s 686us/sample - loss: 0.1758 - accuracy: 0.9436 - val_loss: 0.6222 - val_accuracy: 0.8344
# Epoch 16/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.1122 - accuracy: 0.9622
# Epoch 00016: val_accuracy improved from 0.83483 to 0.84906, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_016_val_0.566_acc_0.849.h5
# 9830/9830 [==============================] - 7s 750us/sample - loss: 0.1122 - accuracy: 0.9622 - val_loss: 0.5660 - val_accuracy: 0.8491
# Epoch 17/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9731
# Epoch 00017: val_accuracy did not improve from 0.84906
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.0826 - accuracy: 0.9731 - val_loss: 0.6633 - val_accuracy: 0.8336
# Epoch 18/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0546 - accuracy: 0.9832
# Epoch 00018: val_accuracy did not improve from 0.84906
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0546 - accuracy: 0.9832 - val_loss: 0.6200 - val_accuracy: 0.8446
# Epoch 19/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0677 - accuracy: 0.9777
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 00019: val_accuracy did not improve from 0.84906
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0677 - accuracy: 0.9778 - val_loss: 0.6379 - val_accuracy: 0.8417
# Epoch 20/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0680 - accuracy: 0.9779
# Epoch 00020: val_accuracy improved from 0.84906 to 0.85679, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_020_val_0.624_acc_0.857.h5
# 9830/9830 [==============================] - 7s 725us/sample - loss: 0.0691 - accuracy: 0.9777 - val_loss: 0.6237 - val_accuracy: 0.8568
# Epoch 21/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9610
# Epoch 00021: val_accuracy did not improve from 0.85679
# 9830/9830 [==============================] - 7s 677us/sample - loss: 0.1175 - accuracy: 0.9609 - val_loss: 0.7457 - val_accuracy: 0.8234
# Epoch 22/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9782
# Epoch 00022: val_accuracy improved from 0.85679 to 0.86086, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_022_val_0.621_acc_0.861.h5
# 9830/9830 [==============================] - 7s 719us/sample - loss: 0.0697 - accuracy: 0.9783 - val_loss: 0.6213 - val_accuracy: 0.8609
# Epoch 23/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9902
# Epoch 00023: val_accuracy did not improve from 0.86086
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.0322 - accuracy: 0.9900 - val_loss: 0.6286 - val_accuracy: 0.8576
# Epoch 24/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0949 - accuracy: 0.9682
# Epoch 00024: val_accuracy did not improve from 0.86086
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0949 - accuracy: 0.9683 - val_loss: 0.7187 - val_accuracy: 0.8324
# Epoch 25/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9861
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 00025: val_accuracy did not improve from 0.86086
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0423 - accuracy: 0.9861 - val_loss: 0.6500 - val_accuracy: 0.8568
# Epoch 26/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9914
# Epoch 00026: val_accuracy did not improve from 0.86086
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.0310 - accuracy: 0.9914 - val_loss: 0.6476 - val_accuracy: 0.8515
# Epoch 27/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0530 - accuracy: 0.9808
# Epoch 00027: val_accuracy did not improve from 0.86086
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0530 - accuracy: 0.9808 - val_loss: 0.6720 - val_accuracy: 0.8442
# Epoch 28/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9888
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 00028: val_accuracy did not improve from 0.86086
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0320 - accuracy: 0.9887 - val_loss: 0.6483 - val_accuracy: 0.8572
# Epoch 29/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0200 - accuracy: 0.9942
# Epoch 00029: val_accuracy improved from 0.86086 to 0.86249, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_029_val_0.644_acc_0.862.h5
# 9830/9830 [==============================] - 7s 724us/sample - loss: 0.0200 - accuracy: 0.9942 - val_loss: 0.6435 - val_accuracy: 0.8625
# Epoch 30/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9944
# Epoch 00030: val_accuracy improved from 0.86249 to 0.86656, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_030_val_0.643_acc_0.867.h5
# 9830/9830 [==============================] - 7s 716us/sample - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.6428 - val_accuracy: 0.8666
# Epoch 31/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9964
# Epoch 00031: val_accuracy did not improve from 0.86656
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.6676 - val_accuracy: 0.8645
# Epoch 32/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0133 - accuracy: 0.9965
# Epoch 00032: val_accuracy did not improve from 0.86656
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0140 - accuracy: 0.9964 - val_loss: 0.6627 - val_accuracy: 0.8637
# Epoch 33/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0145 - accuracy: 0.9954
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 00033: val_accuracy did not improve from 0.86656
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.6851 - val_accuracy: 0.8633
# Epoch 34/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0335 - accuracy: 0.9892
# Epoch 00034: val_accuracy did not improve from 0.86656
# 9830/9830 [==============================] - 7s 678us/sample - loss: 0.0347 - accuracy: 0.9891 - val_loss: 0.6864 - val_accuracy: 0.8572
# Epoch 35/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9945
# Epoch 00035: val_accuracy did not improve from 0.86656
# 9830/9830 [==============================] - 7s 678us/sample - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.6593 - val_accuracy: 0.8617
# Epoch 36/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0141 - accuracy: 0.9955
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 00036: val_accuracy did not improve from 0.86656
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0157 - accuracy: 0.9952 - val_loss: 0.6590 - val_accuracy: 0.8666
# Epoch 37/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0212 - accuracy: 0.9924
# Epoch 00037: val_accuracy did not improve from 0.86656
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0213 - accuracy: 0.9923 - val_loss: 0.6601 - val_accuracy: 0.8645
# Epoch 38/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9977
# Epoch 00038: val_accuracy did not improve from 0.86656
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0092 - accuracy: 0.9975 - val_loss: 0.6782 - val_accuracy: 0.8588
# Epoch 39/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0212 - accuracy: 0.9925
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 00039: val_accuracy did not improve from 0.86656
# 9830/9830 [==============================] - 7s 680us/sample - loss: 0.0210 - accuracy: 0.9926 - val_loss: 0.6910 - val_accuracy: 0.8564
# Epoch 40/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9970
# Epoch 00040: val_accuracy improved from 0.86656 to 0.86696, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_040_val_0.664_acc_0.867.h5
# 9830/9830 [==============================] - 7s 750us/sample - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.6644 - val_accuracy: 0.8670
# Epoch 41/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9990
# Epoch 00041: val_accuracy did not improve from 0.86696
# 9830/9830 [==============================] - 7s 680us/sample - loss: 0.0062 - accuracy: 0.9990 - val_loss: 0.6515 - val_accuracy: 0.8649
# Epoch 42/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9982
# Epoch 00042: val_accuracy did not improve from 0.86696
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.6704 - val_accuracy: 0.8662
# Epoch 43/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9964
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# Epoch 00043: val_accuracy did not improve from 0.86696
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0126 - accuracy: 0.9962 - val_loss: 0.6968 - val_accuracy: 0.8653
# Epoch 44/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0110 - accuracy: 0.9967
# Epoch 00044: val_accuracy did not improve from 0.86696
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.6744 - val_accuracy: 0.8637
# Epoch 45/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0110 - accuracy: 0.9971
# Epoch 00045: val_accuracy improved from 0.86696 to 0.86900, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_045_val_0.671_acc_0.869.h5
# 9830/9830 [==============================] - 7s 736us/sample - loss: 0.0112 - accuracy: 0.9969 - val_loss: 0.6706 - val_accuracy: 0.8690
# Epoch 46/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9985
# Epoch 00046: val_accuracy did not improve from 0.86900
# 9830/9830 [==============================] - 7s 684us/sample - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.6625 - val_accuracy: 0.8674
# Epoch 47/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9991
# Epoch 00047: val_accuracy did not improve from 0.86900
# 9830/9830 [==============================] - 7s 685us/sample - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.6670 - val_accuracy: 0.8690
# Epoch 48/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9989
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
#
# Epoch 00048: val_accuracy did not improve from 0.86900
# 9830/9830 [==============================] - 7s 681us/sample - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.6747 - val_accuracy: 0.8678
# Epoch 49/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0037 - accuracy: 0.9989
# Epoch 00049: val_accuracy improved from 0.86900 to 0.87185, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_049_val_0.665_acc_0.872.h5
# 9830/9830 [==============================] - 7s 718us/sample - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.6647 - val_accuracy: 0.8718
# Epoch 50/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0037 - accuracy: 0.9994
# Epoch 00050: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 685us/sample - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.6789 - val_accuracy: 0.8686
# Epoch 51/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9994
# Epoch 00051: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 684us/sample - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.6705 - val_accuracy: 0.8718
# Epoch 52/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9987
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
#
# Epoch 00052: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 677us/sample - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.6836 - val_accuracy: 0.8690
# Epoch 53/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9989
# Epoch 00053: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 678us/sample - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.6821 - val_accuracy: 0.8649
# Epoch 54/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9993
# Epoch 00054: val_accuracy did not improve from 0.87185
# 9830/9830 [==============================] - 7s 684us/sample - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.6696 - val_accuracy: 0.8702
# Epoch 55/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 00055: val_accuracy improved from 0.87185 to 0.87225, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_055_val_0.673_acc_0.872.h5
# 9830/9830 [==============================] - 7s 715us/sample - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.6725 - val_accuracy: 0.8723
# Epoch 56/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9993
# Epoch 00056: val_accuracy did not improve from 0.87225
# 9830/9830 [==============================] - 7s 678us/sample - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.6764 - val_accuracy: 0.8706
# Epoch 57/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9995
# Epoch 00057: val_accuracy improved from 0.87225 to 0.87307, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_057_val_0.668_acc_0.873.h5
# 9830/9830 [==============================] - 7s 719us/sample - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.6680 - val_accuracy: 0.8731
# Epoch 58/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9995
# Epoch 00058: val_accuracy did not improve from 0.87307
# 9830/9830 [==============================] - 7s 685us/sample - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.6900 - val_accuracy: 0.8710
# Epoch 59/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995
# Epoch 00059: val_accuracy did not improve from 0.87307
# 9830/9830 [==============================] - 7s 682us/sample - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.6683 - val_accuracy: 0.8714
# Epoch 60/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
#
# Epoch 00060: val_accuracy did not improve from 0.87307
# 9830/9830 [==============================] - 7s 673us/sample - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.6827 - val_accuracy: 0.8686
# Epoch 61/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 00061: val_accuracy did not improve from 0.87307
# 9830/9830 [==============================] - 7s 679us/sample - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.6858 - val_accuracy: 0.8706
# Epoch 62/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 00062: val_accuracy did not improve from 0.87307
# 9830/9830 [==============================] - 7s 683us/sample - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.6807 - val_accuracy: 0.8714
# Epoch 63/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9993
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 00063: val_accuracy did not improve from 0.87307
# 9830/9830 [==============================] - 7s 676us/sample - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.6809 - val_accuracy: 0.8690
# Epoch 64/300
# 9760/9830 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993
# Epoch 00064: val_accuracy did not improve from 0.87307
# 9830/9830 [==============================] - 7s 683us/sample - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.6750 - val_accuracy: 0.8710
# Epoch 65/300
# 9792/9830 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9997
# Epoch 00065: val_accuracy improved from 0.87307 to 0.87469, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_065_val_0.669_acc_0.875.h5
# 9830/9830 [==============================] - 7s 754us/sample - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.6695 - val_accuracy: 0.8747
# Epoch 66/300
# 9824/9830 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996
# Epoch 00066: val_accuracy improved from 0.87469 to 0.87632, saving model to ./storage/mnist_test/kfold2_sklearn/epoch_066_val_0.669_acc_0.876.h5
# 9830/9830 [==============================] - 7s 750us/sample - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.6689 - val_accuracy: 0.8763
# ...
# Epoch 65/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9994
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 00065: val_accuracy did not improve from 0.89337
# 9831/9831 [==============================] - 7s 682us/sample - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.5657 - val_accuracy: 0.8860
# Epoch 66/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9991
# Epoch 00066: val_accuracy did not improve from 0.89337
# 9831/9831 [==============================] - 7s 681us/sample - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.5561 - val_accuracy: 0.8893
# Epoch 67/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9992
# Epoch 00067: val_accuracy did not improve from 0.89337
# 9831/9831 [==============================] - 7s 676us/sample - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.5503 - val_accuracy: 0.8913
# Epoch 68/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9998
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
#
# Epoch 00068: val_accuracy did not improve from 0.89337
# 9831/9831 [==============================] - 7s 679us/sample - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.5511 - val_accuracy: 0.8926
# Epoch 69/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997
# Epoch 00069: val_accuracy did not improve from 0.89337
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.5475 - val_accuracy: 0.8901
# Epoch 70/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9994
# Epoch 00070: val_accuracy did not improve from 0.89337
# 9831/9831 [==============================] - 7s 683us/sample - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.5431 - val_accuracy: 0.8901
# Epoch 71/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
#
# Epoch 00071: val_accuracy did not improve from 0.89337
# 9831/9831 [==============================] - 7s 681us/sample - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.5411 - val_accuracy: 0.8930
# Epoch 72/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9996
# Epoch 00072: val_accuracy did not improve from 0.89337
# 9831/9831 [==============================] - 7s 679us/sample - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.5390 - val_accuracy: 0.8930
# Epoch 73/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9997
# Epoch 00073: val_accuracy did not improve from 0.89337
# 9831/9831 [==============================] - 7s 682us/sample - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.5395 - val_accuracy: 0.8917
# Epoch 74/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 9.0634e-04 - accuracy: 0.9998
# Epoch 00074: val_accuracy improved from 0.89337 to 0.89377, saving model to ./storage/mnist_test/kfold5_sklearn/epoch_074_val_0.538_acc_0.894.h5
# 9831/9831 [==============================] - 7s 716us/sample - loss: 9.0574e-04 - accuracy: 0.9998 - val_loss: 0.5382 - val_accuracy: 0.8938
# Epoch 75/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 00075: val_accuracy did not improve from 0.89377
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.5371 - val_accuracy: 0.8909
# Epoch 76/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00076: val_accuracy improved from 0.89377 to 0.89418, saving model to ./storage/mnist_test/kfold5_sklearn/epoch_076_val_0.546_acc_0.894.h5
# 9831/9831 [==============================] - 7s 722us/sample - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.5460 - val_accuracy: 0.8942
# Epoch 77/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 8.5011e-04 - accuracy: 0.9999
# Epoch 00077: val_accuracy did not improve from 0.89418
# 9831/9831 [==============================] - 7s 677us/sample - loss: 8.4983e-04 - accuracy: 0.9999 - val_loss: 0.5492 - val_accuracy: 0.8938
# Epoch 78/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 00078: val_accuracy did not improve from 0.89418
# 9831/9831 [==============================] - 7s 682us/sample - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.5530 - val_accuracy: 0.8921
# Epoch 79/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997
# Epoch 00079: val_accuracy improved from 0.89418 to 0.89459, saving model to ./storage/mnist_test/kfold5_sklearn/epoch_079_val_0.549_acc_0.895.h5
# 9831/9831 [==============================] - 7s 722us/sample - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.5490 - val_accuracy: 0.8946
# Epoch 80/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00080: val_accuracy did not improve from 0.89459
# 9831/9831 [==============================] - 7s 673us/sample - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.5493 - val_accuracy: 0.8938
# Epoch 81/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00081: val_accuracy did not improve from 0.89459
# 9831/9831 [==============================] - 7s 682us/sample - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.5456 - val_accuracy: 0.8942
# Epoch 82/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998
# Epoch 00082: val_accuracy improved from 0.89459 to 0.89499, saving model to ./storage/mnist_test/kfold5_sklearn/epoch_082_val_0.553_acc_0.895.h5
# 9831/9831 [==============================] - 7s 718us/sample - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.5529 - val_accuracy: 0.8950
# Epoch 83/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 00083: val_accuracy did not improve from 0.89499
# 9831/9831 [==============================] - 7s 679us/sample - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.5555 - val_accuracy: 0.8934
# Epoch 84/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9999
# Epoch 00084: val_accuracy improved from 0.89499 to 0.89540, saving model to ./storage/mnist_test/kfold5_sklearn/epoch_084_val_0.557_acc_0.895.h5
# 9831/9831 [==============================] - 7s 737us/sample - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.5569 - val_accuracy: 0.8954
# Epoch 85/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 00085: val_accuracy did not improve from 0.89540
# 9831/9831 [==============================] - 7s 679us/sample - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.5572 - val_accuracy: 0.8930
# Epoch 86/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995
# Epoch 00086: val_accuracy did not improve from 0.89540
# 9831/9831 [==============================] - 7s 682us/sample - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.5515 - val_accuracy: 0.8938
# Epoch 87/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 8.6375e-04 - accuracy: 0.9999
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
#
# Epoch 00087: val_accuracy did not improve from 0.89540
# 9831/9831 [==============================] - 7s 683us/sample - loss: 8.6067e-04 - accuracy: 0.9999 - val_loss: 0.5505 - val_accuracy: 0.8938
# Epoch 88/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 9.4952e-04 - accuracy: 0.9999
# Epoch 00088: val_accuracy improved from 0.89540 to 0.89662, saving model to ./storage/mnist_test/kfold5_sklearn/epoch_088_val_0.553_acc_0.897.h5
# 9831/9831 [==============================] - 7s 713us/sample - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.5528 - val_accuracy: 0.8966
# Epoch 89/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00089: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 681us/sample - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.5536 - val_accuracy: 0.8946
# Epoch 90/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 7.9357e-04 - accuracy: 0.9999
# Epoch 00090: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 687us/sample - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.5546 - val_accuracy: 0.8938
# Epoch 91/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
#
# Epoch 00091: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 682us/sample - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.5600 - val_accuracy: 0.8926
# Epoch 92/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00092: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 686us/sample - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.5556 - val_accuracy: 0.8926
# Epoch 93/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9997
# Epoch 00093: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 682us/sample - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.5586 - val_accuracy: 0.8917
# Epoch 94/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 9.2028e-04 - accuracy: 0.9998
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
#
# Epoch 00094: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 677us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.5562 - val_accuracy: 0.8893
# Epoch 95/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 9.9839e-04 - accuracy: 0.9998
# Epoch 00095: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 679us/sample - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.5568 - val_accuracy: 0.8905
# Epoch 96/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 9.6141e-04 - accuracy: 0.9999
# Epoch 00096: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 686us/sample - loss: 9.6098e-04 - accuracy: 0.9999 - val_loss: 0.5519 - val_accuracy: 0.8917
# Epoch 97/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9997
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
#
# Epoch 00097: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 685us/sample - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.5538 - val_accuracy: 0.8921
# Epoch 98/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 9.3430e-04 - accuracy: 0.9998
# Epoch 00098: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 691us/sample - loss: 9.3382e-04 - accuracy: 0.9998 - val_loss: 0.5504 - val_accuracy: 0.8938
# Epoch 99/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 00099: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 698us/sample - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.5519 - val_accuracy: 0.8913
# Epoch 100/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9997
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
#
# Epoch 00100: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 693us/sample - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.5487 - val_accuracy: 0.8917
# Epoch 101/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 00101: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 693us/sample - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.5534 - val_accuracy: 0.8930
# Epoch 102/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 5.8904e-04 - accuracy: 1.0000
# Epoch 00102: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 692us/sample - loss: 6.6944e-04 - accuracy: 1.0000 - val_loss: 0.5481 - val_accuracy: 0.8917
# Epoch 103/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 5.2603e-04 - accuracy: 0.9999
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
#
# Epoch 00103: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 688us/sample - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.5480 - val_accuracy: 0.8934
# Epoch 104/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 6.5702e-04 - accuracy: 0.9999
# Epoch 00104: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 691us/sample - loss: 6.5703e-04 - accuracy: 0.9999 - val_loss: 0.5461 - val_accuracy: 0.8934
# Epoch 105/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 5.6633e-04 - accuracy: 1.0000
# Epoch 00105: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 690us/sample - loss: 5.6634e-04 - accuracy: 1.0000 - val_loss: 0.5475 - val_accuracy: 0.8938
# Epoch 106/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 7.2598e-04 - accuracy: 0.9999
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
#
# Epoch 00106: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 693us/sample - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.5451 - val_accuracy: 0.8938
# Epoch 107/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 7.0532e-04 - accuracy: 0.9999
# Epoch 00107: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 694us/sample - loss: 7.6082e-04 - accuracy: 0.9999 - val_loss: 0.5431 - val_accuracy: 0.8938
# Epoch 108/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 6.7648e-04 - accuracy: 0.9998
# Epoch 00108: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 697us/sample - loss: 6.7462e-04 - accuracy: 0.9998 - val_loss: 0.5428 - val_accuracy: 0.8946
# Epoch 109/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 7.378698501270265e-06.
#
# Epoch 00109: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 690us/sample - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.5417 - val_accuracy: 0.8934
# Epoch 110/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 7.3808e-04 - accuracy: 0.9999
# Epoch 00110: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 694us/sample - loss: 7.5370e-04 - accuracy: 0.9999 - val_loss: 0.5432 - val_accuracy: 0.8950
# Epoch 111/300
# 9824/9831 [============================>.] - ETA: 0s - loss: 9.3448e-04 - accuracy: 0.9998
# Epoch 00111: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 690us/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.5452 - val_accuracy: 0.8946
# Epoch 112/300
# 9760/9831 [============================>.] - ETA: 0s - loss: 5.8616e-04 - accuracy: 1.0000
# Epoch 00112: ReduceLROnPlateau reducing learning rate to 5.902958946535364e-06.
#
# Epoch 00112: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 691us/sample - loss: 6.2078e-04 - accuracy: 1.0000 - val_loss: 0.5419 - val_accuracy: 0.8934
# Epoch 113/300
# 9792/9831 [============================>.] - ETA: 0s - loss: 6.3366e-04 - accuracy: 1.0000
# Epoch 00113: val_accuracy did not improve from 0.89662
# 9831/9831 [==============================] - 7s 690us/sample - loss: 6.6643e-04 - accuracy: 1.0000 - val_loss: 0.5425 - val_accuracy: 0.8938

# %% [markdown]
# ### Make prediction for the non-shuffling k-fold method

# %%
model1 = load_model('./storage/mnist_test/kfold1/epoch_052_val_0.181_acc_0.971.h5')
model2 = load_model('./storage/mnist_test/kfold2/epoch_162_val_1.666_acc_0.732.h5')
model3 = load_model('./storage/mnist_test/kfold3/epoch_048_val_0.651_acc_0.882.h5')
model4 = load_model('./storage/mnist_test/kfold4/epoch_072_val_1.140_acc_0.793.h5')
model5 = load_model('./storage/mnist_test/kfold5/epoch_097_val_0.868_acc_0.833.h5')

pred1 = model1.predict([x_test, test_letters_numeric])
pred2 = model2.predict([x_test, test_letters_numeric])
pred3 = model3.predict([x_test, test_letters_numeric])
pred4 = model4.predict([x_test, test_letters_numeric])
pred5 = model5.predict([x_test, test_letters_numeric])

pred_avg = (pred1+pred2+pred3+pred4+pred5)/5.0

# %%
result_arr = [] 
for pred in pred_avg: 
    result_arr.append(np.argmax(pred))
result_arr = np.asarray(result_arr)
result_arr
# Out:
# array([6, 9, 8, ..., 6, 8, 0])

# %%
submission['digit'] = result_arr
submission.head()
# Out:
#      id  digit
# 0  2049      6
# 1  2050      9
# 2  2051      8
# 3  2052      0
# 4  2053      3

# %%
submission.to_csv('./storage/augmented_custom_kfold.csv',index=False)

# %% [markdown]
# ### Make prediction for the shuffling k-fold method

# %%
model1 = load_model('./storage/mnist_test/kfold1_sklearn/epoch_053_val_0.583_acc_0.884.h5')
model2 = load_model('./storage/mnist_test/kfold2_sklearn/epoch_071_val_0.684_acc_0.880.h5')
model3 = load_model('./storage/mnist_test/kfold3_sklearn/epoch_077_val_0.583_acc_0.893.h5')
model4 = load_model('./storage/mnist_test/kfold4_sklearn/epoch_065_val_0.603_acc_0.887.h5')
model5 = load_model('./storage/mnist_test/kfold5_sklearn/epoch_088_val_0.553_acc_0.897.h5')

pred1 = model1.predict([x_test, test_letters_numeric])
pred2 = model2.predict([x_test, test_letters_numeric])
pred3 = model3.predict([x_test, test_letters_numeric])
pred4 = model4.predict([x_test, test_letters_numeric])
pred5 = model5.predict([x_test, test_letters_numeric])

pred_avg = (pred1+pred2+pred3+pred4+pred5)/5.0

# %%
result_arr = [] 
for pred in pred_avg: 
    result_arr.append(np.argmax(pred))
result_arr = np.asarray(result_arr)
result_arr
# Out:
# array([6, 3, 8, ..., 6, 1, 0])

# %%
submission['digit'] = result_arr
submission.head()
# Out:
#      id  digit
# 0  2049      6
# 1  2050      3
# 2  2051      8
# 3  2052      0
# 4  2053      3

# %%
submission.to_csv('./storage/augmented_sklearn_kfold.csv',index=False)

# %% [markdown]
# Interesting reads and references :
# - https://www.kdnuggets.com/2018/09/dropout-convolutional-networks.html
# - https://kangbk0120.github.io/articles/2018-01/inception-googlenet-review
