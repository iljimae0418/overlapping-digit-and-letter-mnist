# %%
# environment: Paperspace Quadro P6000 GPU  
import numpy as np 
import pandas as pd 
import os 
import tensorflow as tf
import tensorflow.keras # run pip install keras==2.3 beforehand for compatability 
from tensorflow.keras import Input, Model 
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, AlphaDropout, MaxPooling2D, AveragePooling2D, BatchNormalization, Concatenate, Flatten, Reshape, Add, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from keras.utils.np_utils import to_categorical
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import skimage
from skimage.transform import rotate
from skimage.util import random_noise
from skimage.transform import warp, AffineTransform
from skimage.transform import resize
import cv2
import random 
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.utils import shuffle # shuffle dataset before splitting into folds 
from scipy.ndimage.filters import gaussian_filter # for elastic distortion 
from scipy.ndimage.interpolation import map_coordinates # for elastic distortion
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Read in file and preprocess data

# %%
train_path = './storage/modified_mnist_dataset/train.csv'  
test_path = './storage/modified_mnist_dataset/test.csv' 
submission_path = './storage/modified_mnist_dataset/submission.csv'

# %%
train = pd.read_csv(train_path)
test = pd.read_csv(test_path) 
submission = pd.read_csv(submission_path)

# %%
# convert types of digit and letter columns to categorical 
train.iloc[:,1] = pd.Categorical(train.iloc[:,1])
train.iloc[:,2] = pd.Categorical(train.iloc[:,2]) 
test.iloc[:,1] = pd.Categorical(test.iloc[:,1])

# %%
# convert types of digit and letter columns to categorical 
train.iloc[:,1] = pd.Categorical(train.iloc[:,1])
train.iloc[:,2] = pd.Categorical(train.iloc[:,2]) 
test.iloc[:,1] = pd.Categorical(test.iloc[:,1])

# define and re-format train and test data 
x_train = train.iloc[:,3:].values.reshape(-1,28,28,1).astype(np.float32) 
y_train = train.iloc[:,1].values
y_train = np.asarray(y_train)
y_train = to_categorical(y_train, num_classes = 10)
train_letters = train.iloc[:,2].values

x_test = test.iloc[:,2:].values.reshape(-1,28,28,1).astype(np.float32)  
test_letters = test.iloc[:,1].values

# %%
train_letters_numeric = [] 
test_letters_numeric = [] 
for letter in train_letters: 
    train_letters_numeric.append(ord(letter) - ord("A"))
for letter in test_letters: 
    test_letters_numeric.append(ord(letter) - ord("A")) 
    
train_letters_numeric = np.asarray(train_letters_numeric) 
test_letters_numeric = np.asarray(test_letters_numeric) 

train_letters_numeric = to_categorical(train_letters_numeric, num_classes = 26) 
test_letters_numeric = to_categorical(test_letters_numeric, num_classes = 26)

x_train.shape, y_train.shape, x_test.shape, train_letters_numeric.shape, test_letters_numeric.shape
# Out:
# ((2048, 28, 28, 1), (2048, 10), (20480, 28, 28, 1), (2048, 26), (20480, 26))

# %%
# min-max scaling 
x_train /= 255.0 
x_test /= 255.0

# %% [markdown]
# # Augment Data
#
# For now, we will try augmenting the data using the following methods
# - rotation
# - adding noise
# - adding gaussian blur
# - shifting image
#
# Please refer to [this notebook](https://github.com/iljimae0418/overlapping-digit-and-letter-mnist/blob/master/Examples%20of%20data%20augmentations.ipynb) for examples.
#
# Some more augmentations were decided to be added. They are
# - modifying brightness
# - ZCA Whitening
# - random crops
# - elastic distortions
# - Autoencoder generated images
#
# some more augmentations that are being planned are
# - GAN generated images
#
# Please refer to [this notebook](https://github.com/iljimae0418/overlapping-digit-and-letter-mnist/blob/master/Examples%20of%20augmentation%202%20(further%20augmentation).ipynb) for examples.

# %%
# apply rotations 
x_train_rotated = [] 
for x_data in x_train:
    rotated_img = rotate(x_data, angle = random.randint(10,40))
    x_train_rotated.append(rotated_img) 
x_train_rotated = np.asarray(x_train_rotated)

# %%
# apply clockwise rotations 
x_train_rotated_2 = [] 
for x_data in x_train: 
    rotated_img = rotate(x_data, angle = -random.randint(10,40)) 
    x_train_rotated_2.append(rotated_img)
x_train_rotated_2 = np.asarray(x_train_rotated_2)

# %%
# add noise 
x_noised = [] 
for x_data in x_train: 
    noised_img = random_noise(x_data) 
    x_noised.append(noised_img)
x_noised = np.asarray(x_noised)

# %%
# add gaussian blur 
x_blurred = [] 
for x_data in x_train:
    kernel_size = random.choice([3,5,9]) 
    blurred = cv2.GaussianBlur(x_data, (kernel_size, kernel_size), 0) 
    x_blurred.append(blurred)
x_blurred = np.asarray(x_blurred)
x_blurred = x_blurred.reshape(-1,28,28,1)

# %%
# shift image 
x_shifted = [] 
for x_data in x_train: 
    dx = random.choice([-2,-1,1,2])
    dy = random.choice([-2,-1,1,2])
    transform = AffineTransform(translation = (dx,dy))
    warp_img = warp(x_data, transform, mode = "wrap")
    x_shifted.append(warp_img) 
x_shifted = np.asarray(x_shifted)

# %%
# apply brightness modifications 
x_brightness = [] 
for x_data in x_train: 
    brightness = 0.5
    alpha = 1.0 + random.uniform(-brightness, brightness) 
    brightness_modified = x_data * alpha 
    x_brightness.append(brightness_modified) 

x_brightness = np.asarray(x_brightness)

# %%
# apply zca whitening 
def zca_whitening(sample): 
    sample = sample - sample.mean(axis=0)
    cov = np.cov(sample, rowvar = False)
    U,S,V = np.linalg.svd(cov) 
    epsilon = 0.1
    X_ZCA = U.dot(np.diag(1.0/np.sqrt(S + epsilon))).dot(U.T).dot(sample.T).T
    X_ZCA_rescaled = (X_ZCA - X_ZCA.min()) / (X_ZCA.max() - X_ZCA.min())
    X_ZCA_rescaled = X_ZCA_rescaled.reshape((28,28,1)) 
    return X_ZCA_rescaled 

x_zca_whitened = [] 
for x_data in x_train: 
    zca_whitened = zca_whitening(x_data.reshape((28,28))) 
    x_zca_whitened.append(zca_whitened) 
    
x_zca_whitened = np.asarray(x_zca_whitened)

# %%
# add random cropping (zooming effect)
def random_crop(img): 
    img = img.copy() 
    size = random.randint(22,24) # this seems to be a good balance, since our image size is 28 by 28
    crop_size = (size,size)
    w,h = img.shape[:2]
    x,y = np.random.randint(h-crop_size[0]), np.random.randint(w-crop_size[1])
    img = img[y:y+crop_size[0], x:x+crop_size[1]] 
    return img 

x_random_crop = []
for x_data in x_train: 
    cropped = random_crop(x_data) 
    cropped = resize(cropped, (28,28,1))
    x_random_crop.append(cropped)

x_random_crop = np.asarray(x_random_crop)

# %%
# add elastic distortions 
# from https://www.kaggle.com/babbler/mnist-data-augmentation-with-elastic-distortion
def elastic_transform(image, alpha_range, sigma, random_state=None):
    """Elastic deformation of images as described in [Simard2003]_.
    .. [Simard2003] Simard, Steinkraus and Platt, "Best Practices for
       Convolutional Neural Networks applied to Visual Document Analysis", in
       Proc. of the International Conference on Document Analysis and
       Recognition, 2003.
       
   # Arguments
       image: Numpy array with shape (height, width, channels). 
       alpha_range: Float for fixed value or [lower, upper] for random value from uniform distribution.
           Controls intensity of deformation.
       sigma: Float, sigma of gaussian filter that smooths the displacement fields.
       random_state: `numpy.random.RandomState` object for generating displacement fields.
    """
    
    if random_state is None:
        random_state = np.random.RandomState(None)
        
    if np.isscalar(alpha_range):
        alpha = alpha_range
    else:
        alpha = np.random.uniform(low=alpha_range[0], high=alpha_range[1])
    
    shape = image.shape
    dx = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma) * alpha
    dy = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma) * alpha

    x, y, z = np.meshgrid(np.arange(shape[0]), np.arange(shape[1]), np.arange(shape[2]), indexing='ij')
    indices = np.reshape(x+dx, (-1, 1)), np.reshape(y+dy, (-1, 1)), np.reshape(z, (-1, 1))

    return map_coordinates(image, indices, order=1, mode='reflect').reshape(shape)

x_elastic_distort = [] 
for x_data in x_train: 
    distorted = elastic_transform(x_data, [8,10], 3) 
    x_elastic_distort.append(distorted) 
    
x_elastic_distort = np.asarray(x_elastic_distort)

# %%
# load autoencoder generated images 
# seems to lower performance a bit 
# x_en = np.load('./storage/ae_gen_2.npy')

# %%
# concatenating augmented data to the original 
x_train = np.concatenate((x_train, x_train_rotated, x_train_rotated_2, x_noised, x_blurred, x_shifted, x_brightness, x_zca_whitened, x_random_crop, x_elastic_distort), axis = 0) 
y_train = np.concatenate((y_train, y_train, y_train, y_train, y_train, y_train, y_train, y_train, y_train, y_train), axis = 0) 
train_letters_numeric = np.concatenate((train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric, train_letters_numeric), axis = 0)

x_train.shape, y_train.shape, train_letters_numeric.shape
# Out:
# ((20480, 28, 28, 1), (20480, 10), (20480, 26))

# %% [markdown]
# # Conduct Training

# %%
# define train and test data generators 
# this "replaces" the train data. It does not add to it 
# I am not using this for now. I am directly adding augmented data 
train_datagen = ImageDataGenerator(width_shift_range = 0.1, 
                                  height_shift_range = 0.1, 
                                  shear_range = 0.1,
                                  zoom_range = 0.1,
                                  )

# %%
# uses skip connections and also adds information from both MaxPooling2D and AveragePooling2D 
def conv2d_block(input_layer, n_filters, kernel):
    conv1 = Conv2D(n_filters, kernel, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
    conv1 = BatchNormalization()(conv1)
    conv2 = Conv2D(n_filters, kernel, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1) 
    conv2 = BatchNormalization()(conv2)
    conv3 = Conv2D(n_filters, kernel, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2) 
    conv3 = Add()([conv3, conv1])   
    conv3 = BatchNormalization()(conv3) 
    maxpool = MaxPooling2D((2,2))(conv3) 
    avgpool = AveragePooling2D((2,2))(conv3)
    ret = Add()([maxpool,avgpool]) 
    return ret 

# obtains around 82% validation accuracy on a 9:1 train/validation split
# the most promising model so far, until we come up with a potentially more powerful grade 5 model 
def base_cnn_grade_4(): 
    inputs = Input((28,28,1))
    letter_input = Input((26,))    
    conv1 = conv2d_block(inputs, 64, 7) 
    conv2 = conv2d_block(inputs, 64, 5) 
    conv3 = conv2d_block(inputs, 64, 3) 
    conv = Concatenate()([conv1,conv2,conv3])   
    conv1 = conv2d_block(conv, 32, 7)
    conv2 = conv2d_block(conv, 32, 5)
    conv3 = conv2d_block(conv, 32, 3) 
    conv = Concatenate()([conv1,conv2,conv3]) 
    outputs = Flatten()(conv) 
    outputs = Concatenate()([outputs,letter_input])
    for unit in [512, 256, 128]: 
        outputs = Dense(unit, activation = 'relu')(outputs)  
        outputs = BatchNormalization()(outputs) 
    outputs = Dropout(0.4)(outputs) 
    outputs = Dense(10, activation = 'softmax')(outputs)
    model = Model(inputs = [inputs, letter_input], outputs = outputs)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model  

# obtains 91.2% accuracy on public leaderboard. 
# increased to three convolutional blocks 
# batchnorm input layer to normalize the input layer  
def base_cnn_grade_5(): 
    inputs = Input((28,28,1))
    letter_input = Input((26,))  
    bn = BatchNormalization()(inputs)
    conv1 = conv2d_block(bn, 64, 7) 
    conv2 = conv2d_block(bn, 64, 5) 
    conv3 = conv2d_block(bn, 64, 3) 
    conv4 = conv2d_block(bn, 64, 1)
    conv = Concatenate()([conv1,conv2,conv3,conv4])   
    conv = BatchNormalization()(conv) 
    conv1 = conv2d_block(conv, 32, 7)
    conv2 = conv2d_block(conv, 32, 5)
    conv3 = conv2d_block(conv, 32, 3) 
    conv4 = conv2d_block(conv, 32, 1)
    conv = Concatenate()([conv1,conv2,conv3,conv4])   
    conv = BatchNormalization()(conv) 
    conv1 = conv2d_block(conv, 16, 7)
    conv2 = conv2d_block(conv, 16, 5)
    conv3 = conv2d_block(conv, 16, 3)   
    conv4 = conv2d_block(conv, 16, 1)       
    conv = Concatenate()([conv1,conv2,conv3,conv4]) 
    conv = BatchNormalization()(conv) 
    outputs = Flatten()(conv) 
    outputs = Concatenate()([outputs, letter_input]) 
    for units in [512, 256, 128]: 
        outputs = Dense(units, activation = 'relu', kernel_initializer = 'he_normal')(outputs) 
        outputs = BatchNormalization()(outputs)  
    outputs = Dropout(0.4)(outputs) 
    outputs = Dense(10, activation = 'softmax')(outputs)
    model = Model(inputs = [inputs, letter_input], outputs = outputs)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model  


# reduced to two convolutional blocks, but used one more filter size. 
# more dense layers at the end 
# batchnorm input layer to normalize the input layer 
def base_cnn_grade_6(): 
    inputs = Input((28,28,1))
    letter_input = Input((26,))  
    bn = BatchNormalization()(inputs)
    conv1 = conv2d_block(bn, 64, 7) 
    conv2 = conv2d_block(bn, 64, 5) 
    conv3 = conv2d_block(bn, 64, 4)
    conv4 = conv2d_block(bn, 64, 3) 
    conv5 = conv2d_block(bn, 64, 1)
    conv = Concatenate()([conv1,conv2,conv3,conv4,conv5])   
    conv = BatchNormalization()(conv) 
    conv1 = conv2d_block(conv, 32, 7)
    conv2 = conv2d_block(conv, 32, 5)
    conv3 = conv2d_block(conv, 32, 4) 
    conv4 = conv2d_block(conv, 32, 3) 
    conv5 = conv2d_block(conv, 32, 1)
    conv = Concatenate()([conv1,conv2,conv3,conv4,conv5])   
    conv = BatchNormalization()(conv) 
    outputs = Flatten()(conv)  
    outputs = Concatenate()([outputs, letter_input])
    for units in [1024, 512, 256, 128]: 
        outputs = Dense(units, activation = 'relu', kernel_initializer = 'he_normal')(outputs) 
        outputs = BatchNormalization()(outputs)  
    outputs = Dropout(0.4)(outputs) 
    outputs = Dense(10, activation = 'softmax')(outputs)
    model = Model(inputs = [inputs, letter_input], outputs = outputs)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model  

# reduced number of different kernels 
# four conv2d_blocks 
def cnn_grade_7(): 
    inputs = Input((28,28,1)) 
    letter_input = Input((26,)) 
    bn = BatchNormalization()(inputs)  
    # 28x28 -> 14x14 
    conv1 = conv2d_block(bn, 32, 7) 
    conv2 = conv2d_block(bn, 32, 5) 
    conv3 = conv2d_block(bn, 32, 3) 
    conv4 = conv2d_block(bn, 32, 1) 
    conv = Concatenate()([conv1,conv2,conv3,conv4]) 
    conv = BatchNormalization()(conv) 
    
    # 14x14 -> 7x7 
    conv1 = conv2d_block(conv, 64, 7) 
    conv2 = conv2d_block(conv, 64, 5) 
    conv3 = conv2d_block(conv, 64, 3) 
    conv4 = conv2d_block(conv, 64, 1) 
    conv = Concatenate()([conv1,conv2,conv3,conv4]) 
    conv = BatchNormalization()(conv) 
    
    # 7x7 -> 3x3 
    conv1 = conv2d_block(conv, 128, 7)
    conv2 = conv2d_block(conv, 128, 5) 
    conv3 = conv2d_block(conv, 128, 3)
    conv4 = conv2d_block(conv, 128, 1) 
    conv = Concatenate()([conv1,conv2,conv3,conv4]) 
    conv = BatchNormalization()(conv) 
    
    # 3x3 -> 1x1 
    conv1 = conv2d_block(conv, 256, 3) 
    conv2 = conv2d_block(conv, 256, 1) 
    conv = Concatenate()([conv1,conv2]) 
    conv = BatchNormalization()(conv) 
    
    # flatten 
    outputs = Flatten()(conv) 
    outputs = Concatenate()([outputs, letter_input])
    
    # dense resnet-layers
    outputs = Dense(256, activation = 'relu', kernel_initializer = 'he_normal')(outputs) 
    outputs = BatchNormalization()(outputs) 
    res = outputs 
    outputs = Dropout(0.4)(outputs) 
    
    outputs = Dense(256, activation = 'relu', kernel_initializer = 'he_normal')(outputs) 
    outputs = Add()([res, outputs]) 
    outputs = BatchNormalization()(outputs) 
    outputs = Dropout(0.4)(outputs) 
    
    # produce output and create tf map 
    outputs = Dense(10, activation = 'softmax')(outputs)
    model = Model(inputs = [inputs, letter_input], outputs = outputs)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model

# %%
# implement k-fold cv 
def k_fold(k,files):  
    folds = [] 
    fold_size = len(files) // k 
    for i in range(k): 
        if i == k-1:  
            l = files[i*fold_size:] 
        else: 
            l = files[i*fold_size:(i+1)*fold_size]  
        folds.append(l)   
    return folds  

# uncomment below to shuffle before splitting data into folds 
x_train, y_train, train_letters_numeric = shuffle(x_train, y_train, train_letters_numeric)
# split data into 10 folds 
k = 10
x_train_folds = k_fold(k, x_train)
y_train_folds = k_fold(k, y_train) 
letter_train_folds = k_fold(k,train_letters_numeric)

for t in range(k):  
    print("************ Fold {} training ************".format(t+1)) 
    cur_val_x = x_train_folds[t] 
    cur_val_y = y_train_folds[t] 
    cur_val_letter = letter_train_folds[t]
    train_folds_x = x_train_folds[0:t] + x_train_folds[t+1:] 
    train_folds_y = y_train_folds[0:t] + y_train_folds[t+1:]
    train_fold_letter = letter_train_folds[0:t] + letter_train_folds[t+1:]
    cur_train_x = [] 
    cur_train_y = [] 
    cur_letter = [] 
    for j in train_folds_x:  
        for q in j:  
            cur_train_x.append(q) 
    for j in train_folds_y:  
        for q in j:  
            cur_train_y.append(q)  
    for j in train_fold_letter: 
        for q in j: 
            cur_letter.append(q) 
    cur_train_x = np.asarray(cur_train_x)
    cur_train_y = np.asarray(cur_train_y)
    cur_letter = np.asarray(cur_letter) 
    model_path = './storage/mnist_test_3/' + 'kfold' + str(t+1) + '/epoch_{epoch:03d}_val_{val_loss:.3f}_acc_{val_accuracy:.3f}.h5' 
    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.8)
    checkpoint = ModelCheckpoint(filepath=model_path,monitor='val_accuracy',verbose=1,save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_accuracy',patience=25)
    annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x) # possible alternative to ReduceLROnPlateau
    model = cnn_grade_7() 
    
    history = model.fit([cur_train_x,cur_letter],
                        cur_train_y,
                       batch_size = 32,
                       shuffle = True, 
                       validation_data = ([cur_val_x,cur_val_letter],cur_val_y),
                       verbose = 1, 
                       epochs = 300,
                       callbacks = [learning_rate_reduction, checkpoint, early_stopping])
# Out:
# ************ Fold 1 training ************
# Train on 18432 samples, validate on 2048 samples
# Epoch 1/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 2.0240 - accuracy: 0.3569
# Epoch 00001: val_accuracy improved from -inf to 0.60254, saving model to ./storage/mnist_test_3/kfold1/epoch_001_val_1.165_acc_0.603.h5
# 18432/18432 [==============================] - 38s 2ms/sample - loss: 2.0229 - accuracy: 0.3572 - val_loss: 1.1653 - val_accuracy: 0.6025
# Epoch 2/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.9832 - accuracy: 0.6726
# Epoch 00002: val_accuracy improved from 0.60254 to 0.73584, saving model to ./storage/mnist_test_3/kfold1/epoch_002_val_0.773_acc_0.736.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.9830 - accuracy: 0.6727 - val_loss: 0.7729 - val_accuracy: 0.7358
# Epoch 3/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.6280 - accuracy: 0.7935
# Epoch 00003: val_accuracy improved from 0.73584 to 0.80420, saving model to ./storage/mnist_test_3/kfold1/epoch_003_val_0.597_acc_0.804.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.6285 - accuracy: 0.7935 - val_loss: 0.5966 - val_accuracy: 0.8042
# Epoch 4/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.4552 - accuracy: 0.8508
# Epoch 00004: val_accuracy improved from 0.80420 to 0.82910, saving model to ./storage/mnist_test_3/kfold1/epoch_004_val_0.526_acc_0.829.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.4554 - accuracy: 0.8507 - val_loss: 0.5258 - val_accuracy: 0.8291
# Epoch 5/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.3635 - accuracy: 0.8823
# Epoch 00005: val_accuracy improved from 0.82910 to 0.88623, saving model to ./storage/mnist_test_3/kfold1/epoch_005_val_0.338_acc_0.886.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.3634 - accuracy: 0.8824 - val_loss: 0.3379 - val_accuracy: 0.8862
# Epoch 6/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.2687 - accuracy: 0.9142
# Epoch 00006: val_accuracy did not improve from 0.88623
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.2686 - accuracy: 0.9142 - val_loss: 0.3568 - val_accuracy: 0.8857
# Epoch 7/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.2284 - accuracy: 0.9270
# Epoch 00007: val_accuracy improved from 0.88623 to 0.89551, saving model to ./storage/mnist_test_3/kfold1/epoch_007_val_0.344_acc_0.896.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.2286 - accuracy: 0.9269 - val_loss: 0.3441 - val_accuracy: 0.8955
# Epoch 8/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1691 - accuracy: 0.9470
# Epoch 00008: val_accuracy improved from 0.89551 to 0.90332, saving model to ./storage/mnist_test_3/kfold1/epoch_008_val_0.315_acc_0.903.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.1692 - accuracy: 0.9469 - val_loss: 0.3152 - val_accuracy: 0.9033
# Epoch 9/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1557 - accuracy: 0.9513
# Epoch 00009: val_accuracy improved from 0.90332 to 0.90771, saving model to ./storage/mnist_test_3/kfold1/epoch_009_val_0.311_acc_0.908.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.1558 - accuracy: 0.9512 - val_loss: 0.3107 - val_accuracy: 0.9077
# Epoch 10/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1338 - accuracy: 0.9579
# Epoch 00010: val_accuracy improved from 0.90771 to 0.91748, saving model to ./storage/mnist_test_3/kfold1/epoch_010_val_0.291_acc_0.917.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.1336 - accuracy: 0.9580 - val_loss: 0.2915 - val_accuracy: 0.9175
# Epoch 11/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1102 - accuracy: 0.9653
# Epoch 00011: val_accuracy did not improve from 0.91748
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.1100 - accuracy: 0.9653 - val_loss: 0.3515 - val_accuracy: 0.9048
# Epoch 12/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.9668
# Epoch 00012: val_accuracy did not improve from 0.91748
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.1077 - accuracy: 0.9669 - val_loss: 0.2954 - val_accuracy: 0.9160
# Epoch 13/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0843 - accuracy: 0.9747
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
#
# Epoch 00013: val_accuracy did not improve from 0.91748
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0842 - accuracy: 0.9748 - val_loss: 0.3543 - val_accuracy: 0.9019
# Epoch 14/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0555 - accuracy: 0.9820
# Epoch 00014: val_accuracy improved from 0.91748 to 0.93604, saving model to ./storage/mnist_test_3/kfold1/epoch_014_val_0.255_acc_0.936.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0554 - accuracy: 0.9820 - val_loss: 0.2554 - val_accuracy: 0.9360
# Epoch 15/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0551 - accuracy: 0.9826
# Epoch 00015: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0550 - accuracy: 0.9826 - val_loss: 0.3212 - val_accuracy: 0.9165
# Epoch 16/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0532 - accuracy: 0.9835
# Epoch 00016: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0531 - accuracy: 0.9836 - val_loss: 0.3557 - val_accuracy: 0.9131
# Epoch 17/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9848
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 00017: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0487 - accuracy: 0.9848 - val_loss: 0.3139 - val_accuracy: 0.9238
# Epoch 18/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0293 - accuracy: 0.9909
# Epoch 00018: val_accuracy improved from 0.93604 to 0.93994, saving model to ./storage/mnist_test_3/kfold1/epoch_018_val_0.263_acc_0.940.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0292 - accuracy: 0.9909 - val_loss: 0.2625 - val_accuracy: 0.9399
# Epoch 19/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0253 - accuracy: 0.9917
# Epoch 00019: val_accuracy did not improve from 0.93994
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0253 - accuracy: 0.9918 - val_loss: 0.3174 - val_accuracy: 0.9263
# Epoch 20/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9905
# Epoch 00020: val_accuracy did not improve from 0.93994
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0312 - accuracy: 0.9904 - val_loss: 0.2989 - val_accuracy: 0.9302
# Epoch 21/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9921
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 00021: val_accuracy did not improve from 0.93994
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0267 - accuracy: 0.9921 - val_loss: 0.4181 - val_accuracy: 0.9092
# Epoch 22/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0177 - accuracy: 0.9951
# Epoch 00022: val_accuracy did not improve from 0.93994
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0177 - accuracy: 0.9951 - val_loss: 0.3107 - val_accuracy: 0.9351
# Epoch 23/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9974
# Epoch 00023: val_accuracy improved from 0.93994 to 0.94336, saving model to ./storage/mnist_test_3/kfold1/epoch_023_val_0.273_acc_0.943.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.2732 - val_accuracy: 0.9434
# Epoch 24/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9926
# Epoch 00024: val_accuracy did not improve from 0.94336
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0263 - accuracy: 0.9926 - val_loss: 0.3277 - val_accuracy: 0.9336
# Epoch 25/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 0.9942
# Epoch 00025: val_accuracy did not improve from 0.94336
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0173 - accuracy: 0.9942 - val_loss: 0.3070 - val_accuracy: 0.9380
# Epoch 26/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 0.9959
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 00026: val_accuracy did not improve from 0.94336
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.3619 - val_accuracy: 0.9233
# Epoch 27/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0110 - accuracy: 0.9965
# Epoch 00027: val_accuracy did not improve from 0.94336
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.3153 - val_accuracy: 0.9375
# Epoch 28/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9969
# Epoch 00028: val_accuracy did not improve from 0.94336
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.2683 - val_accuracy: 0.9424
# Epoch 29/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9967
# Epoch 00029: val_accuracy improved from 0.94336 to 0.95068, saving model to ./storage/mnist_test_3/kfold1/epoch_029_val_0.258_acc_0.951.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.2575 - val_accuracy: 0.9507
# Epoch 30/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9971
# Epoch 00030: val_accuracy did not improve from 0.95068
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.3043 - val_accuracy: 0.9370
# Epoch 31/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 0.9956
# Epoch 00031: val_accuracy did not improve from 0.95068
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0148 - accuracy: 0.9956 - val_loss: 0.3143 - val_accuracy: 0.9355
# Epoch 32/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9971
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 00032: val_accuracy did not improve from 0.95068
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0097 - accuracy: 0.9971 - val_loss: 0.2912 - val_accuracy: 0.9438
# Epoch 33/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9976
# Epoch 00033: val_accuracy did not improve from 0.95068
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.2996 - val_accuracy: 0.9409
# Epoch 34/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9989
# Epoch 00034: val_accuracy did not improve from 0.95068
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.3209 - val_accuracy: 0.9409
# Epoch 35/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 00035: val_accuracy did not improve from 0.95068
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.3431 - val_accuracy: 0.9395
# Epoch 36/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9987
# Epoch 00036: val_accuracy did not improve from 0.95068
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.3345 - val_accuracy: 0.9380
# Epoch 37/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9992
# Epoch 00037: val_accuracy improved from 0.95068 to 0.95117, saving model to ./storage/mnist_test_3/kfold1/epoch_037_val_0.258_acc_0.951.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.2577 - val_accuracy: 0.9512
# Epoch 38/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9986
# Epoch 00038: val_accuracy did not improve from 0.95117
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.3449 - val_accuracy: 0.9380
# Epoch 39/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9979
# Epoch 00039: val_accuracy did not improve from 0.95117
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.3093 - val_accuracy: 0.9458
# Epoch 40/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9988
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 00040: val_accuracy did not improve from 0.95117
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.2866 - val_accuracy: 0.9404
# Epoch 41/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 00041: val_accuracy did not improve from 0.95117
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.2860 - val_accuracy: 0.9443
# Epoch 42/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 00042: val_accuracy did not improve from 0.95117
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.2860 - val_accuracy: 0.9458
# Epoch 43/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 7.9063e-04 - accuracy: 0.9998
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# Epoch 00043: val_accuracy did not improve from 0.95117
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 7.8950e-04 - accuracy: 0.9998 - val_loss: 0.2799 - val_accuracy: 0.9482
# Epoch 44/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 5.8754e-04 - accuracy: 0.9998
# Epoch 00044: val_accuracy improved from 0.95117 to 0.95508, saving model to ./storage/mnist_test_3/kfold1/epoch_044_val_0.261_acc_0.955.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 5.8815e-04 - accuracy: 0.9998 - val_loss: 0.2606 - val_accuracy: 0.9551
# Epoch 45/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 8.3386e-04 - accuracy: 0.9997
# Epoch 00045: val_accuracy did not improve from 0.95508
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 8.3249e-04 - accuracy: 0.9997 - val_loss: 0.2545 - val_accuracy: 0.9546
# Epoch 46/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 6.2164e-04 - accuracy: 0.9998
# Epoch 00046: val_accuracy did not improve from 0.95508
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 6.2099e-04 - accuracy: 0.9998 - val_loss: 0.2628 - val_accuracy: 0.9531
# Epoch 47/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 7.5478e-04 - accuracy: 0.9998
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
#
# Epoch 00047: val_accuracy did not improve from 0.95508
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 7.5354e-04 - accuracy: 0.9998 - val_loss: 0.3098 - val_accuracy: 0.9482
# Epoch 48/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 00048: val_accuracy did not improve from 0.95508
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.2911 - val_accuracy: 0.9536
# Epoch 49/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00049: val_accuracy did not improve from 0.95508
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.2790 - val_accuracy: 0.9507
# Epoch 50/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 9.0202e-04 - accuracy: 0.9997
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
#
# Epoch 00050: val_accuracy did not improve from 0.95508
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 8.9895e-04 - accuracy: 0.9997 - val_loss: 0.2770 - val_accuracy: 0.9512
# Epoch 51/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00051: val_accuracy did not improve from 0.95508
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.2770 - val_accuracy: 0.9546
# Epoch 52/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 5.8637e-04 - accuracy: 0.9999
# Epoch 00052: val_accuracy did not improve from 0.95508
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 5.8538e-04 - accuracy: 0.9999 - val_loss: 0.2773 - val_accuracy: 0.9541
# Epoch 53/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.2100e-04 - accuracy: 1.0000
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
#
# Epoch 00053: val_accuracy did not improve from 0.95508
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.2083e-04 - accuracy: 1.0000 - val_loss: 0.2752 - val_accuracy: 0.9546
# Epoch 54/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.1748e-04 - accuracy: 1.0000
# Epoch 00054: val_accuracy improved from 0.95508 to 0.95654, saving model to ./storage/mnist_test_3/kfold1/epoch_054_val_0.271_acc_0.957.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 1.1730e-04 - accuracy: 1.0000 - val_loss: 0.2712 - val_accuracy: 0.9565
# Epoch 55/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.2181e-04 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.95654
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.2163e-04 - accuracy: 1.0000 - val_loss: 0.2799 - val_accuracy: 0.9546
# Epoch 56/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 1.2337e-04 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.95654
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 2.3288e-04 - accuracy: 0.9999 - val_loss: 0.2830 - val_accuracy: 0.9561
# Epoch 57/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 00057: val_accuracy did not improve from 0.95654
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.2977 - val_accuracy: 0.9531
# Epoch 58/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 5.9329e-04 - accuracy: 0.9998
# Epoch 00058: val_accuracy did not improve from 0.95654
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 5.9228e-04 - accuracy: 0.9998 - val_loss: 0.2890 - val_accuracy: 0.9551
# Epoch 59/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.9376e-04 - accuracy: 0.9999
# Epoch 00059: val_accuracy did not improve from 0.95654
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.9343e-04 - accuracy: 0.9999 - val_loss: 0.2839 - val_accuracy: 0.9546
# Epoch 60/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 8.1542e-05 - accuracy: 1.0000
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
#
# Epoch 00060: val_accuracy did not improve from 0.95654
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 8.1411e-05 - accuracy: 1.0000 - val_loss: 0.2831 - val_accuracy: 0.9565
# Epoch 61/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 1.0435e-04 - accuracy: 1.0000
# Epoch 00061: val_accuracy improved from 0.95654 to 0.95703, saving model to ./storage/mnist_test_3/kfold1/epoch_061_val_0.280_acc_0.957.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 1.0401e-04 - accuracy: 1.0000 - val_loss: 0.2803 - val_accuracy: 0.9570
# Epoch 62/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 8.6503e-05 - accuracy: 1.0000
# Epoch 00062: val_accuracy improved from 0.95703 to 0.95850, saving model to ./storage/mnist_test_3/kfold1/epoch_062_val_0.280_acc_0.958.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 8.6361e-05 - accuracy: 1.0000 - val_loss: 0.2799 - val_accuracy: 0.9585
# Epoch 63/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.0026e-04 - accuracy: 0.9999
# Epoch 00063: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.0010e-04 - accuracy: 0.9999 - val_loss: 0.2799 - val_accuracy: 0.9570
# Epoch 64/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 5.6910e-05 - accuracy: 1.0000
# Epoch 00064: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 5.6817e-05 - accuracy: 1.0000 - val_loss: 0.2725 - val_accuracy: 0.9570
# Epoch 65/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 4.8125e-05 - accuracy: 1.0000
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
#
# Epoch 00065: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 4.8062e-05 - accuracy: 1.0000 - val_loss: 0.2719 - val_accuracy: 0.9570
# Epoch 66/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 5.4916e-05 - accuracy: 1.0000
# Epoch 00066: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 5.4885e-05 - accuracy: 1.0000 - val_loss: 0.2727 - val_accuracy: 0.9551
# Epoch 67/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 5.2563e-05 - accuracy: 1.0000
# Epoch 00067: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 5.2588e-05 - accuracy: 1.0000 - val_loss: 0.2743 - val_accuracy: 0.9585
# Epoch 68/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.0508e-04 - accuracy: 0.9999
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
#
# Epoch 00068: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.0492e-04 - accuracy: 0.9999 - val_loss: 0.2758 - val_accuracy: 0.9536
# Epoch 69/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 3.1905e-05 - accuracy: 1.0000
# Epoch 00069: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 3.1873e-05 - accuracy: 1.0000 - val_loss: 0.2761 - val_accuracy: 0.9551
# Epoch 70/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 4.3837e-05 - accuracy: 1.0000
# Epoch 00070: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 4.3919e-05 - accuracy: 1.0000 - val_loss: 0.2792 - val_accuracy: 0.9551
# Epoch 71/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 3.6753e-05 - accuracy: 1.0000
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
#
# Epoch 00071: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 3.6796e-05 - accuracy: 1.0000 - val_loss: 0.2798 - val_accuracy: 0.9570
# Epoch 72/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 2.3973e-05 - accuracy: 1.0000
# Epoch 00072: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 2.3949e-05 - accuracy: 1.0000 - val_loss: 0.2825 - val_accuracy: 0.9551
# Epoch 73/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 2.2215e-05 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 2.2195e-05 - accuracy: 1.0000 - val_loss: 0.2825 - val_accuracy: 0.9565
# Epoch 74/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.8628e-05 - accuracy: 1.0000
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
#
# Epoch 00074: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.8619e-05 - accuracy: 1.0000 - val_loss: 0.2859 - val_accuracy: 0.9565
# Epoch 75/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 4.7910e-05 - accuracy: 1.0000
# Epoch 00075: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 4.7840e-05 - accuracy: 1.0000 - val_loss: 0.2866 - val_accuracy: 0.9565
# Epoch 76/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 2.0984e-05 - accuracy: 1.0000
# Epoch 00076: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 2.0951e-05 - accuracy: 1.0000 - val_loss: 0.2864 - val_accuracy: 0.9556
# Epoch 77/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 4.4239e-05 - accuracy: 1.0000
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
#
# Epoch 00077: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 4.4165e-05 - accuracy: 1.0000 - val_loss: 0.2849 - val_accuracy: 0.9570
# Epoch 78/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.5224e-05 - accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.5210e-05 - accuracy: 1.0000 - val_loss: 0.2864 - val_accuracy: 0.9556
# Epoch 79/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 7.0246e-05 - accuracy: 0.9999
# Epoch 00079: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 7.0128e-05 - accuracy: 0.9999 - val_loss: 0.2832 - val_accuracy: 0.9565
# Epoch 80/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.9010e-05 - accuracy: 1.0000
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
#
# Epoch 00080: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.8987e-05 - accuracy: 1.0000 - val_loss: 0.2831 - val_accuracy: 0.9556
# Epoch 81/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.8312e-05 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.8282e-05 - accuracy: 1.0000 - val_loss: 0.2850 - val_accuracy: 0.9551
# Epoch 82/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.5884e-05 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.5859e-05 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9546
# Epoch 83/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.8278e-05 - accuracy: 1.0000
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
#
# Epoch 00083: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.8246e-05 - accuracy: 1.0000 - val_loss: 0.2845 - val_accuracy: 0.9565
# Epoch 84/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.6557e-05 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.6554e-05 - accuracy: 1.0000 - val_loss: 0.2842 - val_accuracy: 0.9565
# Epoch 85/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.4500e-05 - accuracy: 1.0000
# Epoch 00085: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.4482e-05 - accuracy: 1.0000 - val_loss: 0.2845 - val_accuracy: 0.9551
# Epoch 86/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.2287e-05 - accuracy: 1.0000
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
#
# Epoch 00086: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.2272e-05 - accuracy: 1.0000 - val_loss: 0.2861 - val_accuracy: 0.9561
# Epoch 87/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.2119e-05 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.95850
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.2105e-05 - accuracy: 1.0000 - val_loss: 0.2860 - val_accuracy: 0.9561
# ************ Fold 2 training ************
# Train on 18432 samples, validate on 2048 samples
# Epoch 1/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.9740 - accuracy: 0.3737
# Epoch 00001: val_accuracy improved from -inf to 0.56543, saving model to ./storage/mnist_test_3/kfold2/epoch_001_val_1.319_acc_0.565.h5
# 18432/18432 [==============================] - 36s 2ms/sample - loss: 1.9722 - accuracy: 0.3743 - val_loss: 1.3188 - val_accuracy: 0.5654
# Epoch 2/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.9693 - accuracy: 0.6796
# Epoch 00002: val_accuracy improved from 0.56543 to 0.76025, saving model to ./storage/mnist_test_3/kfold2/epoch_002_val_0.748_acc_0.760.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.9689 - accuracy: 0.6796 - val_loss: 0.7476 - val_accuracy: 0.7603
# Epoch 3/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.6166 - accuracy: 0.7988
# Epoch 00003: val_accuracy improved from 0.76025 to 0.82178, saving model to ./storage/mnist_test_3/kfold2/epoch_003_val_0.528_acc_0.822.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.6164 - accuracy: 0.7989 - val_loss: 0.5276 - val_accuracy: 0.8218
# Epoch 4/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.4490 - accuracy: 0.8542
# Epoch 00004: val_accuracy improved from 0.82178 to 0.84863, saving model to ./storage/mnist_test_3/kfold2/epoch_004_val_0.492_acc_0.849.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.4492 - accuracy: 0.8542 - val_loss: 0.4925 - val_accuracy: 0.8486
# Epoch 5/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.3447 - accuracy: 0.8890
# Epoch 00005: val_accuracy improved from 0.84863 to 0.87598, saving model to ./storage/mnist_test_3/kfold2/epoch_005_val_0.377_acc_0.876.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.3446 - accuracy: 0.8891 - val_loss: 0.3772 - val_accuracy: 0.8760
# Epoch 6/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.2770 - accuracy: 0.9128
# Epoch 00006: val_accuracy improved from 0.87598 to 0.88525, saving model to ./storage/mnist_test_3/kfold2/epoch_006_val_0.378_acc_0.885.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.2770 - accuracy: 0.9128 - val_loss: 0.3781 - val_accuracy: 0.8853
# Epoch 7/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.2126 - accuracy: 0.9322
# Epoch 00007: val_accuracy improved from 0.88525 to 0.88818, saving model to ./storage/mnist_test_3/kfold2/epoch_007_val_0.374_acc_0.888.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.2125 - accuracy: 0.9323 - val_loss: 0.3738 - val_accuracy: 0.8882
# Epoch 8/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1751 - accuracy: 0.9444
# Epoch 00008: val_accuracy improved from 0.88818 to 0.90625, saving model to ./storage/mnist_test_3/kfold2/epoch_008_val_0.313_acc_0.906.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.1748 - accuracy: 0.9444 - val_loss: 0.3126 - val_accuracy: 0.9062
# Epoch 9/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1509 - accuracy: 0.9514
# Epoch 00009: val_accuracy improved from 0.90625 to 0.90967, saving model to ./storage/mnist_test_3/kfold2/epoch_009_val_0.300_acc_0.910.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.1507 - accuracy: 0.9514 - val_loss: 0.3002 - val_accuracy: 0.9097
# Epoch 10/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1384 - accuracy: 0.9566
# Epoch 00010: val_accuracy improved from 0.90967 to 0.91699, saving model to ./storage/mnist_test_3/kfold2/epoch_010_val_0.301_acc_0.917.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.1386 - accuracy: 0.9565 - val_loss: 0.3014 - val_accuracy: 0.9170
# Epoch 11/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1075 - accuracy: 0.9660
# Epoch 00011: val_accuracy did not improve from 0.91699
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.1078 - accuracy: 0.9659 - val_loss: 0.3410 - val_accuracy: 0.9062
# Epoch 12/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1007 - accuracy: 0.9683
# Epoch 00012: val_accuracy did not improve from 0.91699
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.1007 - accuracy: 0.9683 - val_loss: 0.4249 - val_accuracy: 0.8965
# Epoch 13/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.1042 - accuracy: 0.9684
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
#
# Epoch 00013: val_accuracy did not improve from 0.91699
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.1041 - accuracy: 0.9685 - val_loss: 0.3286 - val_accuracy: 0.9126
# Epoch 14/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0529 - accuracy: 0.9825
# Epoch 00014: val_accuracy improved from 0.91699 to 0.92236, saving model to ./storage/mnist_test_3/kfold2/epoch_014_val_0.291_acc_0.922.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0531 - accuracy: 0.9824 - val_loss: 0.2914 - val_accuracy: 0.9224
# Epoch 15/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9840
# Epoch 00015: val_accuracy did not improve from 0.92236
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0510 - accuracy: 0.9839 - val_loss: 0.3379 - val_accuracy: 0.9165
# Epoch 16/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0545 - accuracy: 0.9845
# Epoch 00016: val_accuracy improved from 0.92236 to 0.92969, saving model to ./storage/mnist_test_3/kfold2/epoch_016_val_0.288_acc_0.930.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0545 - accuracy: 0.9844 - val_loss: 0.2878 - val_accuracy: 0.9297
# Epoch 17/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9847
# Epoch 00017: val_accuracy did not improve from 0.92969
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0466 - accuracy: 0.9847 - val_loss: 0.3593 - val_accuracy: 0.9170
# Epoch 18/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0508 - accuracy: 0.9845
# Epoch 00018: val_accuracy did not improve from 0.92969
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0508 - accuracy: 0.9845 - val_loss: 0.3511 - val_accuracy: 0.9185
# Epoch 19/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0519 - accuracy: 0.9849
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 00019: val_accuracy did not improve from 0.92969
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0518 - accuracy: 0.9849 - val_loss: 0.2952 - val_accuracy: 0.9253
# Epoch 20/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9936
# Epoch 00020: val_accuracy improved from 0.92969 to 0.93604, saving model to ./storage/mnist_test_3/kfold2/epoch_020_val_0.248_acc_0.936.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0205 - accuracy: 0.9936 - val_loss: 0.2481 - val_accuracy: 0.9360
# Epoch 21/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 0.9968
# Epoch 00021: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.3166 - val_accuracy: 0.9297
# Epoch 22/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9902
# Epoch 00022: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0348 - accuracy: 0.9901 - val_loss: 0.4354 - val_accuracy: 0.9004
# Epoch 23/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9928
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 00023: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0231 - accuracy: 0.9928 - val_loss: 0.3353 - val_accuracy: 0.9248
# Epoch 24/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9946
# Epoch 00024: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.3680 - val_accuracy: 0.9302
# Epoch 25/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9956
# Epoch 00025: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.3690 - val_accuracy: 0.9238
# Epoch 26/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9959
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 00026: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.3379 - val_accuracy: 0.9336
# Epoch 27/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9970
# Epoch 00027: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.3365 - val_accuracy: 0.9292
# Epoch 28/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9968
# Epoch 00028: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.3058 - val_accuracy: 0.9355
# Epoch 29/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9985
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 00029: val_accuracy did not improve from 0.93604
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.3346 - val_accuracy: 0.9331
# Epoch 30/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9978
# Epoch 00030: val_accuracy improved from 0.93604 to 0.93848, saving model to ./storage/mnist_test_3/kfold2/epoch_030_val_0.306_acc_0.938.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.3064 - val_accuracy: 0.9385
# Epoch 31/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9982
# Epoch 00031: val_accuracy improved from 0.93848 to 0.94531, saving model to ./storage/mnist_test_3/kfold2/epoch_031_val_0.291_acc_0.945.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.2910 - val_accuracy: 0.9453
# Epoch 32/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9995
# Epoch 00032: val_accuracy did not improve from 0.94531
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.3761 - val_accuracy: 0.9321
# Epoch 33/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9981
# Epoch 00033: val_accuracy did not improve from 0.94531
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.3199 - val_accuracy: 0.9370
# Epoch 34/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0138 - accuracy: 0.9959
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 00034: val_accuracy did not improve from 0.94531
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0137 - accuracy: 0.9959 - val_loss: 0.3425 - val_accuracy: 0.9336
# Epoch 35/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9987
# Epoch 00035: val_accuracy did not improve from 0.94531
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.3040 - val_accuracy: 0.9409
# Epoch 36/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 00036: val_accuracy did not improve from 0.94531
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.2953 - val_accuracy: 0.9419
# Epoch 37/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 9.5359e-04 - accuracy: 0.9999
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 00037: val_accuracy did not improve from 0.94531
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 9.5300e-04 - accuracy: 0.9999 - val_loss: 0.2766 - val_accuracy: 0.9453
# Epoch 38/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 9.1945e-04 - accuracy: 0.9997
# Epoch 00038: val_accuracy did not improve from 0.94531
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 9.1798e-04 - accuracy: 0.9997 - val_loss: 0.2881 - val_accuracy: 0.9434
# Epoch 39/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993
# Epoch 00039: val_accuracy did not improve from 0.94531
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.3234 - val_accuracy: 0.9385
# Epoch 40/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# Epoch 00040: val_accuracy did not improve from 0.94531
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.2840 - val_accuracy: 0.9434
# Epoch 41/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9997
# Epoch 00041: val_accuracy did not improve from 0.94531
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.2825 - val_accuracy: 0.9434
# Epoch 42/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996
# Epoch 00042: val_accuracy improved from 0.94531 to 0.94727, saving model to ./storage/mnist_test_3/kfold2/epoch_042_val_0.301_acc_0.947.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.3014 - val_accuracy: 0.9473
# Epoch 43/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 9.2322e-04 - accuracy: 0.9997
# Epoch 00043: val_accuracy did not improve from 0.94727
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 9.2168e-04 - accuracy: 0.9997 - val_loss: 0.2860 - val_accuracy: 0.9458
# Epoch 44/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9995
# Epoch 00044: val_accuracy did not improve from 0.94727
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.2902 - val_accuracy: 0.9453
# Epoch 45/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 00045: val_accuracy improved from 0.94727 to 0.94824, saving model to ./storage/mnist_test_3/kfold2/epoch_045_val_0.300_acc_0.948.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.3002 - val_accuracy: 0.9482
# Epoch 46/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9991
# Epoch 00046: val_accuracy did not improve from 0.94824
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.3409 - val_accuracy: 0.9409
# Epoch 47/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 8.5863e-04 - accuracy: 0.9998
# Epoch 00047: val_accuracy did not improve from 0.94824
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 8.6043e-04 - accuracy: 0.9998 - val_loss: 0.2944 - val_accuracy: 0.9458
# Epoch 48/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 4.2772e-04 - accuracy: 0.9999
# Epoch 00048: val_accuracy improved from 0.94824 to 0.95117, saving model to ./storage/mnist_test_3/kfold2/epoch_048_val_0.291_acc_0.951.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 4.2707e-04 - accuracy: 0.9999 - val_loss: 0.2910 - val_accuracy: 0.9512
# Epoch 49/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 3.0527e-04 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.95117
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 3.0479e-04 - accuracy: 1.0000 - val_loss: 0.2982 - val_accuracy: 0.9512
# Epoch 50/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.8216e-04 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.95117
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.8195e-04 - accuracy: 1.0000 - val_loss: 0.2940 - val_accuracy: 0.9492
# Epoch 51/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.4691e-04 - accuracy: 1.0000
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
#
# Epoch 00051: val_accuracy did not improve from 0.95117
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.4669e-04 - accuracy: 1.0000 - val_loss: 0.2869 - val_accuracy: 0.9507
# Epoch 52/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.3245e-04 - accuracy: 1.0000
# Epoch 00052: val_accuracy improved from 0.95117 to 0.95361, saving model to ./storage/mnist_test_3/kfold2/epoch_052_val_0.279_acc_0.954.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 1.3224e-04 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.9536
# Epoch 53/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 1.3780e-04 - accuracy: 1.0000
# Epoch 00053: val_accuracy did not improve from 0.95361
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.3766e-04 - accuracy: 1.0000 - val_loss: 0.2904 - val_accuracy: 0.9507
# Epoch 54/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 2.5246e-04 - accuracy: 0.9999
# Epoch 00054: val_accuracy improved from 0.95361 to 0.95410, saving model to ./storage/mnist_test_3/kfold2/epoch_054_val_0.275_acc_0.954.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 2.5207e-04 - accuracy: 0.9999 - val_loss: 0.2755 - val_accuracy: 0.9541
# Epoch 55/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.4790e-04 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.95410
# ...
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0383 - accuracy: 0.9877 - val_loss: 0.3465 - val_accuracy: 0.9160
# Epoch 17/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0374 - accuracy: 0.9888
# Epoch 00017: val_accuracy did not improve from 0.91602
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0376 - accuracy: 0.9888 - val_loss: 0.4708 - val_accuracy: 0.8804
# Epoch 18/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0575 - accuracy: 0.9822
# Epoch 00018: val_accuracy improved from 0.91602 to 0.92285, saving model to ./storage/mnist_test_3/kfold10/epoch_018_val_0.337_acc_0.923.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0574 - accuracy: 0.9823 - val_loss: 0.3375 - val_accuracy: 0.9229
# Epoch 19/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0381 - accuracy: 0.9889
# Epoch 00019: val_accuracy improved from 0.92285 to 0.92578, saving model to ./storage/mnist_test_3/kfold10/epoch_019_val_0.351_acc_0.926.h5
# 18432/18432 [==============================] - 27s 1ms/sample - loss: 0.0380 - accuracy: 0.9889 - val_loss: 0.3512 - val_accuracy: 0.9258
# Epoch 20/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9871
# Epoch 00020: val_accuracy did not improve from 0.92578
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0415 - accuracy: 0.9871 - val_loss: 0.3817 - val_accuracy: 0.9136
# Epoch 21/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9884
# Epoch 00021: val_accuracy did not improve from 0.92578
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0406 - accuracy: 0.9884 - val_loss: 0.3370 - val_accuracy: 0.9209
# Epoch 22/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9897
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 00022: val_accuracy did not improve from 0.92578
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0329 - accuracy: 0.9897 - val_loss: 0.4046 - val_accuracy: 0.9209
# Epoch 23/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9936
# Epoch 00023: val_accuracy improved from 0.92578 to 0.93262, saving model to ./storage/mnist_test_3/kfold10/epoch_023_val_0.335_acc_0.933.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0225 - accuracy: 0.9937 - val_loss: 0.3353 - val_accuracy: 0.9326
# Epoch 24/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0200 - accuracy: 0.9940
# Epoch 00024: val_accuracy did not improve from 0.93262
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0200 - accuracy: 0.9940 - val_loss: 0.3941 - val_accuracy: 0.9258
# Epoch 25/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 0.9944
# Epoch 00025: val_accuracy improved from 0.93262 to 0.93311, saving model to ./storage/mnist_test_3/kfold10/epoch_025_val_0.336_acc_0.933.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0220 - accuracy: 0.9944 - val_loss: 0.3365 - val_accuracy: 0.9331
# Epoch 26/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0259 - accuracy: 0.9927
# Epoch 00026: val_accuracy did not improve from 0.93311
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0259 - accuracy: 0.9927 - val_loss: 0.3877 - val_accuracy: 0.9204
# Epoch 27/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0197 - accuracy: 0.9942
# Epoch 00027: val_accuracy did not improve from 0.93311
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0197 - accuracy: 0.9941 - val_loss: 0.4468 - val_accuracy: 0.9170
# Epoch 28/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 0.0203 - accuracy: 0.9938
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 00028: val_accuracy did not improve from 0.93311
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0203 - accuracy: 0.9938 - val_loss: 0.3551 - val_accuracy: 0.9209
# Epoch 29/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9977
# Epoch 00029: val_accuracy did not improve from 0.93311
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.3354 - val_accuracy: 0.9316
# Epoch 30/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9979
# Epoch 00030: val_accuracy did not improve from 0.93311
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.3936 - val_accuracy: 0.9331
# Epoch 31/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0145 - accuracy: 0.9958
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 00031: val_accuracy did not improve from 0.93311
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.3536 - val_accuracy: 0.9277
# Epoch 32/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9979
# Epoch 00032: val_accuracy improved from 0.93311 to 0.93896, saving model to ./storage/mnist_test_3/kfold10/epoch_032_val_0.318_acc_0.939.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.3185 - val_accuracy: 0.9390
# Epoch 33/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9973
# Epoch 00033: val_accuracy did not improve from 0.93896
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.3628 - val_accuracy: 0.9326
# Epoch 34/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0085 - accuracy: 0.9972
# Epoch 00034: val_accuracy did not improve from 0.93896
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.2768 - val_accuracy: 0.9380
# Epoch 35/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9987
# Epoch 00035: val_accuracy improved from 0.93896 to 0.94775, saving model to ./storage/mnist_test_3/kfold10/epoch_035_val_0.275_acc_0.948.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.2747 - val_accuracy: 0.9478
# Epoch 36/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9968
# Epoch 00036: val_accuracy did not improve from 0.94775
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0125 - accuracy: 0.9967 - val_loss: 0.3589 - val_accuracy: 0.9336
# Epoch 37/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9978
# Epoch 00037: val_accuracy did not improve from 0.94775
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.3491 - val_accuracy: 0.9409
# Epoch 38/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9973
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 00038: val_accuracy did not improve from 0.94775
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0107 - accuracy: 0.9972 - val_loss: 0.3771 - val_accuracy: 0.9365
# Epoch 39/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9989
# Epoch 00039: val_accuracy improved from 0.94775 to 0.95215, saving model to ./storage/mnist_test_3/kfold10/epoch_039_val_0.309_acc_0.952.h5
# 18432/18432 [==============================] - 26s 1ms/sample - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.3093 - val_accuracy: 0.9521
# Epoch 40/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 00040: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.3118 - val_accuracy: 0.9473
# Epoch 41/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9988
# Epoch 00041: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.3585 - val_accuracy: 0.9360
# Epoch 42/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9986
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 00042: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.3454 - val_accuracy: 0.9404
# Epoch 43/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9988
# Epoch 00043: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.3499 - val_accuracy: 0.9395
# Epoch 44/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9990
# Epoch 00044: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.3742 - val_accuracy: 0.9346
# Epoch 45/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9989
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 00045: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0064 - accuracy: 0.9989 - val_loss: 0.3466 - val_accuracy: 0.9424
# Epoch 46/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 00046: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.3464 - val_accuracy: 0.9399
# Epoch 47/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9995
# Epoch 00047: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.3400 - val_accuracy: 0.9434
# Epoch 48/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 6.2051e-04 - accuracy: 0.9999
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# Epoch 00048: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 6.1960e-04 - accuracy: 0.9999 - val_loss: 0.3390 - val_accuracy: 0.9429
# Epoch 49/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 3.6656e-04 - accuracy: 0.9999
# Epoch 00049: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 3.6593e-04 - accuracy: 0.9999 - val_loss: 0.3568 - val_accuracy: 0.9424
# Epoch 50/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 2.4782e-04 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 2.4751e-04 - accuracy: 1.0000 - val_loss: 0.3511 - val_accuracy: 0.9424
# Epoch 51/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 1.8644e-04 - accuracy: 0.9999
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
#
# Epoch 00051: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.8599e-04 - accuracy: 0.9999 - val_loss: 0.3546 - val_accuracy: 0.9419
# Epoch 52/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 9.9543e-05 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 9.9485e-05 - accuracy: 1.0000 - val_loss: 0.3600 - val_accuracy: 0.9419
# Epoch 53/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 00053: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.3794 - val_accuracy: 0.9404
# Epoch 54/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 7.5260e-04 - accuracy: 0.9998
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
#
# Epoch 00054: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 7.5135e-04 - accuracy: 0.9998 - val_loss: 0.3836 - val_accuracy: 0.9414
# Epoch 55/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 5.1989e-04 - accuracy: 0.9998
# Epoch 00055: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 5.1900e-04 - accuracy: 0.9998 - val_loss: 0.4041 - val_accuracy: 0.9414
# Epoch 56/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 2.8243e-04 - accuracy: 0.9999
# Epoch 00056: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 2.8196e-04 - accuracy: 0.9999 - val_loss: 0.3843 - val_accuracy: 0.9429
# Epoch 57/300
# 18368/18432 [============================>.] - ETA: 0s - loss: 2.9825e-04 - accuracy: 0.9999
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
#
# Epoch 00057: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 2.9732e-04 - accuracy: 0.9999 - val_loss: 0.3814 - val_accuracy: 0.9429
# Epoch 58/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 2.6965e-04 - accuracy: 0.9999
# Epoch 00058: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 2.6919e-04 - accuracy: 0.9999 - val_loss: 0.4051 - val_accuracy: 0.9438
# Epoch 59/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.7202e-04 - accuracy: 1.0000
# Epoch 00059: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.7177e-04 - accuracy: 1.0000 - val_loss: 0.4036 - val_accuracy: 0.9429
# Epoch 60/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.3459e-04 - accuracy: 1.0000
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 00060: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.3437e-04 - accuracy: 1.0000 - val_loss: 0.4038 - val_accuracy: 0.9419
# Epoch 61/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 8.8471e-05 - accuracy: 1.0000
# Epoch 00061: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 8.8343e-05 - accuracy: 1.0000 - val_loss: 0.3967 - val_accuracy: 0.9429
# Epoch 62/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.1208e-04 - accuracy: 1.0000
# Epoch 00062: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.1189e-04 - accuracy: 1.0000 - val_loss: 0.4047 - val_accuracy: 0.9438
# Epoch 63/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 1.0255e-04 - accuracy: 0.9999
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
#
# Epoch 00063: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 1.0265e-04 - accuracy: 0.9999 - val_loss: 0.4165 - val_accuracy: 0.9414
# Epoch 64/300
# 18400/18432 [============================>.] - ETA: 0s - loss: 4.0078e-05 - accuracy: 1.0000
# Epoch 00064: val_accuracy did not improve from 0.95215
# 18432/18432 [==============================] - 25s 1ms/sample - loss: 4.0115e-05 - accuracy: 1.0000 - val_loss: 0.4142 - val_accuracy: 0.9414
